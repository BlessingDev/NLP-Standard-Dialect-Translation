# %%
import pandas as pd

# %% [markdown]
# # 제주 방언 자모 토큰 구간별 분할

# %%
jj_jamo = pd.read_csv("/workspace/datas/jeju/jeju_dialect_jamo_integration.csv", index_col=0)

jj_jamo
# Out:
#                                                        방언  \
# 0       ㄴ ㅏ ㄴ <SEP> <SPC> ㅈ ㅣ ㄴ <SEP> ㅉ ㅏ <SEP> <SPC> ...
# 9       ㅇ ㅏ <SEP> <SPC> ㅇ ㅖ <SEP> ㅊ ㅗ <SEP> ㅎ ㅏ <SEP> ...
# 11      ㅇ ㅏ <SEP> <SPC> ㄱ ㅓ ㅇ <SEP> ㅎ ㅏ <SEP> ㄴ ㅣ <SEP...
# 14      ㅈ ㅓ <SEP> ㄱ ㅣ <SEP> <SPC> ㄷ ㅗ ㄹ <SEP> ㅁ ㅔ ㅇ <S...
# 17      ㄴ ㅏ <SEP> <SPC> ㅇ ㅏ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ㅅ ...
# ...                                                   ...
# 333774  ㅇ ㅏ <SEP> <SPC> ㄴ ㅓ <SEP> <SPC> ㄴ ㅓ <SEP> <SPC...
# 333778  ㅇ ㅏ <SEP> <SPC> ㅅ ㅣ ㅂ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ...
# 333782  ㅇ ㅣ ㄹ <SEP> ㅇ ㅛ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ㅇ ㅗ <S...
# 333790  ㅁ ㅏ ㄱ <SEP> ㄱ ㅓ ㄹ <SEP> ㄹ ㅣ <SEP> ㄴ ㅏ <SEP> <S...
# 333800  ㄴ ㅏ ㄴ <SEP> <SPC> ㅊ ㅏ <SEP> <SPC> ㅇ ㅓ <SEP> ㅅ ...
#
#                                                       표준어  연령대  \
# 0       ㄴ ㅏ ㄴ <SEP> <SPC> ㅈ ㅣ ㄴ <SEP> ㅉ ㅏ <SEP> <SPC> ...  50대
# 9       ㅇ ㅏ <SEP> <SPC> ㅇ ㅖ <SEP> ㅊ ㅗ <SEP> ㅎ ㅏ <SEP> ...  50대
# 11      ㅇ ㅏ <SEP> <SPC> ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄴ ㅣ <SEP> ...  50대
# ...

# %%
jj_jamo = jj_jamo.reset_index(drop=True)

# %%
seq_len_list = []
for sentence in jj_jamo["방언"].to_list():
    seq_len = len(sentence.split())
    
    seq_len_list.append(seq_len)

jj_jamo.loc[jj_jamo.index, "토큰 길이"] = seq_len_list

jj_jamo
# Out:
#                                                         방언  \
# 0        ㄴ ㅏ ㄴ <SEP> <SPC> ㅈ ㅣ ㄴ <SEP> ㅉ ㅏ <SEP> <SPC> ...
# 1        ㅇ ㅏ <SEP> <SPC> ㅇ ㅖ <SEP> ㅊ ㅗ <SEP> ㅎ ㅏ <SEP> ...
# 2        ㅇ ㅏ <SEP> <SPC> ㄱ ㅓ ㅇ <SEP> ㅎ ㅏ <SEP> ㄴ ㅣ <SEP...
# 3        ㅈ ㅓ <SEP> ㄱ ㅣ <SEP> <SPC> ㄷ ㅗ ㄹ <SEP> ㅁ ㅔ ㅇ <S...
# 4        ㄴ ㅏ <SEP> <SPC> ㅇ ㅏ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ㅅ ...
# ...                                                    ...
# 1535552  ㅇ ㅏ <SEP> <SPC> ㄴ ㅓ <SEP> <SPC> ㄴ ㅓ <SEP> <SPC...
# 1535553  ㅇ ㅏ <SEP> <SPC> ㅅ ㅣ ㅂ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ...
# 1535554  ㅇ ㅣ ㄹ <SEP> ㅇ ㅛ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ㅇ ㅗ <S...
# 1535555  ㅁ ㅏ ㄱ <SEP> ㄱ ㅓ ㄹ <SEP> ㄹ ㅣ <SEP> ㄴ ㅏ <SEP> <S...
# 1535556  ㄴ ㅏ ㄴ <SEP> <SPC> ㅊ ㅏ <SEP> <SPC> ㅇ ㅓ <SEP> ㅅ ...
#
#                                                        표준어  연령대  \
# 0        ㄴ ㅏ ㄴ <SEP> <SPC> ㅈ ㅣ ㄴ <SEP> ㅉ ㅏ <SEP> <SPC> ...  50대
# 1        ㅇ ㅏ <SEP> <SPC> ㅇ ㅖ <SEP> ㅊ ㅗ <SEP> ㅎ ㅏ <SEP> ...  50대
# ...

# %%
jj_jamo["토큰 길이"].mean()
# Out:
# 72.8849720329496

# %%
jj_jamo_1 = jj_jamo[jj_jamo["토큰 길이"] <= 106]

jj_jamo_1
# Out:
#                                                         방언  \
# 0        ㄴ ㅏ ㄴ <SEP> <SPC> ㅈ ㅣ ㄴ <SEP> ㅉ ㅏ <SEP> <SPC> ...
# 1        ㅇ ㅏ <SEP> <SPC> ㅇ ㅖ <SEP> ㅊ ㅗ <SEP> ㅎ ㅏ <SEP> ...
# 2        ㅇ ㅏ <SEP> <SPC> ㄱ ㅓ ㅇ <SEP> ㅎ ㅏ <SEP> ㄴ ㅣ <SEP...
# 3        ㅈ ㅓ <SEP> ㄱ ㅣ <SEP> <SPC> ㄷ ㅗ ㄹ <SEP> ㅁ ㅔ ㅇ <S...
# 4        ㄴ ㅏ <SEP> <SPC> ㅇ ㅏ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ㅅ ...
# ...                                                    ...
# 1535552  ㅇ ㅏ <SEP> <SPC> ㄴ ㅓ <SEP> <SPC> ㄴ ㅓ <SEP> <SPC...
# 1535553  ㅇ ㅏ <SEP> <SPC> ㅅ ㅣ ㅂ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ...
# 1535554  ㅇ ㅣ ㄹ <SEP> ㅇ ㅛ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ㅇ ㅗ <S...
# 1535555  ㅁ ㅏ ㄱ <SEP> ㄱ ㅓ ㄹ <SEP> ㄹ ㅣ <SEP> ㄴ ㅏ <SEP> <S...
# 1535556  ㄴ ㅏ ㄴ <SEP> <SPC> ㅊ ㅏ <SEP> <SPC> ㅇ ㅓ <SEP> ㅅ ...
#
#                                                        표준어  연령대  \
# 0        ㄴ ㅏ ㄴ <SEP> <SPC> ㅈ ㅣ ㄴ <SEP> ㅉ ㅏ <SEP> <SPC> ...  50대
# 1        ㅇ ㅏ <SEP> <SPC> ㅇ ㅖ <SEP> ㅊ ㅗ <SEP> ㅎ ㅏ <SEP> ...  50대
# ...

# %%
jj_jamo_1[jj_jamo_1["셋"] == "train"]
# Out:
#                                                         방언  \
# 0        ㄴ ㅏ ㄴ <SEP> <SPC> ㅈ ㅣ ㄴ <SEP> ㅉ ㅏ <SEP> <SPC> ...
# 1        ㅇ ㅏ <SEP> <SPC> ㅇ ㅖ <SEP> ㅊ ㅗ <SEP> ㅎ ㅏ <SEP> ...
# 2        ㅇ ㅏ <SEP> <SPC> ㄱ ㅓ ㅇ <SEP> ㅎ ㅏ <SEP> ㄴ ㅣ <SEP...
# 3        ㅈ ㅓ <SEP> ㄱ ㅣ <SEP> <SPC> ㄷ ㅗ ㄹ <SEP> ㅁ ㅔ ㅇ <S...
# 4        ㄴ ㅏ <SEP> <SPC> ㅇ ㅏ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ㅅ ...
# ...                                                    ...
# 1375428  ㄷ ㅜ <SEP> <SPC> ㅁ ㅕ ㅇ <SEP> <SPC> ㅇ ㅣ <SEP> <S...
# 1375429  ㄴ ㅏ <SEP> <SPC> ㅈ ㅣ ㅂ <SEP> ㅇ ㅔ <SEP> <SPC> ㅎ ...
# 1375431  ㅅ ㅐ ㄱ <SEP> ㄲ ㅏ ㄹ <SEP> <SPC> ㅂ ㅏ ㄴ <SEP> ㅈ ㅓ ...
# 1375433  n <SEP> a <SEP> m <SEP> e <SEP> ㅇ ㅣ <SEP> <SPC...
# 1375434  ㅇ ㅓ <SEP> <SPC> ㅁ ㅏ ㅈ <SEP> ㅇ ㅏ <SEP> <SPC> ㄴ ...
#
#                                                        표준어  연령대  \
# 0        ㄴ ㅏ ㄴ <SEP> <SPC> ㅈ ㅣ ㄴ <SEP> ㅉ ㅏ <SEP> <SPC> ...  50대
# 1        ㅇ ㅏ <SEP> <SPC> ㅇ ㅖ <SEP> ㅊ ㅗ <SEP> ㅎ ㅏ <SEP> ...  50대
# ...

# %%
jj_jamo_1.to_csv("/workspace/datas/jeju/jeju_dialect_jamo_integration_1.csv")

# %%
jj_jamo_2 = jj_jamo[(jj_jamo["토큰 길이"] >= 107) & (jj_jamo["토큰 길이"] < 196)]

jj_jamo_2
# Out:
#                                                         방언  \
# 6        ㅇ ㅏ <SEP> ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄴ ㅣ <SEP> ㄲ ㅏ <S...
# 49       ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄴ ㅣ <SEP> ㄲ ㅏ <SEP> <SPC> ...
# 51       ㄱ ㅡ <SEP> ㄸ ㅐ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ㄴ ㅗ ㅇ <S...
# 52       ㅇ ㅛ <SEP> ㅈ ㅡ ㅁ <SEP> ㅇ ㅡ ㄴ <SEP> <SPC> ㅇ ㅝ <S...
# 62       ㅇ ㅓ <SEP> ㅇ ㅓ <SEP> <SPC> ㅇ ㅓ <SEP> <SPC> ㄱ ㅡ ...
# ...                                                    ...
# 1535530  ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㄱ ㅏ <SEP> ㅈ ㅣ <SEP> ㄱ ㅜ <S...
# 1535532  ㄱ ㅡ <SEP> <SPC> ㅈ ㅓ <SEP> <SPC> ㄹ ㅓ ㄴ <SEP> ㄴ ...
# 1535543  ㄱ ㅑ ㅇ <SEP> <SPC> ㄱ ㅡ ㅂ <SEP> ㅎ ㅐ <SEP> ㄱ ㅏ <S...
# 1535544  ㅇ ㅣ <SEP> ㅈ ㅔ <SEP> <SPC> ㅈ ㅜ ㅇ <SEP> ㅎ ㅏ ㄱ <S...
# 1535549  ㄴ ㅏ <SEP> <SPC> ㄴ ㅏ <SEP> <SPC> ㅅ ㅣ ㅂ <SEP> ㅅ ...
#
#                                                        표준어  연령대  \
# 6        ㅇ ㅏ <SEP> ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄴ ㅣ <SEP> ㄲ ㅏ <S...  50대
# 49       ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄴ ㅣ <SEP> ㄲ ㅏ <SEP> <SPC> ...  50대
# ...

# %%
jj_jamo_2[jj_jamo_2["셋"] == "train"]
# Out:
#                                                         방언  \
# 6        ㅇ ㅏ <SEP> ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄴ ㅣ <SEP> ㄲ ㅏ <S...
# 49       ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄴ ㅣ <SEP> ㄲ ㅏ <SEP> <SPC> ...
# 51       ㄱ ㅡ <SEP> ㄸ ㅐ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ㄴ ㅗ ㅇ <S...
# 52       ㅇ ㅛ <SEP> ㅈ ㅡ ㅁ <SEP> ㅇ ㅡ ㄴ <SEP> <SPC> ㅇ ㅝ <S...
# 62       ㅇ ㅓ <SEP> ㅇ ㅓ <SEP> <SPC> ㅇ ㅓ <SEP> <SPC> ㄱ ㅡ ...
# ...                                                    ...
# 1375404  ㅎ ㅣ <SEP> ㅌ ㅡ ㄹ <SEP> ㄹ ㅓ <SEP> <SPC> ㄱ ㅡ <SEP...
# 1375405  ㄱ ㅡ <SEP> <SPC> ㄱ ㅔ <SEP> ㅇ ㅣ ㅁ <SEP> <SPC> ㅇ ...
# 1375427  ㅂ ㅗ <SEP> ㄷ ㅡ <SEP> ㄱ ㅔ <SEP> ㅇ ㅣ ㅁ <SEP> <SPC...
# 1375430  ㅇ ㅓ <SEP> <SPC> ㄹ ㅜ <SEP> ㅁ ㅣ <SEP> ㅋ ㅠ <SEP> ...
# 1375432  ㄱ ㅡ <SEP> ㄹ ㅣ <SEP> ㄱ ㅗ <SEP> <SPC> ㅇ ㅛ <SEP> ...
#
#                                                        표준어  연령대  \
# 6        ㅇ ㅏ <SEP> ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄴ ㅣ <SEP> ㄲ ㅏ <S...  50대
# 49       ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄴ ㅣ <SEP> ㄲ ㅏ <SEP> <SPC> ...  50대
# ...

# %%
jj_jamo_2.to_csv("/workspace/datas/jeju/jeju_dialect_jamo_integration_2.csv")

# %%
jj_jamo_3 = jj_jamo[(jj_jamo["토큰 길이"] >= 196) & (jj_jamo["토큰 길이"] < 285)]

jj_jamo_3
# Out:
#                                                         방언  \
# 2242     ㅇ ㅣ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㄱ ㅓ <SEP> <SPC> ㅂ ...
# 2315     ㄱ ㅓ ㅇ <SEP> ㅎ ㅐ <SEP> ㄴ ㅏ ㄴ <SEP> <SPC> ㄱ ㅛ <S...
# 2321     ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄱ ㅗ <SEP> <SPC> ㄴ ㅏ <SEP> ...
# 2448     ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅇ ㅏ <SEP> ...
# 2457     ㅇ ㅣ ㄹ <SEP> ㅇ ㅣ <SEP> <SPC> ㅂ ㅐ ㄱ <SEP> ㅇ ㅝ ㄴ ...
# ...                                                    ...
# 1529918  ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅇ ㅣ <SEP> ...
# 1532608  ㅇ ㅣ <SEP> ㄱ ㅓ <SEP> <SPC> ㅈ ㅣ ㄴ <SEP> ㅉ ㅏ <SEP...
# 1532614  ㅁ ㅏ ㄱ <SEP> <SPC> ㅁ ㅏ <SEP> ㅈ ㅣ <SEP> ㅁ ㅏ ㄱ <S...
# 1532622  ㄱ ㅡ <SEP> <SPC> ㅇ ㅕ <SEP> ㅈ ㅣ ㄱ <SEP> ㅇ ㅝ ㄴ <S...
# 1532654  ㅋ ㅓ <SEP> ㅍ ㅣ <SEP> <SPC> ㅁ ㅏ ㄴ <SEP> ㄷ ㅡ <SEP...
#
#                                                        표준어     연령대  \
# 2242     ㅇ ㅣ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㄱ ㅓ <SEP> <SPC> ㅂ ...     20대
# 2315     ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㄱ ㅛ <SEP> ...  60대 이상
# ...

# %%
jj_jamo_3[jj_jamo_3["셋"] == "train"]
# Out:
#                                                         방언  \
# 2242     ㅇ ㅣ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㄱ ㅓ <SEP> <SPC> ㅂ ...
# 2315     ㄱ ㅓ ㅇ <SEP> ㅎ ㅐ <SEP> ㄴ ㅏ ㄴ <SEP> <SPC> ㄱ ㅛ <S...
# 2321     ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㄱ ㅗ <SEP> <SPC> ㄴ ㅏ <SEP> ...
# 2448     ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅇ ㅏ <SEP> ...
# 2457     ㅇ ㅣ ㄹ <SEP> ㅇ ㅣ <SEP> <SPC> ㅂ ㅐ ㄱ <SEP> ㅇ ㅝ ㄴ ...
# ...                                                    ...
# 1372342  ㅂ ㅗ <SEP> ㅌ ㅗ ㅇ <SEP> <SPC> ㄱ ㅡ <SEP> ㄹ ㅐ <SEP...
# 1372387  ㄴ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㄱ ㅜ ㄱ <SEP> ㅈ ㅔ <SEP...
# 1372513  ㅇ ㅏ <SEP> ㄴ ㅣ <SEP> <SPC> ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP...
# 1372564  ㅇ ㅏ ㅁ <SEP> ㅌ ㅡ ㄴ <SEP> <SPC> ㄸ ㅏ ㄴ <SEP> <SPC...
# 1372666  ㅇ ㅏ <SEP> ㄴ ㅣ <SEP> <SPC> ㄱ ㅡ <SEP> ㄴ ㅣ <SEP> ...
#
#                                                        표준어     연령대  \
# 2242     ㅇ ㅣ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㄱ ㅓ <SEP> <SPC> ㅂ ...     20대
# 2315     ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㄱ ㅛ <SEP> ...  60대 이상
# ...

# %%
jj_jamo_3.to_csv("/workspace/datas/jeju/jeju_dialect_jamo_integration_3.csv")

# %%
jj_jamo_4 = jj_jamo[(jj_jamo["토큰 길이"] >= 285) & (jj_jamo["토큰 길이"] < 374)]

jj_jamo_4
# Out:
#                                                         방언  \
# 27721    ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅁ ㅝ <SEP> ...
# 27796    ㄱ ㅓ <SEP> ㄱ ㅣ <SEP> <SPC> ㄱ ㅏ <SEP> ㄴ ㅣ <SEP> ...
# 27797    ㄷ ㅏ <SEP> ㄱ ㅏ <SEP> ㅇ ㅗ <SEP> ㅁ ㅕ ㄴ <SEP> <SPC...
# 27812    x <SEP> x <SEP> ㄷ ㅏ <SEP> ㄱ ㅏ <SEP> <SPC> ㅇ ㅣ ...
# 55550    ㄴ ㅐ <SEP> <SPC> ㅅ ㅐ ㅇ <SEP> ㄱ ㅏ ㄱ <SEP> ㅇ ㅡ ㄴ ...
# ...                                                    ...
# 1480484  ㅈ ㅓ ㄴ <SEP> ㅎ ㅘ <SEP> ㄹ ㅗ <SEP> ㄷ ㅗ <SEP> <SPC...
# 1486423  ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㄴ ㅐ <SEP> ...
# 1525551  ㄴ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㄴ ㅓ <SEP> <SPC> ㄴ ㅓ ...
# 1525553  ㅇ ㅓ <SEP> <SPC> ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㄱ ㅏ <SEP> ...
# 1525630  ㄱ ㅣ <SEP> ㄴ ㅑ <SEP> <SPC> ㅇ ㅏ <SEP> ㄴ ㅣ <SEP> ...
#
#                                                        표준어  연령대  \
# 27721    ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅁ ㅝ <SEP> ...  20대
# 27796    ㄱ ㅓ <SEP> ㄱ ㅣ <SEP> <SPC> ㄱ ㅏ <SEP> ㄴ ㅣ <SEP> ...  20대
# ...

# %%
jj_jamo_4[jj_jamo_4["셋"] == "train"]
# Out:
#                                                         방언  \
# 27721    ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅁ ㅝ <SEP> ...
# 27796    ㄱ ㅓ <SEP> ㄱ ㅣ <SEP> <SPC> ㄱ ㅏ <SEP> ㄴ ㅣ <SEP> ...
# 27797    ㄷ ㅏ <SEP> ㄱ ㅏ <SEP> ㅇ ㅗ <SEP> ㅁ ㅕ ㄴ <SEP> <SPC...
# 27812    x <SEP> x <SEP> ㄷ ㅏ <SEP> ㄱ ㅏ <SEP> <SPC> ㅇ ㅣ ...
# 55550    ㄴ ㅐ <SEP> <SPC> ㅅ ㅐ ㅇ <SEP> ㄱ ㅏ ㄱ <SEP> ㅇ ㅡ ㄴ ...
# ...                                                    ...
# 1307409  ㅇ ㅏ ㄹ <SEP> ㅇ ㅏ <SEP> ㅂ ㅗ ㄴ <SEP> <SPC> ㄷ ㅏ <S...
# 1323257  ㄱ ㅓ ㅇ <SEP> ㅎ ㅏ <SEP> ㄱ ㅗ <SEP> . <SEP> <SPC> ...
# 1323282  ㅇ ㅓ <SEP> ㄹ ㅕ ㄴ <SEP> ㅎ ㅣ <SEP> <SPC> ㅇ ㅘ ㅇ <S...
# 1323301  ㅇ ㅓ <SEP> ㅋ ㅕ <SEP> . <SEP> <SPC> ㅊ ㅜ <SEP> ㅇ ...
# 1323373  ㄱ ㅡ <SEP> <SPC> ㅇ ㅜ <SEP> ㄹ ㅣ ㄴ <SEP> <SPC> ㅇ ...
#
#                                                        표준어     연령대  \
# 27721    ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅁ ㅝ <SEP> ...     20대
# 27796    ㄱ ㅓ <SEP> ㄱ ㅣ <SEP> <SPC> ㄱ ㅏ <SEP> ㄴ ㅣ <SEP> ...     20대
# ...

# %%
jj_jamo_4.to_csv("/workspace/datas/jeju/jeju_dialect_jamo_integration_4.csv")

# %%
jj_jamo_5 = jj_jamo[(jj_jamo["토큰 길이"] >= 374) & (jj_jamo["토큰 길이"] < 462)]

jj_jamo_5
# Out:
#                                                        방언  \
# 119333  ㅇ ㅓ <SEP> <SPC> n <SEP> a <SEP> m <SEP> e <SEP...
# 119337  ㅇ ㅓ <SEP> <SPC> ㅇ ㅓ <SEP> . <SEP> <SPC> ㄴ ㅓ <S...
# 119348  ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㄱ ㅏ <SEP> ㅈ ㅣ <SEP> ㄱ ㅗ <S...
# 119388  ㄸ ㅏ ㅇ <SEP> <SPC> ㄱ ㅏ <SEP> ㄹ ㅏ <SEP> . <SEP> ...
# 119425  ㅅ ㅏ ㄹ <SEP> ㅉ ㅏ ㄱ <SEP> <SPC> ㄱ ㅡ <SEP> ㄹ ㅓ ㄴ ...
# 119475  ㄱ ㅡ <SEP> ㄴ ㅑ ㅇ <SEP> <SPC> ㄴ ㅏ ㄴ <SEP> . <SEP...
# 119522  ㅇ ㅠ <SEP> ㅂ ㅏ ㄹ <SEP> ㅎ ㅏ <SEP> ㄴ ㅡ ㄴ <SEP> <S...
# 119562  ㅇ ㅣ <SEP> <SPC> ㄴ ㅏ ㅁ <SEP> ㅈ ㅏ <SEP> ㄱ ㅏ <SEP...
# 119760  ㄱ ㅡ <SEP> ㅊ ㅣ <SEP> . <SEP> <SPC> ㄱ ㅡ ㄴ <SEP> ...
# 119763  ㄱ ㅡ <SEP> ㅊ ㅣ <SEP> . <SEP> <SPC> ㄱ ㅡ <SEP> ㅊ ...
# 287627  ㅇ ㅓ <SEP> <SPC> ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㄱ ...
# 292488  ㄱ ㅡ <SEP> ㄱ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ㅈ ㅜ <SEP...
# 320168  ㄱ ㅔ ㄴ <SEP> ㄷ ㅣ <SEP> <SPC> ㄴ ㅏ <SEP> <SPC> ㅅ ...
# 320171  ㄱ ㅔ <SEP> ㄴ ㅏ ㄴ <SEP> <SPC> ㅇ ㅜ <SEP> ㄹ ㅣ <SEP...
# 320172  ㄱ ㅕ ㅇ <SEP> ㅎ ㅏ <SEP> ㄴ ㅏ ㄴ <SEP> <SPC> ㄱ ㅡ <S...
# ...

# %%
print(len(jj_jamo_5[jj_jamo_5["셋"] == "train"]))
# Out:
# 26

# %%
jj_jamo_5.to_csv("/workspace/datas/jeju/jeju_dialect_jamo_integration_5.csv")

# %%
jj_jamo_6 = jj_jamo[(jj_jamo["토큰 길이"] >= 462) & (jj_jamo["토큰 길이"] < 551)]

jj_jamo_6
# Out:
#                                                        방언  \
# 119331  ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> <SPC> ㄱ ㅏ <SEP> ㅈ ㅣ <SEP> ...
# 119426  ㅇ ㅙ <SEP> ㄴ ㅑ <SEP> ㅎ ㅏ <SEP> ㅁ ㅕ ㄴ <SEP> <SPC...
# 119476  ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㅇ ㅛ <SEP> ㅅ ㅐ <SEP...
# 333247  ㅇ ㅏ <SEP> ㄴ ㅣ <SEP> <SPC> ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP...
# 856990  ㅂ ㅣ ㅅ <SEP> ㄷ ㅐ <SEP> ㅇ ㅓ <SEP> ㄱ ㅡ <SEP> ㄴ ㅐ ...
# 857053  ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㄴ ㅏ <SEP> ㄱ ㅏ <SEP...
# 857061  ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㄷ ㅗ <SEP> <SPC> ㄱ ㅡ <SEP> ...
#
#                                                       표준어  연령대  \
# 119331  ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> <SPC> ㄱ ㅏ <SEP> ㅈ ㅣ <SEP> ...  20대
# 119426  ㅇ ㅙ <SEP> ㄴ ㅑ <SEP> ㅎ ㅏ <SEP> ㅁ ㅕ ㄴ <SEP> <SPC...  20대
# 119476  ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㅇ ㅛ <SEP> ㅅ ㅐ <SEP...  20대
# 333247  ㅇ ㅏ <SEP> ㄴ ㅣ <SEP> <SPC> ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP...  20대
# 856990  ㅂ ㅣ ㅅ <SEP> ㄷ ㅐ <SEP> ㅇ ㅓ <SEP> ㅅ ㅓ <SEP> <SPC...  50대
# 857053  ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㄴ ㅏ <SEP> ㄱ ㅏ <SEP...  50대
# ...

# %%
jj_jamo_6.to_csv("/workspace/datas/jeju/jeju_dialect_jamo_integration_6.csv")

# %%
jj_jamo_7 = jj_jamo[(jj_jamo["토큰 길이"] >= 551) & (jj_jamo["토큰 길이"] < 640)]

jj_jamo_7
# Out:
#                                                        방언  \
# 119413  ㅊ ㅣ ㄹ <SEP> ㅅ ㅣ ㅂ <SEP> ㅍ ㅏ ㄹ <SEP> . <SEP> <S...
#
#                                                       표준어  연령대  \
# 119413  ㅊ ㅣ ㄹ <SEP> ㅅ ㅣ ㅂ <SEP> ㅍ ㅏ ㄹ <SEP> . <SEP> <S...  20대
#
#                     출처 파일  길이      셋  토큰 길이
# 119413  DZES20000550.json  66  train  605.0

# %%
jj_jamo_7.to_csv("/workspace/datas/jeju/jeju_dialect_jamo_integration_7.csv")

# %%
jj_jamo_8 = jj_jamo[(jj_jamo["토큰 길이"] >= 640) & (jj_jamo["토큰 길이"] < 729)]

jj_jamo_8
# Out:
# Empty DataFrame
# Columns: [방언, 표준어, 연령대, 출처 파일, 길이, 셋, 토큰 길이]
# Index: []

# %%
jj_jamo_9 = jj_jamo[(jj_jamo["토큰 길이"] >= 729) & (jj_jamo["토큰 길이"] < 817)]

jj_jamo_9
# Out:
# Empty DataFrame
# Columns: [방언, 표준어, 연령대, 출처 파일, 길이, 셋, 토큰 길이]
# Index: []

# %%
jj_jamo_10 = jj_jamo[(jj_jamo["토큰 길이"] >= 817)]

jj_jamo_10
# Out:
#                                                        방언  \
# 119416  ㅇ ㅣ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㅅ ㅣ ㄱ <SEP> ㅇ ㅣ <S...
#
#                                                       표준어  연령대  \
# 119416  ㅇ ㅣ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㅅ ㅣ ㄱ <SEP> ㅇ ㅣ <S...  20대
#
#                     출처 파일  길이      셋  토큰 길이
# 119416  DZES20000550.json  88  train  905.0

# %%
jj_jamo_10.to_csv("/workspace/datas/jeju/jeju_dialect_jamo_integration_10.csv")

# %% [markdown]
# # 충청 방언

# %%
cc_jamo = pd.read_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration.csv", index_col=0)

cc_jamo
# Out:
#                                                        방언  \
# 0       ㅇ ㅕ ㅇ <SEP> ㅎ ㅘ <SEP> ㅂ ㅗ <SEP> ㄷ ㅏ <SEP> ㄴ ㅡ ...
# 1       ㅇ ㅔ <SEP> ~ <SEP> <SPC> ㅈ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> ...
# 2       ㄱ ㅡ <SEP> <SPC> c <SEP> o <SEP> m <SEP> p <SEP...
# 3       ㄱ ㅗ <SEP> ㅇ ㅟ <SEP> ㅎ ㅓ ㅁ <SEP> <SPC> ㄱ ㅡ <SEP...
# 4       ㅋ ㅗ <SEP> ㄹ ㅗ <SEP> ㄴ ㅏ <SEP> <SPC> ㄸ ㅐ <SEP> ...
# ...                                                   ...
# 227987  ㄴ ㅏ ㅁ <SEP> ㅇ ㅢ <SEP> <SPC> ㅇ ㅣ ㄴ <SEP> ㅈ ㅔ <S...
# 227988  ㄱ ㅡ <SEP> <SPC> ㅈ ㅏ ㅂ <SEP> ㅊ ㅗ <SEP> ㄱ ㅏ <SEP...
# 227993  ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㅁ ㅕ ㄴ <SEP> ㅅ ㅓ <SEP> <SPC...
# 227994  ㅇ ㅏ <SEP> ㅇ ㅠ <SEP> <SPC> ㅈ ㅓ <SEP> ㄱ ㅣ <SEP> ...
# 227995  ㄱ ㅡ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㅁ ㅏ ㄹ <SEP> ㅇ ㅣ <S...
#
#                                                       표준어  연령대  \
# 0       ㅇ ㅕ ㅇ <SEP> ㅎ ㅘ <SEP> ㅂ ㅗ <SEP> ㄷ ㅏ <SEP> ㄴ ㅡ ...  50대
# 1       ㅇ ㅔ <SEP> ~ <SEP> <SPC> ㅈ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> ...  20대
# 2       ㄱ ㅡ <SEP> <SPC> c <SEP> o <SEP> m <SEP> p <SEP...  20대
# ...

# %%
cc_jamo = cc_jamo.reset_index(drop=True)

# %%
seq_len_list = []
for sentence in cc_jamo["방언"].to_list():
    seq_len = len(sentence.split())
    
    seq_len_list.append(seq_len)

cc_jamo.loc[cc_jamo.index, "토큰 길이"] = seq_len_list

cc_jamo
# Out:
#                                                        방언  \
# 0       ㅇ ㅕ ㅇ <SEP> ㅎ ㅘ <SEP> ㅂ ㅗ <SEP> ㄷ ㅏ <SEP> ㄴ ㅡ ...
# 1       ㅇ ㅔ <SEP> ~ <SEP> <SPC> ㅈ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> ...
# 2       ㄱ ㅡ <SEP> <SPC> c <SEP> o <SEP> m <SEP> p <SEP...
# 3       ㄱ ㅗ <SEP> ㅇ ㅟ <SEP> ㅎ ㅓ ㅁ <SEP> <SPC> ㄱ ㅡ <SEP...
# 4       ㅋ ㅗ <SEP> ㄹ ㅗ <SEP> ㄴ ㅏ <SEP> <SPC> ㄸ ㅐ <SEP> ...
# ...                                                   ...
# 710983  ㄴ ㅏ ㅁ <SEP> ㅇ ㅢ <SEP> <SPC> ㅇ ㅣ ㄴ <SEP> ㅈ ㅔ <S...
# 710984  ㄱ ㅡ <SEP> <SPC> ㅈ ㅏ ㅂ <SEP> ㅊ ㅗ <SEP> ㄱ ㅏ <SEP...
# 710985  ㄱ ㅡ <SEP> ㄹ ㅓ <SEP> ㅁ ㅕ ㄴ <SEP> ㅅ ㅓ <SEP> <SPC...
# 710986  ㅇ ㅏ <SEP> ㅇ ㅠ <SEP> <SPC> ㅈ ㅓ <SEP> ㄱ ㅣ <SEP> ...
# 710987  ㄱ ㅡ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㅁ ㅏ ㄹ <SEP> ㅇ ㅣ <S...
#
#                                                       표준어  연령대  \
# 0       ㅇ ㅕ ㅇ <SEP> ㅎ ㅘ <SEP> ㅂ ㅗ <SEP> ㄷ ㅏ <SEP> ㄴ ㅡ ...  50대
# 1       ㅇ ㅔ <SEP> ~ <SEP> <SPC> ㅈ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> ...  20대
# 2       ㄱ ㅡ <SEP> <SPC> c <SEP> o <SEP> m <SEP> p <SEP...  20대
# ...

# %%
cc_jamo["토큰 길이"].mean()
# Out:
# 96.54796846078978

# %%
max(cc_jamo["토큰 길이"].to_list())
# Out:
# 415.0

# %%
min(cc_jamo["토큰 길이"].to_list())
# Out:
# 21.0

# %% [markdown]
# 구간은 10개. 구간 길이는 415-21=394
#
# 구간 한 개는 394 / 10 = 39
#
# - 376-415
# - 336-375
# - 296-335
# - 256-295
# - 216-255
# - 176-215
# - 136-175
# - 96-135
# - 56-95
# - 21-55

# %%
cc_jamo_1 = cc_jamo[cc_jamo["토큰 길이"] <= 55]

cc_jamo_1
# Out:
#                                                        방언  \
# 1       ㅇ ㅔ <SEP> ~ <SEP> <SPC> ㅈ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> ...
# 16      ㅁ ㅏ ㄱ <SEP> <SPC> ㅇ ㅘ ㅆ <SEP> ㅇ ㅓ <SEP> <SPC> ...
# 31      ㄱ ㅡ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㄱ ㅓ ㄹ <SEP> ㄹ ㅗ <S...
# 39      ㅇ ㅏ ㄴ <SEP> <SPC> ㄷ ㅚ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ...
# 42      ㄷ ㅜ <SEP> ㅂ ㅜ <SEP> <SPC> ㅁ ㅝ <SEP> <SPC> ㄱ ㅡ ...
# ...                                                   ...
# 710946  ㅊ ㅐ <SEP> ㅅ ㅗ <SEP> ㄹ ㅡ ㄹ <SEP> <SPC> ㅅ ㅣ ㅁ <S...
# 710948  ㅅ ㅣ ㅁ <SEP> ㅇ ㅓ ㅆ <SEP> ㄴ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> ...
# 710956  ㅇ ㅓ <SEP> ~ <SEP> <SPC> ㅉ ㅗ <SEP> ㄲ ㅗ ㅁ <SEP> ...
# 710960  ㅈ ㅓ <SEP> ㅎ ㅢ <SEP> <SPC> ㅈ ㅣ ㅂ <SEP> ㄷ ㅜ <SEP...
# 710965  ㄸ ㅗ <SEP> <SPC> ㅅ ㅣ <SEP> ㄱ ㅗ ㄹ <SEP> ㅇ ㅔ <SEP...
#
#                                                       표준어  연령대  \
# 1       ㅇ ㅔ <SEP> ~ <SEP> <SPC> ㅈ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> ...  20대
# 16      ㅁ ㅏ ㄱ <SEP> <SPC> ㅇ ㅘ ㅆ <SEP> ㅇ ㅓ <SEP> <SPC> ...  50대
# 31      ㄱ ㅡ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㄱ ㅓ ㄹ <SEP> ㄹ ㅗ <S...  20대
# ...

# %%
cc_jamo_1[cc_jamo_1["셋"] == "train"]
# Out:
#                                                        방언  \
# 1       ㅇ ㅔ <SEP> ~ <SEP> <SPC> ㅈ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> ...
# 16      ㅁ ㅏ ㄱ <SEP> <SPC> ㅇ ㅘ ㅆ <SEP> ㅇ ㅓ <SEP> <SPC> ...
# 31      ㄱ ㅡ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㄱ ㅓ ㄹ <SEP> ㄹ ㅗ <S...
# 39      ㅇ ㅏ ㄴ <SEP> <SPC> ㄷ ㅚ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ...
# 42      ㄷ ㅜ <SEP> ㅂ ㅜ <SEP> <SPC> ㅁ ㅝ <SEP> <SPC> ㄱ ㅡ ...
# ...                                                   ...
# 520946  ㅇ ㅓ <SEP> ~ <SEP> <SPC> ㄱ ㅡ <SEP> ㄹ ㅓ ㄴ <SEP> ...
# 520950  ㄴ ㅏ <SEP> ㄹ ㅏ ㅇ <SEP> <SPC> ㄱ ㅏ ㅌ <SEP> ㅇ ㅣ <S...
# 520954  ㄱ ㅡ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㄷ ㅔ <SEP> ㅅ ㅓ <SEP...
# 520961  ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㄱ ㅡ <SEP> ㄱ ㅓ <SEP...
# 520972  ㅎ ㅕ ㅇ <SEP> ㅂ ㅜ <SEP> <SPC> ㄸ ㅐ <SEP> ㅁ ㅜ ㄴ <S...
#
#                                                       표준어  연령대  \
# 1       ㅇ ㅔ <SEP> ~ <SEP> <SPC> ㅈ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> ...  20대
# 16      ㅁ ㅏ ㄱ <SEP> <SPC> ㅇ ㅘ ㅆ <SEP> ㅇ ㅓ <SEP> <SPC> ...  50대
# 31      ㄱ ㅡ <SEP> ㄹ ㅓ ㄴ <SEP> <SPC> ㄱ ㅓ ㄹ <SEP> ㄹ ㅗ <S...  20대
# ...

# %%
cc_jamo_1.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_1.csv")

# %%
cc_jamo_2 = cc_jamo[(cc_jamo["토큰 길이"] >= 56) & (cc_jamo["토큰 길이"] < 96)]

cc_jamo_2.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_2.csv")

cc_jamo_2[cc_jamo_2["셋"] == "train"]
# Out:
#                                                        방언  \
# 0       ㅇ ㅕ ㅇ <SEP> ㅎ ㅘ <SEP> ㅂ ㅗ <SEP> ㄷ ㅏ <SEP> ㄴ ㅡ ...
# 2       ㄱ ㅡ <SEP> <SPC> c <SEP> o <SEP> m <SEP> p <SEP...
# 4       ㅋ ㅗ <SEP> ㄹ ㅗ <SEP> ㄴ ㅏ <SEP> <SPC> ㄸ ㅐ <SEP> ...
# 6       ㅇ ㅛ <SEP> ㅂ ㅓ ㄴ <SEP> ㅇ ㅔ <SEP> <SPC> ㄱ ㅡ <SEP...
# 8       ㅁ ㅝ <SEP> <SPC> ㅅ ㅣ ㄹ <SEP> ㄱ ㅣ <SEP> ㅇ ㅔ <SEP...
# ...                                                   ...
# 520980  ㅉ ㅗ ㅁ <SEP> <SPC> ㅎ ㅘ <SEP> ㄹ ㅡ ㄹ <SEP> <SPC> ...
# 520982  ㅇ ㅑ <SEP> <SPC> ㅌ ㅏ <SEP> <SPC> ㄱ ㅡ <SEP> ㄹ ㅐ ...
# 520984  ㄱ ㅡ <SEP> ~ <SEP> <SPC> ㅇ ㅛ ㄱ <SEP> ㅅ ㅣ ㅁ <SEP...
# 520985  ㄱ ㅡ <SEP> ~ <SEP> <SPC> ㄴ ㅏ ㅈ <SEP> ㅇ ㅏ <SEP> ...
# 520986  ㅅ ㅏ <SEP> ㄹ ㅏ ㅁ <SEP> ㄷ ㅡ ㄹ <SEP> <SPC> ㅋ ㅟ ㄴ ...
#
#                                                       표준어     연령대  \
# 0       ㅇ ㅕ ㅇ <SEP> ㅎ ㅘ <SEP> ㅂ ㅗ <SEP> ㄷ ㅏ <SEP> ㄴ ㅡ ...     50대
# 2       ㄱ ㅡ <SEP> <SPC> c <SEP> o <SEP> m <SEP> p <SEP...     20대
# 4       ㅋ ㅗ <SEP> ㄹ ㅗ <SEP> ㄴ ㅏ <SEP> <SPC> ㄸ ㅐ <SEP> ...     40대
# ...

# %%
cc_jamo_3 = cc_jamo[(cc_jamo["토큰 길이"] >= 96) & (cc_jamo["토큰 길이"] < 136)]

cc_jamo_3.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_3.csv")

cc_jamo_3[cc_jamo_3["셋"] == "train"]
# Out:
#                                                        방언  \
# 5       n <SEP> a <SEP> m <SEP> e <SEP> ㅇ ㅣ <SEP> ㄴ ㅡ ...
# 7       ㅎ ㅐ <SEP> <SPC> ㄷ ㅏ ㄹ <SEP> ㄹ ㅏ <SEP> ㄱ ㅗ <SEP...
# 12      ㄴ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㅅ ㅓ ㅇ <SEP> ㄷ ㅏ ㅇ <S...
# 15      ㅇ ㅓ <SEP> <SPC> ㄱ ㅡ ㅇ <SEP> ㄲ ㅏ <SEP> <SPC> ㄱ ...
# 17      ㅇ ㅣ ㄴ <SEP> ㅈ ㅏ <SEP> <SPC> ㄱ ㅡ <SEP> <SPC> ㄱ ...
# ...                                                   ...
# 520976  ㅎ ㅏ ㄴ <SEP> <SPC> ㄷ ㅏ ㄹ <SEP> <SPC> ㄷ ㅗ ㅇ <SEP...
# 520978  ㅈ ㅣ ㅂ <SEP> ㅈ ㅣ ㅂ <SEP> ㅁ ㅏ <SEP> ㄷ ㅏ <SEP> <S...
# 520979  ㄴ ㅏ <SEP> ㄹ ㅏ ㅇ <SEP> <SPC> ㄸ ㅗ ㄱ <SEP> ㄱ ㅏ ㅌ ...
# 520981  ㄷ ㅏ <SEP> ㄹ ㅡ ㄴ <SEP> <SPC> ㅂ ㅏ ㅇ <SEP> ㅇ ㅏ ㄴ ...
# 520983  ㄱ ㅓ <SEP> ㄱ ㅣ <SEP> ㅅ ㅓ <SEP> <SPC> ㅂ ㅏ ㅂ <SEP...
#
#                                                       표준어     연령대  \
# 5       n <SEP> a <SEP> m <SEP> e <SEP> ㅇ ㅣ <SEP> ㄴ ㅡ ...     40대
# 7       ㅎ ㅐ <SEP> <SPC> ㄷ ㅏ ㄹ <SEP> ㄹ ㅏ <SEP> ㄱ ㅗ <SEP...  60대 이상
# 12      ㄴ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㅅ ㅓ ㅇ <SEP> ㄷ ㅏ ㅇ <S...  60대 이상
# ...

# %%
cc_jamo_4 = cc_jamo[(cc_jamo["토큰 길이"] >= 136) & (cc_jamo["토큰 길이"] < 176)]

cc_jamo_4.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_4.csv")

cc_jamo_4[cc_jamo_4["셋"] == "train"]
# Out:
#                                                        방언  \
# 11      ㄷ ㅐ <SEP> ㅍ ㅛ <SEP> ㄴ ㅏ <SEP> <SPC> ㅎ ㅚ <SEP> ...
# 14      ㅇ ㅓ ㄴ <SEP> ㄴ ㅣ <SEP> ㅎ ㅏ ㄴ <SEP> ㅌ ㅔ <SEP> <S...
# 20      ㄷ ㅓ <SEP> <SPC> ㅇ ㅕ <SEP> ㅇ ㅠ <SEP> ㄱ ㅏ <SEP> ...
# 24      ㄸ ㅗ <SEP> <SPC> ㅅ ㅐ <SEP> ㄹ ㅗ <SEP> ㅇ ㅜ ㄴ <SEP...
# 25      ㅇ ㅓ <SEP> ~ <SEP> <SPC> ㅁ ㅝ <SEP> ~ <SEP> <SPC...
# ...                                                   ...
# 520941  ㄴ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㄸ ㅗ <SEP> <SPC> ㄴ ㅜ ...
# 520944  ㄱ ㅓ <SEP> ㄱ ㅣ <SEP> <SPC> ㅇ ㅏ ㄵ <SEP> ㅇ ㅏ ㅆ <S...
# 520951  ㄴ ㅐ <SEP> <SPC> ㅊ ㅣ ㄴ <SEP> ㄱ ㅜ <SEP> ㄱ ㅏ <SEP...
# 520965  ㅇ ㅓ <SEP> ~ <SEP> <SPC> ㅇ ㅙ <SEP> ㄴ ㅑ <SEP> ㅁ ...
# 520969  ㅁ ㅐ ㄴ <SEP> ㄴ ㅏ ㄹ <SEP> <SPC> ㄴ ㅏ <SEP> ㅎ ㅏ ㄴ ...
#
#                                                       표준어     연령대  \
# 11      ㄷ ㅐ <SEP> ㅍ ㅛ <SEP> ㄴ ㅏ <SEP> <SPC> ㅎ ㅚ <SEP> ...     30대
# 14      ㅇ ㅓ ㄴ <SEP> ㄴ ㅣ <SEP> ㅎ ㅏ ㄴ <SEP> ㅌ ㅔ <SEP> <S...     50대
# 20      ㄷ ㅓ <SEP> <SPC> ㅇ ㅕ <SEP> ㅇ ㅠ <SEP> ㄱ ㅏ <SEP> ...     20대
# ...

# %%
cc_jamo_5 = cc_jamo[(cc_jamo["토큰 길이"] >= 176) & (cc_jamo["토큰 길이"] < 216)]

cc_jamo_5.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_5.csv")

cc_jamo_5[cc_jamo_5["셋"] == "train"]
# Out:
#                                                        방언  \
# 3       ㄱ ㅗ <SEP> ㅇ ㅟ <SEP> ㅎ ㅓ ㅁ <SEP> <SPC> ㄱ ㅡ <SEP...
# 30      ㄷ ㅏ <SEP> ㅎ ㅐ ㅇ <SEP> ㅎ ㅣ <SEP> <SPC> ㅇ ㅏ ㄴ <S...
# 32      <SPC> ㄱ ㅡ <SEP> ㄹ ㅐ ㅆ <SEP> ㅇ ㅓ ㅆ <SEP> ㄴ ㅡ ㄴ ...
# 96      ㅁ ㅜ ㄹ <SEP> ㅇ ㅓ <SEP> ㅂ ㅗ ㄴ <SEP> <SPC> ㅅ ㅏ <S...
# 111     ㅈ ㅓ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ㅉ ㅗ <SEP> ㄲ ㅡ ㅁ <S...
# ...                                                   ...
# 520770  ㄱ ㅡ <SEP> ㄸ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㄸ ㅏ ㄱ <SEP...
# 520786  ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㄴ ㅏ <SEP> ...
# 520822  ㅅ ㅗ ㄴ <SEP> <SPC> ㅁ ㅏ ㄱ <SEP> <SPC> ㄱ ㅡ <SEP> ...
# 520864  ㅇ ㅣ <SEP> ㅈ ㅔ <SEP> <SPC> ㅇ ㅛ <SEP> ㅈ ㅡ ㅁ <SEP...
# 520987  ㄱ ㅡ <SEP> ㄴ ㅏ <SEP> ㅁ ㅏ <SEP> <SPC> ㅂ ㅏ ㄹ <SEP...
#
#                                                       표준어  연령대  \
# 3       ㄱ ㅗ <SEP> ㅇ ㅟ <SEP> ㅎ ㅓ ㅁ <SEP> <SPC> ㄱ ㅡ <SEP...  40대
# 30      ㄷ ㅏ <SEP> ㅎ ㅐ ㅇ <SEP> ㅎ ㅣ <SEP> <SPC> ㅇ ㅏ ㄴ <S...  10대
# 32      <SPC> ㄱ ㅡ <SEP> ㄹ ㅐ ㅆ <SEP> ㅇ ㅓ ㅆ <SEP> ㄴ ㅡ ㄴ ...  20대
# ...

# %%
cc_jamo_6 = cc_jamo[(cc_jamo["토큰 길이"] >= 216) & (cc_jamo["토큰 길이"] < 256)]

cc_jamo_6.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_6.csv")

cc_jamo_6[cc_jamo_6["셋"] == "train"]
# Out:
#                                                        방언  \
# 64      ㅁ ㅏ ㄴ <SEP> ㅇ ㅑ ㄱ <SEP> ㅇ ㅔ <SEP> <SPC> ㅇ ㅛ <S...
# 108     ㅇ ㅣ <SEP> ㄷ ㅏ ㄴ <SEP> <SPC> ㄱ ㅛ <SEP> ㅎ ㅚ <SEP...
# 1033    ㅇ ㅓ <SEP> ~ <SEP> <SPC> ㄱ ㅡ <SEP> ~ <SEP> <SPC...
# 1055    ㅇ ㅛ <SEP> ㅈ ㅡ ㅁ <SEP> ㅇ ㅡ ㄴ <SEP> <SPC> ㅉ ㅗ ㅁ ...
# 1206    ㅇ ㅛ <SEP> ㅈ ㅡ ㅁ <SEP> ㅇ ㅔ <SEP> ㄴ ㅡ ㄴ <SEP> <S...
# ...                                                   ...
# 519903  ㅁ ㅏ ㄱ <SEP> <SPC> ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ...
# 519955  ㅇ ㅕ ㄴ <SEP> ㅈ ㅐ <SEP> ㅎ ㅏ ㄹ <SEP> <SPC> ㄸ ㅐ <S...
# 520269  ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅊ ㅣ ㄴ <SEP...
# 520380  ㅈ ㅔ <SEP> ㄱ ㅏ <SEP> <SPC> ㅊ ㅏ <SEP> ㅁ ㅏ <SEP> ...
# 520800  ㄱ ㅡ ㅇ <SEP> ㄲ ㅏ <SEP> ㄴ ㅡ ㄴ <SEP> <SPC> ㅂ ㅣ <S...
#
#                                                       표준어     연령대  \
# 64      ㅁ ㅏ ㄴ <SEP> ㅇ ㅑ ㄱ <SEP> ㅇ ㅔ <SEP> <SPC> ㅇ ㅛ <S...     30대
# 108     ㅇ ㅣ <SEP> ㄷ ㅏ ㄴ <SEP> <SPC> ㄱ ㅛ <SEP> ㅎ ㅚ <SEP...  60대 이상
# 1033    ㅇ ㅓ <SEP> ~ <SEP> <SPC> ㄱ ㅡ <SEP> ~ <SEP> <SPC...  60대 이상
# ...

# %%
cc_jamo_7 = cc_jamo[(cc_jamo["토큰 길이"] >= 256) & (cc_jamo["토큰 길이"] < 296)]

cc_jamo_7.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_7.csv")

cc_jamo_7[cc_jamo_7["셋"] == "train"]
# Out:
#                                                        방언  \
# 4643    ㄴ ㅐ ㅆ <SEP> ㅇ ㅓ <SEP> <SPC> ㄱ ㅏ <SEP> ㅁ ㅏ ㄴ <S...
# 7685    ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅇ ㅣ <SEP> ...
# 12408   ㄱ ㅗ <SEP> ㅇ ㅑ ㅇ <SEP> ㅇ ㅣ <SEP> ㄷ ㅗ <SEP> <SPC...
# 13617   ㅁ ㅝ <SEP> ~ <SEP> <SPC> ㄱ ㅡ <SEP> <SPC> ㅈ ㅓ ㅇ ...
# 14719   ㅁ ㅏ ㄱ <SEP> <SPC> ㄱ ㅖ <SEP> ㅅ ㅗ ㄱ <SEP> <SPC> ...
# ...                                                   ...
# 477163  ㄱ ㅡ ㅇ <SEP> ㄲ ㅏ <SEP> <SPC> ㄴ ㅏ <SEP> <SPC> ㄸ ...
# 490428  ㄱ ㅡ <SEP> ㄴ ㅣ <SEP> ㄲ ㅏ <SEP> <SPC> ㅇ ㅣ <SEP> ...
# 493518  ㅇ ㅏ <SEP> ~ <SEP> <SPC> ㄱ ㅡ <SEP> ㄴ ㅑ ㅇ <SEP> ...
# 504040  ㅇ ㅠ <SEP> ㅈ ㅓ ㄴ <SEP> ㅈ ㅏ <SEP> <SPC> ㄱ ㅓ ㅁ <S...
# 520787  ㅇ ㅓ <SEP> ~ <SEP> <SPC> ㄱ ㅡ <SEP> ㄹ ㅓ ㅎ <SEP> ...
#
#                                                       표준어     연령대  \
# 4643    ㄴ ㅐ ㅆ <SEP> ㅇ ㅓ <SEP> <SPC> ㄱ ㅏ <SEP> ㅁ ㅏ ㄴ <S...  60대 이상
# 7685    ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅇ ㅣ <SEP> ...     20대
# 12408   ㄱ ㅗ <SEP> ㅇ ㅑ ㅇ <SEP> ㅇ ㅣ <SEP> ㄷ ㅗ <SEP> <SPC...     10대
# ...

# %%
cc_jamo_8 = cc_jamo[(cc_jamo["토큰 길이"] >= 296) & (cc_jamo["토큰 길이"] < 336)]

cc_jamo_8.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_8.csv")

print(len(cc_jamo_8[cc_jamo_8["셋"] == "train"]))
# Out:
# 13

# %%
cc_jamo_9 = cc_jamo[(cc_jamo["토큰 길이"] >= 336) & (cc_jamo["토큰 길이"] < 376)]

cc_jamo_9.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_9.csv")

print(len(cc_jamo_9[cc_jamo_9["셋"] == "train"]))
# Out:
# 5

# %%
cc_jamo_10 = cc_jamo[(cc_jamo["토큰 길이"] >= 376) & (cc_jamo["토큰 길이"] < 416)]

cc_jamo_10.to_csv("/workspace/datas/chungcheong/chungcheong_dialect_jamo_integration_10.csv")

print(len(cc_jamo_10[cc_jamo_10["셋"] == "train"]))
# Out:
# 4

# %% [markdown]
# # 강원 방언

# %%
gw_jamo = pd.read_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration.csv", index_col=0)

gw_jamo
# Out:
#                                                        방언  \
# 6       ㅂ ㅏ <SEP> ㄷ ㅏ <SEP> ㅇ ㅢ <SEP> <SPC> ㅁ ㅜ <SEP> ...
# 10      ㅇ ㅖ ㅅ <SEP> ㄴ ㅏ ㄹ <SEP> ㅇ ㅔ <SEP> <SPC> ㅂ ㅏ <S...
# 13      ㄱ ㅜ <SEP> ㅅ ㅣ ㅂ <SEP> <SPC> ㅁ ㅕ ㅊ <SEP> <SPC> ...
# 14      ㄱ ㅡ <SEP> ㄸ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㅇ ㅔ ㅁ <SEP...
# 15      ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅇ ㅔ ㅁ <SEP...
# ...                                                   ...
# 276791  ㅇ ㅣ ㄴ <SEP> ㅈ ㅔ <SEP> <SPC> ㄱ ㅚ <SEP> ㄱ ㅣ <SEP...
# 276792  ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㅈ ㅣ ㄹ <SEP> ㅇ ㅣ <S...
# 276794  ㅇ ㅓ <SEP> ㄹ ㅕ ㅆ <SEP> ㅇ ㅡ ㄹ <SEP> <SPC> ㄸ ㅐ <S...
# 276796  ㅁ ㅓ ㄱ <SEP> ㅇ ㅓ ㅆ <SEP> ㅇ ㅓ ㅆ <SEP> ㄷ ㅓ ㄴ <SEP...
# 276797  ㄴ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㅇ ㅣ ㄹ <SEP> ㅇ ㅡ ㄹ <S...
#
#                                                       표준어     연령대  \
# 6       ㅂ ㅏ <SEP> ㄷ ㅏ <SEP> ㅇ ㅢ <SEP> <SPC> ㅁ ㅜ <SEP> ...  60대 이상
# 10      ㅇ ㅖ ㅅ <SEP> ㄴ ㅏ ㄹ <SEP> ㅇ ㅔ <SEP> <SPC> ㅂ ㅏ <S...  60대 이상
# 13      ㄱ ㅜ <SEP> ㅅ ㅣ ㅂ <SEP> <SPC> ㅁ ㅕ ㅊ <SEP> <SPC> ...  60대 이상
# ...

# %%
gw_jamo = gw_jamo.reset_index(drop=True)

seq_len_list = []
for sentence in gw_jamo["방언"].to_list():
    seq_len = len(sentence.split())
    
    seq_len_list.append(seq_len)

gw_jamo.loc[gw_jamo.index, "토큰 길이"] = seq_len_list

gw_jamo
# Out:
#                                                         방언  \
# 0        ㅂ ㅏ <SEP> ㄷ ㅏ <SEP> ㅇ ㅢ <SEP> <SPC> ㅁ ㅜ <SEP> ...
# 1        ㅇ ㅖ ㅅ <SEP> ㄴ ㅏ ㄹ <SEP> ㅇ ㅔ <SEP> <SPC> ㅂ ㅏ <S...
# 2        ㄱ ㅜ <SEP> ㅅ ㅣ ㅂ <SEP> <SPC> ㅁ ㅕ ㅊ <SEP> <SPC> ...
# 3        ㄱ ㅡ <SEP> ㄸ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㅇ ㅔ ㅁ <SEP...
# 4        ㄱ ㅡ <SEP> ㄹ ㅐ <SEP> ㅅ ㅓ <SEP> <SPC> ㅇ ㅔ ㅁ <SEP...
# ...                                                    ...
# 1024226  ㅇ ㅣ ㄴ <SEP> ㅈ ㅔ <SEP> <SPC> ㄱ ㅚ <SEP> ㄱ ㅣ <SEP...
# 1024227  ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㅈ ㅣ ㄹ <SEP> ㅇ ㅣ <S...
# 1024228  ㅇ ㅓ <SEP> ㄹ ㅕ ㅆ <SEP> ㅇ ㅡ ㄹ <SEP> <SPC> ㄸ ㅐ <S...
# 1024229  ㅁ ㅓ ㄱ <SEP> ㅇ ㅓ ㅆ <SEP> ㅇ ㅓ ㅆ <SEP> ㄷ ㅓ ㄴ <SEP...
# 1024230  ㄴ ㅐ <SEP> ㄱ ㅏ <SEP> <SPC> ㅇ ㅣ ㄹ <SEP> ㅇ ㅡ ㄹ <S...
#
#                                                        표준어     연령대  \
# 0        ㅂ ㅏ <SEP> ㄷ ㅏ <SEP> ㅇ ㅢ <SEP> <SPC> ㅁ ㅜ <SEP> ...  60대 이상
# 1        ㅇ ㅖ ㅅ <SEP> ㄴ ㅏ ㄹ <SEP> ㅇ ㅔ <SEP> <SPC> ㅂ ㅏ <S...  60대 이상
# ...

# %%
gw_jamo["토큰 길이"].median()
# Out:
# 68.0

# %%
print(max(gw_jamo["토큰 길이"].to_list()))
print(min(gw_jamo["토큰 길이"].to_list()))
# Out:
# 535.0
# 19.0

# %% [markdown]
# 구간은 10개. 구간 길이는 535-19=516
#
# 구간 한 개는 516 / 10 = 51
#
# - 484-535
# - 432-483
# - 380-431
# - 328-379
# - 276-327
# - 224-275
# - 172-223
# - 120-171
# - 68-119
# - 19-67

# %%
gw_jamo_1 = gw_jamo[(gw_jamo["토큰 길이"] >= 19) & (gw_jamo["토큰 길이"] < 68)]

gw_jamo_1.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_1.csv")

print(len(gw_jamo_1[gw_jamo_1["셋"] == "train"]))
# Out:
# 427991

# %%
gw_jamo_2 = gw_jamo[(gw_jamo["토큰 길이"] >= 68) & (gw_jamo["토큰 길이"] < 120)]

gw_jamo_2.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_2.csv")

print(len(gw_jamo_2[gw_jamo_2["셋"] == "train"]))
# Out:
# 366962

# %%
gw_jamo_3 = gw_jamo[(gw_jamo["토큰 길이"] >= 120) & (gw_jamo["토큰 길이"] < 172)]

gw_jamo_3.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_3.csv")

print(len(gw_jamo_3[gw_jamo_3["셋"] == "train"]))
# Out:
# 42762

# %%
gw_jamo_4 = gw_jamo[(gw_jamo["토큰 길이"] >= 172) & (gw_jamo["토큰 길이"] < 224)]

gw_jamo_4.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_4.csv")

print(len(gw_jamo_4[gw_jamo_4["셋"] == "train"]))
# Out:
# 3480

# %%
gw_jamo_5 = gw_jamo[(gw_jamo["토큰 길이"] >= 224) & (gw_jamo["토큰 길이"] < 276)]

gw_jamo_5.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_5.csv")

print(len(gw_jamo_5[gw_jamo_5["셋"] == "train"]))
# Out:
# 277

# %%
gw_jamo_6 = gw_jamo[(gw_jamo["토큰 길이"] >= 276) & (gw_jamo["토큰 길이"] < 328)]

gw_jamo_6.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_6.csv")

print(len(gw_jamo_6[gw_jamo_6["셋"] == "train"]))
# Out:
# 40

# %%
gw_jamo_7 = gw_jamo[(gw_jamo["토큰 길이"] >= 328) & (gw_jamo["토큰 길이"] < 380)]

gw_jamo_7.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_7.csv")

print(len(gw_jamo_7[gw_jamo_7["셋"] == "train"]))
# Out:
# 14

# %%
gw_jamo_8 = gw_jamo[(gw_jamo["토큰 길이"] >= 380) & (gw_jamo["토큰 길이"] < 432)]

gw_jamo_8.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_8.csv")

print(len(gw_jamo_8[gw_jamo_8["셋"] == "train"]))
# Out:
# 11

# %%
gw_jamo_9 = gw_jamo[(gw_jamo["토큰 길이"] >= 432) & (gw_jamo["토큰 길이"] < 484)]

gw_jamo_9.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_9.csv")

print(len(gw_jamo_9[gw_jamo_9["셋"] == "train"]))
# Out:
# 0

# %%
gw_jamo_10 = gw_jamo[(gw_jamo["토큰 길이"] >= 484) & (gw_jamo["토큰 길이"] < 536)]

gw_jamo_10.to_csv("/workspace/datas/gangwon/gangwon_dialect_jamo_integration_10.csv")

print(len(gw_jamo_10[gw_jamo_10["셋"] == "train"]))
# Out:
# 3

# %% [markdown]
# # 경상 방언

# %%
gs_jamo = pd.read_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration.csv", index_col=0)

gs_jamo
# Out:
#                                                        방언  \
# 0       ㅇ ㅏ <SEP> ~ <SEP> <SPC> ㅇ ㅣ <SEP> <SPC> ㄴ ㅗ <S...
# 1       ㄸ ㅏ ㅇ <SEP> ㅇ ㅣ <SEP> ㄴ ㅏ <SEP> <SPC> ㅇ ㅣ <SEP...
# 2       ㅇ ㅓ <SEP> ㅉ ㅐ ㅆ <SEP> ㄱ ㅓ ㄴ <SEP> <SPC> ㅇ ㅏ <S...
# 3       ㅅ ㅐ ㅇ <SEP> ㅎ ㅘ ㄹ <SEP> <SPC> ㅂ ㅗ <SEP> ㅁ ㅕ ㄴ ...
# 4       ㄱ ㅡ <SEP> ㄴ ㅑ ㅇ <SEP> <SPC> ㅂ ㅏ <SEP> ㄹ ㅡ <SEP...
# ...                                                   ...
# 229489  ㅈ ㅔ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ㅂ ㅕ ㄹ <SEP> ㄹ ㅗ <S...
# 229490  ㅈ ㅔ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ㅂ ㅕ ㄹ <SEP> ㄹ ㅗ <S...
# 229491  ㄱ ㅡ <SEP> ~ <SEP> <SPC> ㅈ ㅏ <SEP> ㅈ ㅓ ㄴ <SEP> ...
# 229493  ㄷ ㅟ <SEP> ㅇ ㅔ <SEP> <SPC> ㄴ ㅐ <SEP> ㄱ ㅏ <SEP> ...
# 229496  ㄱ ㅡ <SEP> ㄱ ㅓ <SEP> <SPC> ㅌ ㅏ <SEP> ㄱ ㅏ <SEP> ...
#
#                                                       표준어  연령대  \
# 0       ㅇ ㅏ <SEP> ~ <SEP> <SPC> ㅇ ㅣ <SEP> <SPC> ㄴ ㅗ <S...  20대
# 1       ㄸ ㅏ ㅇ <SEP> ㅇ ㅣ <SEP> ㄴ ㅏ <SEP> <SPC> ㅇ ㅣ <SEP...  50대
# 2       ㅇ ㅓ <SEP> ㅉ ㅐ ㅆ <SEP> ㄱ ㅓ ㄴ <SEP> <SPC> ㅇ ㅏ <S...  50대
# ...

# %%
gs_jamo = gs_jamo.reset_index(drop=True)

seq_len_list = []
for sentence in gs_jamo["방언"].to_list():
    seq_len = len(sentence.split())
    
    seq_len_list.append(seq_len)

gs_jamo.loc[gs_jamo.index, "토큰 길이"] = seq_len_list

gs_jamo
# Out:
#                                                        방언  \
# 0       ㅇ ㅏ <SEP> ~ <SEP> <SPC> ㅇ ㅣ <SEP> <SPC> ㄴ ㅗ <S...
# 1       ㄸ ㅏ ㅇ <SEP> ㅇ ㅣ <SEP> ㄴ ㅏ <SEP> <SPC> ㅇ ㅣ <SEP...
# 2       ㅇ ㅓ <SEP> ㅉ ㅐ ㅆ <SEP> ㄱ ㅓ ㄴ <SEP> <SPC> ㅇ ㅏ <S...
# 3       ㅅ ㅐ ㅇ <SEP> ㅎ ㅘ ㄹ <SEP> <SPC> ㅂ ㅗ <SEP> ㅁ ㅕ ㄴ ...
# 4       ㄱ ㅡ <SEP> ㄴ ㅑ ㅇ <SEP> <SPC> ㅂ ㅏ <SEP> ㄹ ㅡ <SEP...
# ...                                                   ...
# 789808  ㅈ ㅔ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ㅂ ㅕ ㄹ <SEP> ㄹ ㅗ <S...
# 789809  ㅈ ㅔ <SEP> ㅇ ㅣ ㄹ <SEP> <SPC> ㅂ ㅕ ㄹ <SEP> ㄹ ㅗ <S...
# 789810  ㄱ ㅡ <SEP> ~ <SEP> <SPC> ㅈ ㅏ <SEP> ㅈ ㅓ ㄴ <SEP> ...
# 789811  ㄷ ㅟ <SEP> ㅇ ㅔ <SEP> <SPC> ㄴ ㅐ <SEP> ㄱ ㅏ <SEP> ...
# 789812  ㄱ ㅡ <SEP> ㄱ ㅓ <SEP> <SPC> ㅌ ㅏ <SEP> ㄱ ㅏ <SEP> ...
#
#                                                       표준어  연령대  \
# 0       ㅇ ㅏ <SEP> ~ <SEP> <SPC> ㅇ ㅣ <SEP> <SPC> ㄴ ㅗ <S...  20대
# 1       ㄸ ㅏ ㅇ <SEP> ㅇ ㅣ <SEP> ㄴ ㅏ <SEP> <SPC> ㅇ ㅣ <SEP...  50대
# 2       ㅇ ㅓ <SEP> ㅉ ㅐ ㅆ <SEP> ㄱ ㅓ ㄴ <SEP> <SPC> ㅇ ㅏ <S...  50대
# ...

# %%
print(max(gs_jamo["토큰 길이"].to_list()))
print(min(gs_jamo["토큰 길이"].to_list()))
# Out:
# 600.0
# 19.0

# %% [markdown]
# 구간은 10개. 구간 길이는 600-19=581
#
# 구간 한 개는 581 / 10 = 58
#
# - 542-600
# - 483-541
# - 424-482
# - 365-423
# - 306-364
# - 247-305
# - 188-246
# - 129-187
# - 70-128
# - 19-69

# %%
gs_jamo_1 = gs_jamo[gs_jamo["토큰 길이"] <= 69]

gs_jamo_1.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_1.csv")

print(len(gs_jamo_1[gs_jamo_1["셋"] == "train"]))
# Out:
# 187769

# %%
gs_jamo_2 = gs_jamo[(gs_jamo["토큰 길이"] >= 70) & (gs_jamo["토큰 길이"] < 129)]

gs_jamo_2.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_2.csv")

print(len(gs_jamo_2[gs_jamo_2["셋"] == "train"]))
# Out:
# 336865

# %%
gs_jamo_3 = gs_jamo[(gs_jamo["토큰 길이"] >= 129) & (gs_jamo["토큰 길이"] < 188)]

gs_jamo_3.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_3.csv")

print(len(gs_jamo_3[gs_jamo_3["셋"] == "train"]))
# Out:
# 77072

# %%
gs_jamo_4 = gs_jamo[(gs_jamo["토큰 길이"] >= 188) & (gs_jamo["토큰 길이"] < 247)]

gs_jamo_4.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_4.csv")

print(len(gs_jamo_4[gs_jamo_4["셋"] == "train"]))
# Out:
# 8020

# %%
gs_jamo_5 = gs_jamo[(gs_jamo["토큰 길이"] >= 247) & (gs_jamo["토큰 길이"] < 306)]

gs_jamo_5.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_5.csv")

print(len(gs_jamo_5[gs_jamo_5["셋"] == "train"]))
# Out:
# 876

# %%
gs_jamo_6 = gs_jamo[(gs_jamo["토큰 길이"] >= 306) & (gs_jamo["토큰 길이"] < 365)]

gs_jamo_6.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_6.csv")

print(len(gs_jamo_6[gs_jamo_6["셋"] == "train"]))
# Out:
# 141

# %%
gs_jamo_7 = gs_jamo[(gs_jamo["토큰 길이"] >= 365) & (gs_jamo["토큰 길이"] < 424)]

gs_jamo_7.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_7.csv")

print(len(gs_jamo_7[gs_jamo_7["셋"] == "train"]))
# Out:
# 38

# %%
gs_jamo_8 = gs_jamo[(gs_jamo["토큰 길이"] >= 424) & (gs_jamo["토큰 길이"] < 483)]

gs_jamo_8.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_8.csv")

print(len(gs_jamo_8[gs_jamo_8["셋"] == "train"]))
# Out:
# 6

# %%
gs_jamo_9 = gs_jamo[(gs_jamo["토큰 길이"] >= 483) & (gs_jamo["토큰 길이"] < 542)]

gs_jamo_9.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_9.csv")

print(len(gs_jamo_9[gs_jamo_9["셋"] == "train"]))
# Out:
# 1

# %%
gs_jamo_10 = gs_jamo[(gs_jamo["토큰 길이"] >= 542) & (gs_jamo["토큰 길이"] < 601)]

gs_jamo_10.to_csv("/workspace/datas/gyeongsang/gyeongsang_dialect_jamo_integration_10.csv")

print(len(gs_jamo_10[gs_jamo_10["셋"] == "train"]))
# Out:
# 2

# %% [markdown]
# # 전라 방언

# %%
jl_jamo = pd.read_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration.csv", index_col=0)

jl_jamo
# Out:
#                                                        방언  \
# 0       ㅁ ㅏ ㄱ <SEP> ㅅ ㅏ ㅇ <SEP> <SPC> ㅇ ㅘ ㄴ <SEP> ㅈ ㅓ ...
# 1       ㅈ ㅗ ㅎ <SEP> ㅇ ㅡ ㄴ <SEP> <SPC> ㅊ ㅜ <SEP> ㅇ ㅓ ㄱ ...
# 2       ㅉ ㅗ ㅁ <SEP> <SPC> ㅂ ㅗ <SEP> ㅁ ㅕ ㄴ <SEP> <SPC> ...
# 3       ㄱ ㅏ <SEP> ㅅ ㅣ <SEP> ㄴ ㅏ <SEP> ㄷ ㅡ ㄹ <SEP> <SPC...
# 4       ㄱ ㅓ <SEP> ㄱ ㅣ <SEP> ㅅ ㅓ <SEP> <SPC> ㅇ ㅓ <SEP> ...
# ...                                                   ...
# 275119  ㅇ ㅣ ㄹ <SEP> ㅂ ㅏ ㄴ <SEP> <SPC> ㅅ ㅏ <SEP> ㄹ ㅏ ㅁ ...
# 275120  ㄷ ㅓ <SEP> <SPC> ㄴ ㅏ <SEP> ㅇ ㅏ <SEP> ㄱ ㅏ <SEP> ...
# 275123  ㅇ ㅓ <SEP> <SPC> ㅌ ㅐ ㄱ <SEP> ㅅ ㅣ <SEP> ㄱ ㅏ <SEP...
# 275133  ㅇ ㅣ <SEP> <SPC> ㅊ ㅓ ㄴ <SEP> <SPC> ㅇ ㅣ <SEP> <S...
# 275134  ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㅂ ㅏ ㄹ <SEP> ㅍ ㅛ <S...
#
#                                                       표준어  연령대  \
# 0       ㅁ ㅏ ㄱ <SEP> ㅅ ㅏ ㅇ <SEP> <SPC> ㅇ ㅘ ㄴ <SEP> ㅈ ㅓ ...  20대
# 1       ㅈ ㅗ ㅎ <SEP> ㅇ ㅡ ㄴ <SEP> <SPC> ㅊ ㅜ <SEP> ㅇ ㅓ ㄱ ...  30대
# 2       ㅈ ㅗ <SEP> ㄱ ㅡ ㅁ <SEP> <SPC> ㅂ ㅗ <SEP> ㅁ ㅕ ㄴ <S...  30대
# ...

# %%
jl_jamo = jl_jamo.reset_index(drop=True)

seq_len_list = []
for sentence in jl_jamo["방언"].to_list():
    seq_len = len(sentence.split())
    
    seq_len_list.append(seq_len)

jl_jamo.loc[jl_jamo.index, "토큰 길이"] = seq_len_list

jl_jamo
# Out:
#                                                        방언  \
# 0       ㅁ ㅏ ㄱ <SEP> ㅅ ㅏ ㅇ <SEP> <SPC> ㅇ ㅘ ㄴ <SEP> ㅈ ㅓ ...
# 1       ㅈ ㅗ ㅎ <SEP> ㅇ ㅡ ㄴ <SEP> <SPC> ㅊ ㅜ <SEP> ㅇ ㅓ ㄱ ...
# 2       ㅉ ㅗ ㅁ <SEP> <SPC> ㅂ ㅗ <SEP> ㅁ ㅕ ㄴ <SEP> <SPC> ...
# 3       ㄱ ㅏ <SEP> ㅅ ㅣ <SEP> ㄴ ㅏ <SEP> ㄷ ㅡ ㄹ <SEP> <SPC...
# 4       ㄱ ㅓ <SEP> ㄱ ㅣ <SEP> ㅅ ㅓ <SEP> <SPC> ㅇ ㅓ <SEP> ...
# ...                                                   ...
# 729326  ㅇ ㅣ ㄹ <SEP> ㅂ ㅏ ㄴ <SEP> <SPC> ㅅ ㅏ <SEP> ㄹ ㅏ ㅁ ...
# 729327  ㄷ ㅓ <SEP> <SPC> ㄴ ㅏ <SEP> ㅇ ㅏ <SEP> ㄱ ㅏ <SEP> ...
# 729328  ㅇ ㅓ <SEP> <SPC> ㅌ ㅐ ㄱ <SEP> ㅅ ㅣ <SEP> ㄱ ㅏ <SEP...
# 729329  ㅇ ㅣ <SEP> <SPC> ㅊ ㅓ ㄴ <SEP> <SPC> ㅇ ㅣ <SEP> <S...
# 729330  ㄱ ㅡ ㄴ <SEP> ㄷ ㅔ <SEP> <SPC> ㅂ ㅏ ㄹ <SEP> ㅍ ㅛ <S...
#
#                                                       표준어  연령대  \
# 0       ㅁ ㅏ ㄱ <SEP> ㅅ ㅏ ㅇ <SEP> <SPC> ㅇ ㅘ ㄴ <SEP> ㅈ ㅓ ...  20대
# 1       ㅈ ㅗ ㅎ <SEP> ㅇ ㅡ ㄴ <SEP> <SPC> ㅊ ㅜ <SEP> ㅇ ㅓ ㄱ ...  30대
# 2       ㅈ ㅗ <SEP> ㄱ ㅡ ㅁ <SEP> <SPC> ㅂ ㅗ <SEP> ㅁ ㅕ ㄴ <S...  30대
# ...

# %%
print(max(jl_jamo["토큰 길이"].to_list()))
print(min(jl_jamo["토큰 길이"].to_list()))
# Out:
# 362.0
# 19.0

# %% [markdown]
# 구간은 10개. 구간 길이는 362-19=343
#
# 구간 한 개는 343 / 10 = 34
#
# - 328-362
# - 293-327
# - 258-292
# - 223-257
# - 188-222
# - 153-187
# - 118-152
# - 83-117
# - 48-82
# - 19-47

# %%
jl_jamo_1 = jl_jamo[jl_jamo["토큰 길이"] <= 47]

jl_jamo_1.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_1.csv")

print(len(jl_jamo_1[jl_jamo_1["셋"] == "train"]))
# Out:
# 33974

# %%
jl_jamo_2 = jl_jamo[(jl_jamo["토큰 길이"] >= 48) & (jl_jamo["토큰 길이"] < 83)]

jl_jamo_2.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_2.csv")

print(len(jl_jamo_2[jl_jamo_2["셋"] == "train"]))
# Out:
# 208107

# %%
jl_jamo_3 = jl_jamo[(jl_jamo["토큰 길이"] >= 83) & (jl_jamo["토큰 길이"] < 118)]

jl_jamo_3.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_3.csv")

print(len(jl_jamo_3[jl_jamo_3["셋"] == "train"]))
# Out:
# 169804

# %%
jl_jamo_4 = jl_jamo[(jl_jamo["토큰 길이"] >= 118) & (jl_jamo["토큰 길이"] < 153)]

jl_jamo_4.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_4.csv")

print(len(jl_jamo_4[jl_jamo_4["셋"] == "train"]))
# Out:
# 73500

# %%
jl_jamo_5 = jl_jamo[(jl_jamo["토큰 길이"] >= 153) & (jl_jamo["토큰 길이"] < 188)]

jl_jamo_5.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_5.csv")

print(len(jl_jamo_5[jl_jamo_5["셋"] == "train"]))
# Out:
# 19139

# %%
jl_jamo_6 = jl_jamo[(jl_jamo["토큰 길이"] >= 188) & (jl_jamo["토큰 길이"] < 223)]

jl_jamo_6.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_6.csv")

print(len(jl_jamo_6[jl_jamo_6["셋"] == "train"]))
# Out:
# 3076

# %%
jl_jamo_7 = jl_jamo[(jl_jamo["토큰 길이"] >= 223) & (jl_jamo["토큰 길이"] < 258)]

jl_jamo_7.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_7.csv")

print(len(jl_jamo_7[jl_jamo_7["셋"] == "train"]))
# Out:
# 635

# %%
jl_jamo_8 = jl_jamo[(jl_jamo["토큰 길이"] >= 258) & (jl_jamo["토큰 길이"] < 293)]

jl_jamo_8.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_8.csv")

print(len(jl_jamo_8[jl_jamo_8["셋"] == "train"]))
# Out:
# 147

# %%
jl_jamo_9 = jl_jamo[(jl_jamo["토큰 길이"] >= 293) & (jl_jamo["토큰 길이"] < 328)]

jl_jamo_9.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_9.csv")

print(len(jl_jamo_9[jl_jamo_9["셋"] == "train"]))
# Out:
# 31

# %%
jl_jamo_10 = jl_jamo[(jl_jamo["토큰 길이"] >= 328) & (jl_jamo["토큰 길이"] < 363)]

jl_jamo_10.to_csv("/workspace/datas/jeonla/jeonla_dialect_jamo_integration_10.csv")

print(len(jl_jamo_10[jl_jamo_10["셋"] == "train"]))
# Out:
# 1
