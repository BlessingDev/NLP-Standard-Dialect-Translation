# %% [markdown]
# # 탐색적 데이터 분석 1
#
# * ai허브(aihub.or.kr)의 한국어 방언 발화 데이터셋을 살펴보고 전처리하는 과정
# * 1차 시도

# %%
import pandas as pd
import numpy as np
import pathlib
import random
import re

RANDOM_SEED = 19439
random.seed(RANDOM_SEED)

# %%
df = pd.read_csv("datas/output/jeonla_dialect_data.csv", index_col=0)
df.head()
# Out:
#                                                방언  \
# 0                            나는 다이어트에 대해서 말하고 싶어.
# 1                                               하
# 2             우리 집은 내가 봤을 때 살찔 수밖에 없는 구조를 가지고 있어.
# 3  다이어트를 해야 되는 사람은 애초에 야식을 많이 먹거나 아 어제도 야식을 먹었거든?
# 4                                      {laughing}
#
#                                               표준어              출처 파일
# 0                            나는 다이어트에 대해서 말하고 싶어.  DJDD20000001.json
# 1                                               하  DJDD20000001.json
# 2             우리 집은 내가 봤을 때 살찔 수밖에 없는 구조를 가지고 있어.  DJDD20000001.json
# 3  다이어트를 해야 되는 사람은 애초에 야식을 많이 먹거나 아 어제도 야식을 먹었거든?  DJDD20000001.json
# 4                                      {laughing}  DJDD20000001.json

# %%
len(df)
# Out:
# 1992101

# %% [markdown]
# 총 199만 2101개의 발화 데이터 쌍이 존재한다.
#
# 하지만 이 데이터에는 결함이 많음을 직접 파일을 열어 확인했다.
#
# 대표적으로 (())과 같이 텍스트 상에서는 의미가 없는 괄호가 들어간 데이터와 {laughing}으로 표현된 웃는 소리, (방언)/(표준어)로 같이 적은 문장이 있었다.
#
# 가장 큰 문제는 방언임에도 불구하고 이를 표준어에 그대로 적어놓은 경우이다. 이 경우는 프로그램으로 제거하기가 어렵다.
#
# 이를 정규식을 이용해 걸러낼 계획이다.

# %% [markdown]
# ## (()) 문자열 제거

# %%
df[df["방언"].str.contains("\(\(\)\)")|df["표준어"].str.contains("\(\(\)\)")]
# Out:
# Empty DataFrame
# Columns: [방언, 표준어, 출처 파일]
# Index: []

# %% [markdown]
# 표준어나 방언에 (())가 들어간 셋이 총 39016개 존재했다.
#
# 이들에 대해서는 간단히 (())를 제거하는 조치를 취하기로 하였다.

# %%
df["방언"] = df["방언"].str.replace(r"\(\(\)\)", '', regex=True)
df["표준어"] = df["표준어"].str.replace(r"\(\(\)\)", '', regex=True)

df[df["방언"].str.contains("\(\(\)\)")|df["표준어"].str.contains("\(\(\)\)")]
# Out:
# Empty DataFrame
# Columns: [방언, 표준어, 출처 파일]
# Index: []

# %% [markdown]
# 의도대로 (())가 포함된 데이터가 사라졌음을 확인할 수 있다.

# %% [markdown]
# ## 괄호 안에 문자열이 들어간 경우 처리
#
# ### ((문자열)) 처리

# %%
df[df["방언"].str.contains("\(.*\)")]
# Out:
#                                                         방언  \
# 152      그냥 적게 먹고 많이 ((xx하는)) 거고 그냥 그렇게 하면은 되는데 진짜 그런 광...
# 176                  약간 나는 운동(하믄서)/(하면서) 스트레스 풀라는 것도 있긴 한데
# 242          막 포만감도 막 엄청 많지 않으니까 그래서 ((xx xxx도)) 나름대로 높아지고
# 281                                     약간 이 생각도 많이 ((들어))
# 330      근데 확실히 다이어트 평생 ((해야xx)) 느낀 게 우리 엄마도 살이 찌더라고 {l...
# ...                                                    ...
# 1991447                     자제(할려고)/(하려고) 쫌 그렇게 신경을 쓰기는 해.
# 1991464                     ((무슨))의미가 있겠느냐 술이야 뭐 쫌 쭐이면서 점점
# 1991488                          요즘에 다 시국이 시국인지라(잉)/(응) 다
# 1991508                         혼자서 할 수 있는 ((운동)) 하고 집에 뭐~
# 1991765                   투자자금내에 -(맻)/(몇)개- 맻개만 딱 이렇게 우량주를
#
#                                                        표준어              출처 파일
# 152      그냥 적게 먹고 많이 ((xx하는)) 거고 그냥 그렇게 하면은 되는데 진짜 그런 광...  DJDD20000001.json
# 176                  약간 나는 운동(하믄서)/(하면서) 스트레스 풀라는 것도 있긴 한데  DJDD20000001.json
# 242          막 포만감도 막 엄청 많지 않으니까 그래서 ((xx xxx도)) 나름대로 높아지고  DJDD20000001.json
# 281                                     약간 이 생각도 많이 ((들어))  DJDD20000001.json
# 330      근데 확실히 다이어트 평생 ((해야xx)) 느낀 게 우리 엄마도 살이 찌더라고 {l...  DJDD20000001.json
# ...                                                    ...                ...
# 1991447                    자제(할려고)/(하려고) 조금 그렇게 신경을 쓰기는 해.  DJSX20004851.json
# 1991464                    ((무슨))의미가 있겠느냐 술이야 뭐 조금 쭐이면서 점점  DJSX20004851.json
# 1991488                          요즘에 다 시국이 시국인지라(잉)/(응) 다   DJSX20004851.json
# 1991508                         혼자서 할 수 있는 ((운동)) 하고 집에 뭐~  DJSX20004851.json
# 1991765                   투자자금내에 -(맻)/(몇)개- 몇개만 딱 이렇게 우량주를  DJSX20004852.json
#
# [17910 rows x 3 columns]

# %% [markdown]
# 눈으로 확인할 수 있는 경우가 두 가지 있다. (()) 안에 글자가 들어간 경우와 (방언)/(표준어) 쌍이 들어있는 경우이다.
#
# (()) 안에 글자가 들은 경우는 그 안의 글자를 빼내고, (방언)/(표준어) 쌍의 경우는 각 열에 맞추어 적절한 단어를 선택하여 대입할 계획이다.
#
# 다만 두 경우를 합쳐 만 7천 개 정도이니 전체 중 비율은 0.9%에 불과하다. 이는 다행스러운 일이다.

# %%
df[df["방언"].str.contains("\(\(.*\)\)")]
# Out:
#                                                         방언  \
# 152      그냥 적게 먹고 많이 ((xx하는)) 거고 그냥 그렇게 하면은 되는데 진짜 그런 광...
# 242          막 포만감도 막 엄청 많지 않으니까 그래서 ((xx xxx도)) 나름대로 높아지고
# 281                                     약간 이 생각도 많이 ((들어))
# 330      근데 확실히 다이어트 평생 ((해야xx)) 느낀 게 우리 엄마도 살이 찌더라고 {l...
# 342       나는 다이어트는 진짜 ((그래도)) 진짜 아니면 평생 그냥 좀 뚱뚱하고 통통하게 살던가
# ...                                                    ...
# 1990837         어~ 거의 시내 쪽에서 뭐~~ 콜로세움 뭐~ ((그케이케)) 뭐~ 거기 시내
# 1991374                            그게 의지 ((그래)) 의지일 수도 있는데
# 1991423                    자기 입장에서도 난감하고 물론 ((암도다)) 몇 달 후에
# 1991464                     ((무슨))의미가 있겠느냐 술이야 뭐 쫌 쭐이면서 점점
# 1991508                         혼자서 할 수 있는 ((운동)) 하고 집에 뭐~
#
#                                                        표준어              출처 파일
# 152      그냥 적게 먹고 많이 ((xx하는)) 거고 그냥 그렇게 하면은 되는데 진짜 그런 광...  DJDD20000001.json
# 242          막 포만감도 막 엄청 많지 않으니까 그래서 ((xx xxx도)) 나름대로 높아지고  DJDD20000001.json
# 281                                     약간 이 생각도 많이 ((들어))  DJDD20000001.json
# 330      근데 확실히 다이어트 평생 ((해야xx)) 느낀 게 우리 엄마도 살이 찌더라고 {l...  DJDD20000001.json
# 342       나는 다이어트는 진짜 ((그래도)) 진짜 아니면 평생 그냥 좀 뚱뚱하고 통통하게 살던가  DJDD20000001.json
# ...                                                    ...                ...
# 1990837         어~ 거의 시내 쪽에서 뭐~~ 콜로세움 뭐~ ((그케이케)) 뭐~ 거기 시내  DJSX20004850.json
# 1991374                            그게 의지 ((그래)) 의지일 수도 있는데  DJSX20004851.json
# 1991423                    자기 입장에서도 난감하고 물론 ((암도다)) 몇 달 후에  DJSX20004851.json
# 1991464                    ((무슨))의미가 있겠느냐 술이야 뭐 조금 쭐이면서 점점  DJSX20004851.json
# 1991508                         혼자서 할 수 있는 ((운동)) 하고 집에 뭐~  DJSX20004851.json
#
# [12452 rows x 3 columns]

# %%
df["방언"].str.extract("\(\((.*)\)\)", expand=False).dropna()
# Out:
# 152           xx하는
# 242        xx xxx도
# 281             들어
# 330           해야xx
# 342            그래도
#             ...
# 1990837       그케이케
# 1991374         그래
# 1991423        암도다
# 1991464         무슨
# 1991508         운동
# Name: 방언, Length: 12452, dtype: object

# %%
phrase_words = df["방언"].str.extract(r"\(\((.*)\)\)", expand=False).dropna()
df.loc[phrase_words.index, "방언"]
# Out:
# 152        그냥 적게 먹고 많이 ((xx하는)) 거고 그냥 그렇게 하면은 되는데 진짜 그런 광...
# 242            막 포만감도 막 엄청 많지 않으니까 그래서 ((xx xxx도)) 나름대로 높아지고
# 281                                       약간 이 생각도 많이 ((들어))
# 330        근데 확실히 다이어트 평생 ((해야xx)) 느낀 게 우리 엄마도 살이 찌더라고 {l...
# 342         나는 다이어트는 진짜 ((그래도)) 진짜 아니면 평생 그냥 좀 뚱뚱하고 통통하게 살던가
#                                  ...
# 1990837           어~ 거의 시내 쪽에서 뭐~~ 콜로세움 뭐~ ((그케이케)) 뭐~ 거기 시내
# 1991374                              그게 의지 ((그래)) 의지일 수도 있는데
# 1991423                      자기 입장에서도 난감하고 물론 ((암도다)) 몇 달 후에
# 1991464                       ((무슨))의미가 있겠느냐 술이야 뭐 쫌 쭐이면서 점점
# 1991508                           혼자서 할 수 있는 ((운동)) 하고 집에 뭐~
# Name: 방언, Length: 12452, dtype: object

# %%
phrase_words = df["방언"].str.extract(r"\(\((.*)\)\)", expand=False).dropna()
for i in phrase_words.index:
    sentence = df.loc[i, "방언"]
    sentence = re.sub(r"\(\(.*\)\)", phrase_words[i], sentence)
    df.loc[i, "방언"] = sentence

df.loc[phrase_words.index, "방언"]
# Out:
# 152        그냥 적게 먹고 많이 xx하는 거고 그냥 그렇게 하면은 되는데 진짜 그런 광고 같은...
# 242                막 포만감도 막 엄청 많지 않으니까 그래서 xx xxx도 나름대로 높아지고
# 281                                           약간 이 생각도 많이 들어
# 330        근데 확실히 다이어트 평생 해야xx 느낀 게 우리 엄마도 살이 찌더라고 {laugh...
# 342             나는 다이어트는 진짜 그래도 진짜 아니면 평생 그냥 좀 뚱뚱하고 통통하게 살던가
#                                  ...
# 1990837               어~ 거의 시내 쪽에서 뭐~~ 콜로세움 뭐~ 그케이케 뭐~ 거기 시내
# 1991374                                  그게 의지 그래 의지일 수도 있는데
# 1991423                          자기 입장에서도 난감하고 물론 암도다 몇 달 후에
# 1991464                           무슨의미가 있겠느냐 술이야 뭐 쫌 쭐이면서 점점
# 1991508                               혼자서 할 수 있는 운동 하고 집에 뭐~
# Name: 방언, Length: 12452, dtype: object

# %%
# 표준어 column에 대해서도 같은 과정을 반복한다.
phrase_words = df["표준어"].str.extract(r"\(\((.*)\)\)", expand=False).dropna()
for i in phrase_words.index:
    sentence = df.loc[i, "표준어"]
    sentence = re.sub(r"\(\(.*\)\)", phrase_words[i], sentence)
    df.loc[i, "표준어"] = sentence

df.loc[phrase_words.index, "표준어"]
# Out:
# 152        그냥 적게 먹고 많이 xx하는 거고 그냥 그렇게 하면은 되는데 진짜 그런 광고 같은...
# 242                막 포만감도 막 엄청 많지 않으니까 그래서 xx xxx도 나름대로 높아지고
# 281                                           약간 이 생각도 많이 들어
# 330        근데 확실히 다이어트 평생 해야xx 느낀 게 우리 엄마도 살이 찌더라고 {laugh...
# 342             나는 다이어트는 진짜 그래도 진짜 아니면 평생 그냥 좀 뚱뚱하고 통통하게 살던가
#                                  ...
# 1990837               어~ 거의 시내 쪽에서 뭐~~ 콜로세움 뭐~ 그케이케 뭐~ 거기 시내
# 1991374                                  그게 의지 그래 의지일 수도 있는데
# 1991423                          자기 입장에서도 난감하고 물론 암도다 몇 달 후에
# 1991464                          무슨의미가 있겠느냐 술이야 뭐 조금 쭐이면서 점점
# 1991508                               혼자서 할 수 있는 운동 하고 집에 뭐~
# Name: 표준어, Length: 12448, dtype: object

# %% [markdown]
# ### (방언)/(표준어) 쌍 처리

# %%
df[df["방언"].str.contains("\(.*\)\/\(.*\)")]
# Out:
#                                                         방언  \
# 176                  약간 나는 운동(하믄서)/(하면서) 스트레스 풀라는 것도 있긴 한데
# 8812        근데 우리 아빠는 오십 살(이냐)/(이잖아) 그니까 그래서 엄마 더 그런 거 있어.
# 8841        그리고 엄마도 그 할머니 병원에 이틀 있었다고 서로 스트레스 받아(갖고)/(가지고)
# 9048                               엄마가 딱 싫어하는 스타일(이여)/(이야)
# 12284    이십일 편인데 이틀 몰아(가꼬)/(가지고) 걍  미친듯이 봤단 말야 하아 흡입력 개...
# ...                                                    ...
# 1991378           멋있어 보이고 그래서 나도 담배 피워(볼려고)/(보려고) 시도를 해봤는데
# 1991418                           이렇게 또 뇌 이런(잉)/(응) 심근 경색
# 1991447                     자제(할려고)/(하려고) 쫌 그렇게 신경을 쓰기는 해.
# 1991488                          요즘에 다 시국이 시국인지라(잉)/(응) 다
# 1991765                   투자자금내에 -(맻)/(몇)개- 맻개만 딱 이렇게 우량주를
#
#                                                        표준어              출처 파일
# 176                  약간 나는 운동(하믄서)/(하면서) 스트레스 풀라는 것도 있긴 한데  DJDD20000001.json
# 8812       근데 우리 아빠는 오십 살(이냐)/(이잖아) 그러니까 그래서 엄마 더 그런 거 있어.  DJDD20000019.json
# 8841        그리고 엄마도 그 할머니 병원에 이틀 있었다고 서로 스트레스 받아(갖고)/(가지고)  DJDD20000019.json
# 9048                               엄마가 딱 싫어하는 스타일(이여)/(이야)  DJDD20000019.json
# 12284    이십일 편인데 이틀 몰아(가꼬)/(가지고) 그냥 미친듯이 봤단 말야 하아 흡입력 개...  DJDD20000028.json
# ...                                                    ...                ...
# 1991378           멋있어 보이고 그래서 나도 담배 피워(볼려고)/(보려고) 시도를 해봤는데  DJSX20004851.json
# 1991418                           이렇게 또 뇌 이런(잉)/(응) 심근 경색   DJSX20004851.json
# 1991447                    자제(할려고)/(하려고) 조금 그렇게 신경을 쓰기는 해.  DJSX20004851.json
# 1991488                          요즘에 다 시국이 시국인지라(잉)/(응) 다   DJSX20004851.json
# 1991765                   투자자금내에 -(맻)/(몇)개- 몇개만 딱 이렇게 우량주를  DJSX20004852.json
#
# [4457 rows x 3 columns]

# %%
phrase_words = df["방언"].str.extract(r"\((.*)\)\/\(.*\)", expand=False).dropna()
for i in phrase_words.index:
    sentence = df.loc[i, "방언"]
    sentence = re.sub(r"\(.*\)\/\(.*\)", phrase_words[i], sentence)
    df.loc[i, "방언"] = sentence

df.loc[phrase_words.index, "방언"]
# Out:
# 176                      약간 나는 운동하믄서 스트레스 풀라는 것도 있긴 한데
# 8812            근데 우리 아빠는 오십 살이냐 그니까 그래서 엄마 더 그런 거 있어.
# 8841            그리고 엄마도 그 할머니 병원에 이틀 있었다고 서로 스트레스 받아갖고
# 9048                                  엄마가 딱 싫어하는 스타일이여
# 12284      이십일 편인데 이틀 몰아가꼬 걍  미친듯이 봤단 말야 하아 흡입력 개 쩔어 걍
#                               ...
# 1991378               멋있어 보이고 그래서 나도 담배 피워볼려고 시도를 해봤는데
# 1991418                             이렇게 또 뇌 이런잉 심근 경색
# 1991447                         자제할려고 쫌 그렇게 신경을 쓰기는 해.
# 1991488                            요즘에 다 시국이 시국인지라잉 다
# 1991765                     투자자금내에 -맻개- 맻개만 딱 이렇게 우량주를
# Name: 방언, Length: 4457, dtype: object

# %%
phrase_words = df["표준어"].str.extract(r"\(.*\)\/\((.*)\)", expand=False).dropna()
for i in phrase_words.index:
    sentence = df.loc[i, "표준어"]
    sentence = re.sub(r"\(.*\)\/\(.*\)", phrase_words[i], sentence)
    df.loc[i, "표준어"] = sentence

df.loc[phrase_words.index, "표준어"]
# Out:
# 176                        약간 나는 운동하면서 스트레스 풀라는 것도 있긴 한데
# 8812            근데 우리 아빠는 오십 살이잖아 그러니까 그래서 엄마 더 그런 거 있어.
# 8841             그리고 엄마도 그 할머니 병원에 이틀 있었다고 서로 스트레스 받아가지고
# 9048                                    엄마가 딱 싫어하는 스타일이야
# 12284      이십일 편인데 이틀 몰아가지고 그냥 미친듯이 봤단 말야 하아 흡입력 개 쩔어 그냥
#                                ...
# 1991378                 멋있어 보이고 그래서 나도 담배 피워보려고 시도를 해봤는데
# 1991418                               이렇게 또 뇌 이런응 심근 경색
# 1991447                          자제하려고 조금 그렇게 신경을 쓰기는 해.
# 1991488                              요즘에 다 시국이 시국인지라응 다
# 1991765                       투자자금내에 -몇개- 몇개만 딱 이렇게 우량주를
# Name: 표준어, Length: 4457, dtype: object

# %% [markdown]
# ## {laughing} 태그 제거

# %%
laugh_index = df["방언"].str.contains("\{laughing\}")
df[laugh_index]
# Out:
#                                                         방언  \
# 4                                               {laughing}
# 27                      약간 거울 봤을 때 약간 내가 괜찮아 보여 {laughing}
# 70                                그러는 게 제일 쉬우니까 {laughing}
# 71                                 그게 제일 만만하잖아. {laughing}
# 77                        그럼 거울 보면서 만족감을 느끼는 거지.{laughing}
# ...                                                    ...
# 1991939  내 김치 맵다고 아예 맵지 않은 김치를 사서 먹거든 너무 너무 편하고 좋더라 {la...
# 1991946                    미쳤다고 그러잖아 그걸 {laughing} 안 맛있어요.
# 1992042             어떻게 이렇게 같이 살아 주는지 나도 참 대단하다 {laughing}
# 1992072  구제 라나 뭐라나 만원 주고 샀다는데 내가 어이가 없어 한참 웃었다 야 {laugh...
# 1992078             우리 신랑은 나한테는 참 부담스러운 존재여 어떻게 {laughing}
#
#                                                        표준어              출처 파일
# 4                                               {laughing}  DJDD20000001.json
# 27                      약간 거울 봤을 때 약간 내가 괜찮아 보여 {laughing}  DJDD20000001.json
# 70                                그러는 게 제일 쉬우니까 {laughing}  DJDD20000001.json
# 71                                 그게 제일 만만하잖아. {laughing}  DJDD20000001.json
# 77                        그럼 거울 보면서 만족감을 느끼는 거지.{laughing}  DJDD20000001.json
# ...                                                    ...                ...
# 1991939  내 김치 맵다고 아예 맵지 않은 김치를 사서 먹거든 너무 너무 편하고 좋더라 {la...  DJSX20004853.json
# 1991946                    미쳤다고 그러잖아 그걸 {laughing} 안 맛있어요.  DJSX20004853.json
# 1992042             어떻게 이렇게 같이 살아 주는지 나도 참 대단하다 {laughing}  DJSX20004853.json
# 1992072  구제 라나 뭐라나 만원 주고 샀다는데 내가 어이가 없어 한참 웃었다 야 {laugh...  DJSX20004853.json
# 1992078             우리 신랑은 나한테는 참 부담스러운 존재여 어떻게 {laughing}  DJSX20004853.json
#
# [23508 rows x 3 columns]

# %%
df["방언"] = df["방언"].str.replace(r"\{laughing\}", "", regex=True)
df[laugh_index]
# Out:
#                                                   방언  \
# 4
# 27                          약간 거울 봤을 때 약간 내가 괜찮아 보여
# 70                                    그러는 게 제일 쉬우니까
# 71                                     그게 제일 만만하잖아.
# 77                            그럼 거울 보면서 만족감을 느끼는 거지.
# ...                                              ...
# 1991939  내 김치 맵다고 아예 맵지 않은 김치를 사서 먹거든 너무 너무 편하고 좋더라
# 1991946                        미쳤다고 그러잖아 그걸  안 맛있어요.
# 1992042                 어떻게 이렇게 같이 살아 주는지 나도 참 대단하다
# 1992072     구제 라나 뭐라나 만원 주고 샀다는데 내가 어이가 없어 한참 웃었다 야
# 1992078                 우리 신랑은 나한테는 참 부담스러운 존재여 어떻게
#
#                                                        표준어              출처 파일
# 4                                               {laughing}  DJDD20000001.json
# 27                      약간 거울 봤을 때 약간 내가 괜찮아 보여 {laughing}  DJDD20000001.json
# 70                                그러는 게 제일 쉬우니까 {laughing}  DJDD20000001.json
# 71                                 그게 제일 만만하잖아. {laughing}  DJDD20000001.json
# 77                        그럼 거울 보면서 만족감을 느끼는 거지.{laughing}  DJDD20000001.json
# ...                                                    ...                ...
# 1991939  내 김치 맵다고 아예 맵지 않은 김치를 사서 먹거든 너무 너무 편하고 좋더라 {la...  DJSX20004853.json
# 1991946                    미쳤다고 그러잖아 그걸 {laughing} 안 맛있어요.  DJSX20004853.json
# 1992042             어떻게 이렇게 같이 살아 주는지 나도 참 대단하다 {laughing}  DJSX20004853.json
# 1992072  구제 라나 뭐라나 만원 주고 샀다는데 내가 어이가 없어 한참 웃었다 야 {laugh...  DJSX20004853.json
# 1992078             우리 신랑은 나한테는 참 부담스러운 존재여 어떻게 {laughing}  DJSX20004853.json
#
# [23508 rows x 3 columns]

# %%
df["표준어"] = df["표준어"].str.replace(r"\{laughing\}", "", regex=True)
df[laugh_index]
# Out:
#                                                   방언  \
# 4
# 27                          약간 거울 봤을 때 약간 내가 괜찮아 보여
# 70                                    그러는 게 제일 쉬우니까
# 71                                     그게 제일 만만하잖아.
# 77                            그럼 거울 보면서 만족감을 느끼는 거지.
# ...                                              ...
# 1991939  내 김치 맵다고 아예 맵지 않은 김치를 사서 먹거든 너무 너무 편하고 좋더라
# 1991946                        미쳤다고 그러잖아 그걸  안 맛있어요.
# 1992042                 어떻게 이렇게 같이 살아 주는지 나도 참 대단하다
# 1992072     구제 라나 뭐라나 만원 주고 샀다는데 내가 어이가 없어 한참 웃었다 야
# 1992078                 우리 신랑은 나한테는 참 부담스러운 존재여 어떻게
#
#                                                  표준어              출처 파일
# 4                                                     DJDD20000001.json
# 27                          약간 거울 봤을 때 약간 내가 괜찮아 보여   DJDD20000001.json
# 70                                    그러는 게 제일 쉬우니까   DJDD20000001.json
# 71                                     그게 제일 만만하잖아.   DJDD20000001.json
# 77                            그럼 거울 보면서 만족감을 느끼는 거지.  DJDD20000001.json
# ...                                              ...                ...
# 1991939  내 김치 맵다고 아예 맵지 않은 김치를 사서 먹거든 너무 너무 편하고 좋더라   DJSX20004853.json
# 1991946                        미쳤다고 그러잖아 그걸  안 맛있어요.  DJSX20004853.json
# 1992042                 어떻게 이렇게 같이 살아 주는지 나도 참 대단하다   DJSX20004853.json
# 1992072     구제 라나 뭐라나 만원 주고 샀다는데 내가 어이가 없어 한참 웃었다 야   DJSX20004853.json
# 1992078                 우리 신랑은 나한테는 참 부담스러운 존재여 어떻게   DJSX20004853.json
#
# [23508 rows x 3 columns]

# %% [markdown]
# ## 빈 문자열 제거

# %%
is_empty_dialect = np.where(df["방언"] == '', True, False).tolist()
is_empty_standard = np.where(df["표준어"] == '', True, False).tolist()
is_empty = [dia or sta for dia, sta in zip(is_empty_dialect, is_empty_standard)]
df.loc[is_empty]
# Out:
#         방언 표준어              출처 파일
# 4               DJDD20000001.json
# 89              DJDD20000001.json
# 1272            DJDD20000004.json
# 1531            DJDD20000004.json
# 3431            DJDD20000008.json
# ...     ..  ..                ...
# 1985289         DJSX20004826.json
# 1986525         DJSX20004837.json
# 1989326         DJSX20004845.json
# 1989397         DJSX20004845.json
# 1991172         DJSX20004851.json
#
# [3453 rows x 3 columns]

# %% [markdown]
# 총 3453개의 데이터가 빈 문자열을 가진다.
#
# 이들을 제거할 필요가 있다.

# %%
empty_index = df.loc[is_empty].index
df = df.drop(empty_index)

# %% [markdown]
# 1차적인 전처리가 끝았으니 우선 데이터를 출력한다.

# %%
df.to_csv("datas/output/jeonla_dialect_data_processed_1.csv")

# %% [markdown]
# ## 표준어에 방언 텍스트가 그대로 들어간 경우

# %%
df = pd.read_csv("datas/output/jeonla_dialect_data_processed_1.csv", index_col=0)
df.loc[438064]
# Out:
# 방언       아직까지는 큰 이상은 없는 거 같애 긍까 너는 지금 인제 막 그런 증상들이 나온다니까
# 표준어      아직까지는 큰 이상은 없는 거 같애 긍까 너는 지금 인제 막 그런 증상들이 나온다니까
# 출처 파일                                  DJDD20001725.json
# Name: 438064, dtype: object

# %% [markdown]
# 위의 경우 '긍까'라는 방언이 표준어에 그대로 들어가 있는 것을 확인할 수 있다.
#
# 이는 원본 파일에서도 나타나는 문제로, 데이터 자체의 문제이다. 이를 처리하고는 싶으나 이러한 오류는 사람이 직접 확인해야만 한다.
#
# 따라서 오류를 직접 확인해서 수정하는 작업을 하는 것은 모델 구축 기간이 짧아 불가능하다.

# %% [markdown]
# ## -(문자열)- 처리

# %% [markdown]
# 데이터가 발화 데이터이다 보니 화자가 말을 더듬거나 고쳐 말할 때가 있다. 이때 고쳐 말한 부분을 -(문자열)- 방식으로 표현하였다.
#
# 이런 문자열은 완전히 삭제해 버리는 게 적절하다.

# %%
df.loc[df["방언"].str.contains(r"\-.*\-")]
# Out:
#                                                         방언  \
# 115      근데 어쩔 수 없이 해야지 약간 이런 생각 때문에 했는데 나는 솔직히 피티가 더 -...
# 209                               아 -그런- 진짜로 그런 경우도 많이 봤어.
# 387                                 -그- 그 근육 늘리기가 진짜 힘들더라고
# 455      맞어 맞어 나도 -사- 사실 막 연애를 보면서 진짜 완전 불타오르는 사랑 그런 거 ...
# 458           아 연애 저렇게 연애하면 진짜 -죽어나- 다 죽어나가겠구나 약간 이 생각 했어.
# ...                                                    ...
# 1991880                   본인이 끓였대 그래서 뭐 -미- 미역국에다가 북어를 넣어서
# 1991889                      예전에 -안- 안 좋았던 기억에 좀 많이 있어 가지고
# 1991956               점심때도 너무 늦게 좀 일하다 보니까 너무 -늦-늦게 나와 가지고
# 1991960                           그렇게 기다리고 -있었- 있었던 거 아니야?
# 1991990                         전화 통화 하면서 -찾아- 찾아 가지고 잘 왔네
#
#                                                        표준어              출처 파일
# 115      근데 어쩔 수 없이 해야지 약간 이런 생각 때문에 했는데 나는 솔직히 피티가 더 -...  DJDD20000001.json
# 209                               아 -그런- 진짜로 그런 경우도 많이 봤어.  DJDD20000001.json
# 387                                 -그- 그 근육 늘리기가 진짜 힘들더라고  DJDD20000001.json
# 455      맞어 맞어 나도 -사- 사실 막 연애를 보면서 진짜 완전 불타오르는 사랑 그런 거 ...  DJDD20000002.json
# 458           아 연애 저렇게 연애하면 진짜 -죽어나- 다 죽어나가겠구나 약간 이 생각 했어.  DJDD20000002.json
# ...                                                    ...                ...
# 1991880                   본인이 끓였대 그래서 뭐 -미- 미역국에다가 북어를 넣어서  DJSX20004853.json
# 1991889                      예전에 -안- 안 좋았던 기억에 좀 많이 있어 가지고  DJSX20004853.json
# 1991956               점심때도 너무 늦게 좀 일하다 보니까 너무 -늦-늦게 나와 가지고  DJSX20004853.json
# 1991960                           그렇게 기다리고 -있었- 있었던 거 아니야?  DJSX20004853.json
# 1991990                         전화 통화 하면서 -찾아- 찾아 가지고 잘 왔네  DJSX20004853.json
#
# [36952 rows x 3 columns]

# %%
stutter_sentence = df["방언"].str.contains(r"\-.*\-")
df["방언"] = df["방언"].str.replace(r"\-.*\-", "", regex=True)
df["표준어"] = df["표준어"].str.replace(r"\-.*\-", "", regex=True)

df.loc[stutter_sentence]
# Out:
# C:\Users\wnsgh\AppData\Local\Temp\ipykernel_14452\656797981.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["방언"] = df["방언"].str.replace(r"\-.*\-", "")
# C:\Users\wnsgh\AppData\Local\Temp\ipykernel_14452\656797981.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["표준어"] = df["표준어"].str.replace(r"\-.*\-", "")
#                                                         방언  \
# 115      근데 어쩔 수 없이 해야지 약간 이런 생각 때문에 했는데 나는 솔직히 피티가 더  ...
# 209                                   아  진짜로 그런 경우도 많이 봤어.
# 387                                     그 근육 늘리기가 진짜 힘들더라고
# 455        맞어 맞어 나도  사실 막 연애를 보면서 진짜 완전 불타오르는 사랑 그런 거 해가지고
# 458                아 연애 저렇게 연애하면 진짜  다 죽어나가겠구나 약간 이 생각 했어.
# ...                                                    ...
# 1991880                      본인이 끓였대 그래서 뭐  미역국에다가 북어를 넣어서
# 1991889                         예전에  안 좋았던 기억에 좀 많이 있어 가지고
# 1991956                  점심때도 너무 늦게 좀 일하다 보니까 너무 늦게 나와 가지고
# 1991960                               그렇게 기다리고  있었던 거 아니야?
# 1991990                             전화 통화 하면서  찾아 가지고 잘 왔네
#
#                                                        표준어              출처 파일
# 115      근데 어쩔 수 없이 해야지 약간 이런 생각 때문에 했는데 나는 솔직히 피티가 더  ...  DJDD20000001.json
# 209                                   아  진짜로 그런 경우도 많이 봤어.  DJDD20000001.json
# 387                                     그 근육 늘리기가 진짜 힘들더라고  DJDD20000001.json
# 455        맞어 맞어 나도  사실 막 연애를 보면서 진짜 완전 불타오르는 사랑 그런 거 해가지고  DJDD20000002.json
# 458                아 연애 저렇게 연애하면 진짜  다 죽어나가겠구나 약간 이 생각 했어.  DJDD20000002.json
# ...                                                    ...                ...
# 1991880                      본인이 끓였대 그래서 뭐  미역국에다가 북어를 넣어서  DJSX20004853.json
# 1991889                         예전에  안 좋았던 기억에 좀 많이 있어 가지고  DJSX20004853.json
# 1991956                  점심때도 너무 늦게 좀 일하다 보니까 너무 늦게 나와 가지고  DJSX20004853.json
# 1991960                               그렇게 기다리고  있었던 거 아니야?  DJSX20004853.json
# 1991990                             전화 통화 하면서  찾아 가지고 잘 왔네  DJSX20004853.json
#
# [36952 rows x 3 columns]

# %% [markdown]
# 성공적으로 말 더듬은 부분이 삭제된 것을 확인할 수 있다.

# %%
df.to_csv("datas/output/jeonla_dialect_data_processed_1.csv")

# %% [markdown]
# ## 포스 태깅 분석

# %% [markdown]
# 포스 태깅은 mecab 클래스로 진행한다. 실행 시간이 타 태깅 라이브러리에 비해 압도적으로 빠르기 때문이다.

# %%
import MeCab

def pos(sentence: str):
    """한국어 토큰을 분리합니다. 토큰과 품사를 튜플 리스트로 반환합니다.
        
        매개변수:
            sentence (str): 토큰화할 문장 
        반환값:
            token list (list[tuple]): 토큰과 품사 리스트
    """
    t = MeCab.Tagger()
    tag_result = t.parse(sentence)
    tag_result = tag_result.replace("\t", ".@!").replace("\n", ".@!").split(".@!")
    tag_word = tag_result[::2][:-1] # 마지막 EOS는 자른다
    tag_info = tag_result[1::2][:-1] # 마지막 EOS는 자른다
    return [(word, info.split(',')[0]) for word, info in zip(tag_word, tag_info)]

def morphs(sentence: str):
    """한국어 토큰을 분리합니다. 토큰의 리스트를 반환합니다.
        
        매개변수:
            sentence (str): 토큰화할 문장 
        반환값:
            token list (list): 토큰 리스트
    """
    t = MeCab.Tagger()
    tag_result = t.parse(sentence)
    tag_result = tag_result.replace("\t", ".@!").replace("\n", ".@!").split(".@!")
    return tag_result[::2][:-1]

def morph_and_preprocess(sentence: str):
    """한국어 토큰을 분리하고 전처리합니다. 토큰의 리스트를 반환합니다.
        
        매개변수:
            sentence (str): 토큰화할 문장 
        반환값:
            token list (list): 토큰 리스트
    """
    
    pos_result = pos(sentence)
    word_list = []
    for word, info in pos_result:
        if info == "NNP":
            # 고유명사일 경우 "고유"라는 단일 명사로 표현하도록 대체
            word_list.append("고유")
        else:
            word_list.append(word)
    
    return word_list

# %%
dialect_list = df["방언"].to_list()
dialect_list = list(map(morph_and_preprocess, dialect_list))
dialect_list
# Out:
# [['나', '는', '다이어트', '에', '대해서', '말', '하', '고', '싶', '어', '.'],
#  ['하'],
#  ['우리',
#   '집',
#   '은',
#   '내',
#   '가',
#   '봤',
#   '을',
#   '때',
#   '살찔',
#   '수',
#   '밖에',
#   '없',
#   '는',
#   '구조',
#   '를',
#   '가지',
#   '고',
#   '있',
#   '어',
#   '.'],
#  ['다이어트',
#   '를',
#   '해야',
#   '되',
#   '는',
#   '사람',
#   '은',
#   '애초',
#   '에',
#   '야식',
#   '을',
#   '많이',
#   '먹',
#   '거나',
#   '아',
#   '어',
#   '제도',
#   '야식',
#   '을',
#   '먹',
#   '었',
#   '거든',
#   '?'],
#  ['그러니까',
#   '다이어트',
#   '는',
#   '이게',
#   '애초',
#   '에',
#   '조금',
#   '만',
#   '먹',
#   '으면',
#   '되',
#   '는데',
#   '많이',
#   '먹',
#   '으니까',
#   '어쩔',
#   '수',
#   '없이',
#   '하',
#   '게',
#   '될',
#   '수',
#   '밖',
#   '에',
#   '없',
#   '어'],
#  ['아', '나', '간헐', '적', '단식', '도', '해', '봤', '거든', '?'],
#  ['하루', '한', '끼', '도', '해', '봤', '단', '말', '이', '야', '.'],
#  ['근데',
#   '하루',
#   '한',
#   '끼',
#   '는',
#   '우선',
#   '옆',
#   '에',
#   '있',
#   '는',
#   '가족',
#   '들',
#   '이',
#   '하루',
#   '세',
#   '끼',
#   '를',
#   '먹',
#   '기',
#   '때문',
#   '에'],
#  ['도저히', '할', '수', '가', '없', '어', '.'],
#  ['밥', '을', '너무', '먹', '고', '싶', '어', '.'],
#  ['그래서', '못', '해'],
#  ['다이어트', '너무', '어려워', '그래서'],
#  ['아',
#   '다이어트',
#   '가',
#   '근데',
#   '진짜',
#   '식단',
#   '이',
#   '진짜',
#   '한',
#   '팔',
#   '십',
#   '퍼센트',
#   '고',
#   '운동',
#   '이',
#   '이',
#   '십',
#   '퍼센트',
#   '정도',
#   '되',
#   '는데'],
#  ['식단', '을', '가족', '들', '이', '그렇게', '다', '옆', '에서', '먹', '어', '버리', '니까'],
#  ['이제',
#   '나',
#   '혼자',
#   '식단',
#   '을',
#   '하',
#   '기',
#   '에',
#   '는',
#   '너무',
#   '힘들',
#   '고',
#   '옆',
#   '에',
#   '또',
#   '맛있',
#   '는',
#   '냄새',
#   '가',
#   '나',
#   '니까',
#   '인제',
#   '나',
#   '는',
#   '또',
#   '고유',
#   '랑',
#   '계란',
#   '이런',
#   '거',
#   '먹',
#   '어야',
#   '되',
#   '고',
#   '너무',
#   '서럽',
#   '지',
#   '.'],
#  ['아',
#   '근데',
#   '옆',
#   '에',
#   '가족',
#   '들',
#   '이',
#   '그',
#   '먹',
#   '어야',
#   '되',
#   '니까',
#   '식단',
#   '못',
#   '하',
#   '는',
#   '거',
#   '는',
#   '좀',
#   '진짜',
#   '인정',
#   '이',
#   '야',
#   '.'],
#  ['왜냐면',
#   '나',
#   '는',
#   '막',
#   '닭',
#   '가슴살',
#   '구워',
#   '가지',
#   '고',
#   '먹',
#   '고',
#   '싶',
#   '은데',
#   '옆',
#   '에서',
#   '라면',
#   '이랑',
#   '끓여',
#   '갖',
#   '고',
#   '먹',
#   '고',
#   '있',
#   '어',
#   '.'],
#  ['그라믄', '나', '는', '뭐', '어떡', '해', '그래서', '옆', '에서', '막', '부추긴다', '?'],
#  ['막',
#   '아',
#   '하나',
#   '만',
#   '먹',
#   '어',
#   '괜찮',
#   '아',
#   '한',
#   '개',
#   '만',
#   '먹',
#   '어도',
#   '괜찮',
#   '아'],
#  ['이러', '면은', '나', '도', '모르', '게', '약간', '홀린다', '고', '그럼', '먹', '게', '된다고'],
#  ['나',
#   '도',
#   '근데',
#   '인제',
#   '다이어트',
#   '를',
#   '딱',
#   '시작',
#   '한다고',
#   '마음',
#   '을',
#   '먹',
#   '었',
#   '는데',
#   '옆',
#   '에서',
#   '그',
#   '자꾸',
#   '그렇게',
#   '먹',
#   '으라고',
#   '하',
#   '면',
#   '이제',
#   '나',
#   '도',
#   '먹',
#   '게',
#   '되',
#   '니까'],
#  ['이제', '또', '먹', '으면'],
#  ['아',
#   '오늘',
#   '까지',
#   '만',
#   '먹',
#   '어야지',
#   '하',
#   '고',
#   '인제',
#   '또',
#   '왕창',
#   '먹',
#   '어',
#   '버리',
#   '니까',
#   '계속',
#   '이게',
#   '반복',
#   '되',
#   '면서',
#   '인제',
#   '계속',
#   '인제',
#   '살',
#   '이',
#   '찌',
#   '고'],
#  ['나',
#   '는',
#   '나',
#   '한테',
#   '실망',
#   '하',
#   '고',
#   '약간',
#   '그런',
#   '게',
#   '있',
#   '는',
#   '것',
#   '같',
#   '아',
#   '.'],
#  ['아', '근데', '자괴감', '자괴감', '오', '는', '거', '자괴감', '오', '는', '거', '인정', '.'],
#  ['근데',
#   '이게',
#   '문제',
#   '가',
#   '이게',
#   '살',
#   '을',
#   '어느',
#   '정도',
#   '빼',
#   '면',
#   '더',
#   '문제',
#   '인',
#   '게'],
#  ['약간', '거울', '봤', '을', '때', '약간', '내', '가', '괜찮', '아', '보여'],
#  ['그러면', '이제', '망하', '는', '거', '야', '.'],
#  ['그럼', '이제', '못', '해', '.'],
#  ['다이어트', '는', '아무것', '도', '못', '해', '.'],
#  ['어', '맞', '어'],
#  ['약간',
#   '옷',
#   '으로',
#   '가려',
#   '지',
#   '는',
#   '것',
#   '도',
#   '있',
#   '고',
#   '좀',
#   '앵',
#   '간해',
#   '보이',
#   '니까',
#   '못한다고',
#   '그거',
#   '를'],
#  ['근데',
#   '진짜',
#   '다이어트',
#   '를',
#   '딱',
#   '했',
#   '을',
#   '때',
#   '인제',
#   '다이어트',
#   '를',
#   '하',
#   '면서',
#   '좀',
#   '몸무게',
#   '같',
#   '은',
#   '걸',
#   '재',
#   '면서',
#   '항상',
#   '아침',
#   '마다',
#   '몸무게',
#   '를',
#   '재',
#   '고',
#   '인제'],
#  ['아',
#   '오늘',
#   '이만큼',
#   '빠졌',
#   '구나',
#   '했',
#   '는데',
#   '인제',
#   '나중',
#   '에',
#   '되',
#   '면서',
#   '어느',
#   '정도',
#   '정체',
#   '되',
#   '는',
#   '몸무게',
#   '가',
#   '되',
#   '잖아'],
#  ['인제',
#   '그러면',
#   '진짜',
#   '거울',
#   '을',
#   '봐도',
#   '머',
#   '달라지',
#   '는',
#   '것',
#   '도',
#   '없',
#   '으니까',
#   '다이어트',
#   '에',
#   '대한',
#   '회의감',
#   '같',
#   '은',
#   '게',
#   '막',
#   '들',
#   '어서'],
#  ['이제', '그때', '이후', '로부터', '는', '이제', '막', '먹', '기', '시작', '하', '는', '거', '지'],
#  ['그래서',
#   '나',
#   '는',
#   '좀',
#   '몸무게',
#   '가',
#   '정체',
#   '됐',
#   '을',
#   '때',
#   '가',
#   '제일',
#   '스트레스',
#   '받',
#   '는',
#   '것',
#   '같',
#   '애',
#   '.'],
#  ['아니',
#   '근데',
#   '나',
#   '는',
#   '체중',
#   '계',
#   '올라가',
#   '는',
#   '것',
#   '도',
#   '좀',
#   '하',
#   '다가',
#   '안',
#   '했',
#   '어',
#   '.'],
#  ['짜증', '나', '가지', '고', '스트레스', '받', '아', '가지', '고'],
#  ['그니까',
#   '다이어트',
#   '를',
#   '안',
#   '하',
#   '는',
#   '게',
#   '제일',
#   '좋',
#   '은데',
#   '그냥',
#   '찌',
#   '면',
#   '안',
#   '되',
#   '잖아',
#   '그게'],
#  ['우리', '고', '삼', '때', '도', '엄청', '쪄', '갖', '고', '막', '난리', '났었', '잖아', '.'],
#  ['그때', '다', '쪄', '가지', '고'],
#  ['심각', '해', '.'],
#  ['근데',
#   '그',
#   '다이어트',
#   '라는',
#   '게',
#   '나',
#   '는',
#   '솔직히',
#   '인제',
#   '처음',
#   '에',
#   '는',
#   '정말로',
#   '막'],
#  ['간헐',
#   '적',
#   '단식',
#   '엄청',
#   '많이',
#   '하',
#   '고',
#   '그냥',
#   '진짜',
#   '고구마',
#   '랑',
#   '계란',
#   '만',
#   '먹',
#   '고'],
#  ['진짜',
#   '막',
#   '한',
#   '달',
#   '에',
#   '십',
#   '키',
#   '로',
#   '씩',
#   '뺄',
#   '만큼',
#   '엄청',
#   '많이',
#   '뺐었',
#   '는데',
#   '진짜',
#   '인제',
#   '다이어트',
#   '를',
#   '많이',
#   '하',
#   '고',
#   '느낀',
#   '게',
#   '그냥',
#   '습관',
#   '적',
#   '인',
#   '거',
#   '를',
#   '바꿔',
#   '가지',
#   '고'],
#  ['인제',
#   '운동',
#   '도',
#   '어느',
#   '정도',
#   '습관',
#   '화',
#   '하',
#   '고',
#   '인제',
#   '밥',
#   '같',
#   '은',
#   '것',
#   '도'],
#  ['소식',
#   '하',
#   '면서',
#   '하',
#   '는',
#   '게',
#   '더',
#   '나',
#   '을',
#   '것',
#   '같',
#   '다',
#   '생각',
#   '해서',
#   '인제',
#   '그렇게',
#   '할려고',
#   '노력',
#   '하',
#   '고',
#   '있',
#   '지만',
#   '확실히',
#   '간헐',
#   '적',
#   '단식',
#   '같',
#   '은',
#   '게',
#   '눈',
#   '에',
#   '잘',
#   '보이',
#   '고',
#   '눈',
#   '에',
#   '인제',
#   '테',
#   '가',
#   '나',
#   '니까'],
#  ['그거', '를', '더', '선호', '선호', '할', '수', '밖에', '없', '는', '것', '같', '애', '.'],
#  ['맞', '어', '.'],
#  ['근데', '내', '가', '피티', '도', '받', '아', '봤', '잖아'],
#  ['근데', '이게', '진짜', '주변', '에서', '피티', '받', '았', '다', '하', '면은'],
#  ['한', '진짜', '한', '열', '명', '이', '십', '명', '물', '어', '본단', '말', '이', '야', '.'],
#  ['근디',
#   '이게',
#   '다',
#   '말',
#   '하',
#   '는',
#   '게',
#   '비싸',
#   '지',
#   '않',
#   '냐고',
#   '물',
#   '어',
#   '본단',
#   '말',
#   '이',
#   '야'],
#  ['진짜',
#   '공감',
#   '해',
#   '나',
#   '진짜',
#   '세',
#   '달',
#   '해',
#   '가지',
#   '고',
#   '백',
#   '오',
#   '십',
#   '만',
#   '원',
#   '들',
#   '었',
#   '어',
#   '.'],
#  ['백', '오', '십', '만', '원', '들', '어', '가지', '고', '십', '키', '로', '빼', '기'],
#  ['그게', '진짜', '너무너무', '좀', '고유', '야', '.'],
#  ['그건', '진짜', '고유', '야', '.'],
#  ['어', '진짜', '고유', '야', '한번', '하', '면', '족해', '.'],
#  ['평소', '습관', '고치', '는', '게', '니', '말', '대로', '맞', '기', '는', '해', '진짜'],
#  ['근데', '그게', '쉽', '지', '가', '않', '단', '말', '이', '야', '진짜로'],
#  ['좀', '덜', '먹', '으면', '되', '는데', '그게', '어렵', '잖아', '솔직히'],
#  ['아', '너무', '힘들', '어', '.'],
#  ['아',
#   '진짜',
#   '근데',
#   '머',
#   '운동',
#   '을',
#   '한다고',
#   '해서',
#   '우리',
#   '가',
#   '막',
#   '뭐',
#   '런닝',
#   '같',
#   '은',
#   '거',
#   '뛴다고',
#   '하',
#   '는데',
#   '런닝',
#   '할',
#   '때',
#   '도',
#   '어떻',
#   '게',
#   '–',
#   '뛰',
#   '-',
#   '어떻게',
#   '뭐',
#   '뭐',
#   '어떻게',
#   '발',
#   '같',
#   '은',
#   '것',
#   '도'],
#  ['알', '고', '보', '니까', '다', '런닝', '에', '도', '자세', '가', '있', '었', '고'],
#  ['그런',
#   '걸',
#   '보',
#   '면서',
#   '아',
#   '운동',
#   '도',
#   '진짜',
#   '이게',
#   '방법',
#   '을',
#   '알',
#   '지',
#   '못하',
#   '면'],
#  ['정말', '힘들', '구나', '라고', '생각', '해'],
#  ['나', '도', '진짜'],
#  ['아', '–', '그', '-', '그러니까', '사람', '들', '이', '다', '굶', '는', '거', '야', '.'],
#  ['그러', '는', '게', '제일', '쉬우', '니까'],
#  ['그게', '제일', '만만', '하', '잖아', '.'],
#  ['그', '운동', '하', '는', '거', '어려우', '니까'],
#  ['그러', '고', '굶', '는', '게', '진짜로', '테', '가', '확', '나', '진짜'],
#  ['갑자기',
#   '하루',
#   '굶',
#   '고',
#   '막',
#   '이틀',
#   '굶',
#   '었',
#   '는데',
#   '이제',
#   '이틀',
#   '간헐',
#   '적',
#   '단식',
#   '하',
#   '니까'],
#  ['인제', '배', '가', '막', '뱃살', '이', '없', '어'],
#  ['그러', '고', '얼굴', '살', '도', '빠져', '있', '고'],
#  ['그럼', '거울', '보', '면서', '만족감', '을', '느끼', '는', '거', '지', '.'],
#  ['근데', '그러면', '힘들', '잖아', '다음', '날'],
#  ['다음',
#   '날',
#   '폭식',
#   '하',
#   '던데',
#   '나',
#   '는',
#   '언제나',
#   '폭식',
#   '을',
#   '부르',
#   '는데',
#   '나',
#   '는',
#   '글',
#   '지'],
#  ['어',
#   '근데',
#   '폭식',
#   '할',
#   '때',
#   '도',
#   '있',
#   '는데',
#   '약간',
#   '좀',
#   '마음',
#   '의',
#   '생각',
#   '을',
#   '다',
#   '잡',
#   '고',
#   '인제',
#   '아',
#   '나',
#   '다이어트',
#   '해야',
#   '되',
#   '겠',
#   '다',
#   '계속',
#   '그렇게',
#   '생각',
#   '하',
#   '면',
#   '되',
#   '긴',
#   '하',
#   '는데'],
#  ['어쩔',
#   '때',
#   '한',
#   '번',
#   '씩',
#   '진짜로',
#   '막',
#   '삘',
#   '받',
#   '아',
#   '가지',
#   '고',
#   '나',
#   '는',
#   '진짜',
#   '고구마',
#   '만',
#   '먹',
#   '다가',
#   '갈치구이',
#   '별로',
#   '좋',
#   '아',
#   '하',
#   '질',
#   '않',
#   '는데',
#   '갈치구이',
#   '먹',
#   '고'],
#  ['근데',
#   '고유',
#   '에',
#   '막',
#   '다이어트',
#   '식단',
#   '이런',
#   '거',
#   '찾아봐도',
#   '막',
#   '되게',
#   '돈',
#   '많이',
#   '들어가',
#   '는',
#   '거',
#   '있',
#   '지'],
#  ['예쁜',
#   '이런',
#   '나무',
#   '볼',
#   '에',
#   '비싼',
#   '고유',
#   '요',
#   '거트',
#   '그런',
#   '거',
#   '해',
#   '가지',
#   '고',
#   '붓',
#   '고',
#   '또',
#   '비싼',
#   '제철',
#   '과일',
#   '이런',
#   '거',
#   '해',
#   '갖',
#   '고',
#   '막',
#   '올려',
#   '놔'],
#  ['우리', '는', '그럴', '돈', '이', '없', '단', '말', '이', '야', '.'],
#  ['우리',
#   '는',
#   '그냥',
#   '편의점',
#   '에서',
#   '천',
#   '오',
#   '백',
#   '원',
#   '씩',
#   '하',
#   '는',
#   '닭',
#   '가슴살',
#   '이런',
#   '거',
#   '사',
#   '다',
#   '먹',
#   '어야',
#   '되',
#   '는',
#   '거',
#   '야',
#   '.'],
#  ['그래서', '어려워', '그래서'],
#  ['아',
#   '근데',
#   '진짜',
#   '대중',
#   '적',
#   '으로',
#   '보여',
#   '지',
#   '는',
#   '그런',
#   '다이어트',
#   '식단',
#   '을',
#   '솔직히',
#   '다',
#   '지키',
#   '잖아',
#   '?'],
#  ['그러면', '진짜', '살', '잘', '빠질', '걸', '?'],
#  ['근데', '맞', '기', '는', '해', '.'],
#  ['연예인', '다이어트', '식단', '이런', '거', '하루', '에', '아침', '에', '양배추', '먹', '고'],
#  ['그',
#   '다음',
#   '에',
#   '뭐',
#   '통밀',
#   '식빵',
#   '이런',
#   '거',
#   '하나',
#   '먹',
#   '고',
#   '그렇게',
#   '하',
#   '면',
#   '빠지',
#   '지'],
#  ['근데', '그건', '진짜', '사람', '사', '는', '게', '아니', '야', '.'],
#  ['다이어트', '가', '근데', '솔직히', '다이어트', '를', '음', '다이어트', '가', '진짜', '어렵', '지만'],
#  ['다이어트',
#   '하',
#   '는',
#   '것',
#   '도',
#   '어렵',
#   '고',
#   '다이어트',
#   '를',
#   '하',
#   '기',
#   '마음',
#   '먹',
#   '기',
#   '까지',
#   '를',
#   '엄청',
#   '어려운데'],
#  ['진짜',
#   '다이어트',
#   '는',
#   '근데',
#   '우리',
#   '가',
#   '평생',
#   '–',
#   '해',
#   '-',
#   '해',
#   '가',
#   '야',
#   '할',
#   '숙제',
#   '숙명',
#   '이',
#   '라고',
#   '생각',
#   '해',
#   '가지',
#   '고',
#   '어쩔',
#   '수',
#   '가',
#   '없',
#   '는',
#   '것',
#   '같',
#   '다',
#   '진짜'],
#  ['맞아',
#   '그리고',
#   '이게',
#   '또',
#   '고유',
#   '옆',
#   '에',
#   '있',
#   '는',
#   '애',
#   '가',
#   '나',
#   '랑',
#   '좀',
#   '비슷비슷',
#   '했',
#   '어',
#   '.'],
#  ['근데', '걔', '가', '빠지', '잖아', '?'],
#  ['그럼', '인제', '그때', '부터', '엄청난', '자극', '이', '온다고'],
#  ['아',
#   '진짜',
#   '옆',
#   '에',
#   '애',
#   '들',
#   '이',
#   '막',
#   '솔직히',
#   '다',
#   '인제',
#   '갑자기',
#   '인제',
#   '고',
#   '삼',
#   '때',
#   '까지',
#   '는',
#   '인제'],
#  ['다',
#   '같이',
#   '인제',
#   '맨날',
#   '그',
#   '머',
#   '급식',
#   '먹',
#   '고',
#   '인제',
#   '그',
#   '맨날',
#   '같이',
#   '급식',
#   '먹',
#   '고',
#   '매점',
#   '가',
#   '니까'],
#  ['인제',
#   '다',
#   '인제',
#   '살',
#   '이',
#   '이렇게',
#   '올라',
#   '있',
#   '는데',
#   '인제',
#   '나중',
#   '에',
#   '한',
#   '육',
#   '개월',
#   '뒤',
#   '쯤',
#   '에',
#   '봐'],
#  ['근데',
#   '갑자기',
#   '뭐',
#   '살',
#   '이',
#   '엄청',
#   '빠져',
#   '있',
#   '어',
#   '그러',
#   '면',
#   '나',
#   '도',
#   '엄청',
#   '자괴감',
#   '들',
#   '고'],
#  ['아', '나', '도', '진짜', '난', '육', '개월', '동안', '뭐', '했', '지', '?'],
#  ['나',
#   '도',
#   '진짜',
#   '살',
#   '빼',
#   '야',
#   '되',
#   '겠',
#   '다',
#   '약간',
#   '이런',
#   '생각',
#   '진짜',
#   '많이',
#   '들',
#   '어',
#   '.'],
#  ['아',
#   '근데',
#   '나',
#   '는',
#   '다',
#   '해',
#   '봤',
#   '을',
#   '때',
#   '솔직히',
#   '돈',
#   '은',
#   '많이',
#   '들어도',
#   '피티',
#   '가',
#   '제일',
#   '좋',
#   '은',
#   '것',
#   '같',
#   '고'],
#  ['피티', '끝', '나', '고', '아니', '면', '헬스'],
#  ['근데',
#   '스',
#   '피닝',
#   '은',
#   '스',
#   '피닝',
#   '은',
#   '내',
#   '가',
#   '진짜',
#   '한',
#   '번',
#   '하',
#   '고',
#   '다리',
#   '후',
#   '들',
#   '거려',
#   '가지',
#   '고',
#   '바로',
#   '막',
#   '난리',
#   '났거든',
#   '?'],
#  ['근데', '너', '는', '스', '피닝', '엄청', '잘', '하', '잖아', '.'],
#  ['아',
#   '나',
#   '도',
#   '근데',
#   '스',
#   '피닝',
#   '을',
#   '내',
#   '가',
#   '좀',
#   '나',
#   '도',
#   '원래',
#   '옛날',
#   '부터'],
#  ['운동',
#   '을',
#   '진짜',
#   '내',
#   '가',
#   '운동',
#   '을',
#   '어렸',
#   '을',
#   '때',
#   '부터',
#   '아빠',
#   '랑',
#   '맨날',
#   '해',
#   '봐',
#   '가지',
#   '고'],
#  ['아', '나', '운동', '잘', '한다', '약간', '이런', '생각', '을', '가지', '고', '있', '었', '는데'],
#  ['스',
#   '피닝',
#   '타',
#   '니까',
#   '막',
#   '앞',
#   '에서',
#   '있',
#   '는',
#   '아줌마',
#   '들',
#   '이',
#   '막',
#   '엄청',
#   '이렇게',
#   '하',
#   '면서'],
#  ['하',
#   '고',
#   '있',
#   '어',
#   '가지',
#   '고',
#   '나',
#   '도',
#   '근데',
#   '처음',
#   '에',
#   '는',
#   '진짜',
#   '힘들',
#   '었',
#   '어',
#   '.'],
#  ['근데',
#   '어쩔',
#   '수',
#   '없이',
#   '해야지',
#   '약간',
#   '이런',
#   '생각',
#   '때문',
#   '에',
#   '했',
#   '는데',
#   '나',
#   '는',
#   '솔직히',
#   '피티',
#   '가',
#   '더',
#   '힘들',
#   '거',
#   '같',
#   '은데'],
#  ['아', '스', '피닝', '은', '단기간', '으로', '해도', '효과', '가', '좀', '쩔', '잖아'],
#  ['이', '좀', '효과', '가', '좋', '잖아', '이게'],
#  ['아',
#   '근데',
#   '–',
#   '피',
#   '-',
#   '스',
#   '피닝',
#   '은',
#   '좀',
#   '단기간',
#   '에',
#   '하',
#   '면은',
#   '효과',
#   '가',
#   '좋',
#   '긴',
#   '좋',
#   '아',
#   '.'],
#  ['근데',
#   '인제',
#   '그거',
#   '를',
#   '스',
#   '피닝',
#   '을',
#   '안',
#   '하',
#   '고',
#   '있',
#   '으면',
#   '인제',
#   '확실히',
#   '그게',
#   '엄청',
#   '칼로리',
#   '태우',
#   '니까'],
#  ['인제',
#   '스',
#   '피닝',
#   '을',
#   '끝내',
#   '고',
#   '안',
#   '하',
#   '면',
#   '인제',
#   '살',
#   '이',
#   '다시',
#   '쪄',
#   '.'],
#  ['어쩔', '수', '가', '없', '어', '이거', '는'],
#  ['아',
#   '근데',
#   '아줌마',
#   '들',
#   '이',
#   '막',
#   '옆',
#   '에서',
#   '겁나',
#   '해',
#   '블',
#   '면',
#   '막',
#   '하',
#   '기',
#   '싫',
#   '어',
#   '지',
#   '더라',
#   '.'],
#  ['막', '하', '기', '싫', '어', '브', '러', '막'],
#  ['왜냐믄',
#   '나',
#   '는',
#   '잘',
#   '못',
#   '하',
#   '는데',
#   '옆',
#   '에서',
#   '막',
#   '겁나',
#   '막',
#   '다리',
#   '막',
#   '겁나',
#   '하',
#   '니까',
#   '난',
#   '잘',
#   '못',
#   '하',
#   '니까'],
#  ['막', '약간', '위축', '되', '갖', '고', '막', '하', '기', '싫', '어', '.'],
#  ['근데',
#   '진짜',
#   '나',
#   '도',
#   '원래',
#   '처음',
#   '에',
#   '진짜',
#   '막',
#   '고유',
#   '고유',
#   '눈치',
#   '까지',
#   '봤',
#   '어',
#   '.'],
#  ['계속',
#   '헬스',
#   '트레이너',
#   '눈치',
#   '까지',
#   '봤',
#   '는데',
#   '인제',
#   '딱히',
#   '그런',
#   '거',
#   '신경',
#   '안',
#   '쓰',
#   '고'],
#  ['어차피', '혼자', '가', '도', '신경', '쓰', '는', '사람', '아무', '도', '없', '더라고'],
#  ['그래서',
#   '인제',
#   '아',
#   '이거',
#   '어차피',
#   '살',
#   '뺄',
#   '거',
#   '나',
#   '혼자',
#   '열심히',
#   '해서',
#   '빼',
#   '자',
#   '약간',
#   '이런',
#   '생각',
#   '으로'],
#  ['처음',
#   '엔',
#   '눈치',
#   '엄청',
#   '봤었',
#   '는데',
#   '인제',
#   '나중',
#   '에',
#   '는',
#   '별로',
#   '눈치',
#   '안',
#   '보',
#   '고',
#   '막',
#   '옆',
#   '에서',
#   '열심히',
#   '해도',
#   '나',
#   '도',
#   '약간',
#   '좀',
#   '경쟁심',
#   '붙',
#   '어',
#   '가지',
#   '고'],
#  ['와',
#   '나',
#   '도',
#   '열심히',
#   '해야',
#   '되',
#   '겠',
#   '다',
#   '막',
#   '쉬',
#   '면',
#   '안',
#   '된다',
#   '하',
#   '면서',
#   '막',
#   '계속',
#   '하',
#   '고',
#   '약간',
#   '그랬',
#   '던',
#   '것',
#   '같',
#   '다',
#   '.'],
#  ['아', '근데', '다이어트', '방법', '이', '너무', '많', '아', '.'],
#  ['아',
#   '좀',
#   '쪼끔',
#   '–',
#   '한',
#   '-',
#   '한두',
#   '개',
#   '만',
#   '있',
#   '어도',
#   '내',
#   '가',
#   '이거',
#   '할까',
#   '저거',
#   '할',
#   '깐',
#   '데',
#   '너무',
#   '많',
#   '으니깐'],
#  ['이거',
#   '해야',
#   '되',
#   '나',
#   '저거',
#   '해야',
#   '되',
#   '나',
#   '그래',
#   '가지',
#   '고',
#   '너무',
#   '헷갈려',
#   '진짜',
#   '로'],
#  ['너무', '방법', '이', '한', '수백', '수천', '가지', '는', '되', '는', '것', '같', '애', '.'],
#  ['아', '그치', '.'],
#  ['근데', '다이어트', '방법', '정말', '많', '지만', '최대한', '건강', '하', '게', '진짜', '머리', '가'],
#  ['나',
#   '는',
#   '다이어트',
#   '를',
#   '했',
#   '는데',
#   '이제',
#   '–',
#   '간',
#   '-',
#   '나',
#   '도',
#   '간헐',
#   '적',
#   '단식',
#   '이',
#   '라고',
#   '진짜',
#   '열심히'],
#  ['막',
#   '일',
#   '일',
#   '일식',
#   '까지',
#   '하',
#   '고',
#   '했',
#   '는데',
#   '머리',
#   '가',
#   '빠지',
#   '는',
#   '거',
#   '야',
#   '.'],
#  ['그래', '가지', '고', '아오', '진짜', '안', '되', '겠', '다'],
#  ['그래서', '진짜', '건강', '하', '게', '해야', '될', '것', '같', '아', '다이어트', '는'],
#  ['맞', '아', '그거', '진짜', '고유', '야', '.'],
#  ['근데', '이게', '좀', '어려운', '게', '막', '고유', '다이어트', '이런', '거', '알', '지'],
#  ['인터넷', '치', '면', '겁나', '많이', '나온다고', '이게'],
#  ['고유', '다이어트', '레몬', '고유', '다이어트', '막', '이렇게', '해', '가지', '고'],
#  ['근데',
#   '그런',
#   '거',
#   '보',
#   '면은',
#   '하루',
#   '에',
#   '한',
#   '잔',
#   '만',
#   '마시',
#   '면',
#   '오',
#   '키',
#   '로',
#   '씩',
#   '빠집니다',
#   '막',
#   '이러',
#   '니까'],
#  ['솔직히', '말', '하', '면', '한', '번', '해', '보', '고', '싶', '긴', '하', '지'],
#  ['돈', '주', '고', '사', '보', '고', '싶', '긴', '하', '더라', '다이어트', '때문', '에'],
#  ['아',
#   '근데',
#   '다이어트',
#   '가',
#   '뭐',
#   '엄청',
#   '우리',
#   '가',
#   '매체',
#   '같',
#   '은',
#   '거',
#   '봐도',
#   '진짜로',
#   '진짜',
#   '상업',
#   '적',
#   '인',
#   '광고',
#   '가',
#   '너무',
#   '많',
#   '아',
#   '.'],
#  ['막', '뭐', '고유', '다이어트', '아까', '말', '했', '듯이', '?'],
#  ['그런',
#   '것',
#   '도',
#   '엄청',
#   '많',
#   '고',
#   '근데',
#   '실질',
#   '적',
#   '인',
#   '다이어트',
#   '방법',
#   '은',
#   '우리',
#   '가',
#   '다',
#   '알',
#   '고'],
#  ['그냥',
#   '적',
#   '게',
#   '먹',
#   '고',
#   '많이',
#   'xx',
#   '하',
#   '는',
#   '거',
#   '고',
#   '그냥',
#   '그렇게',
#   '하',
#   '면은',
#   '되',
#   '는데',
#   '진짜',
#   '그런',
#   '광고',
#   '같',
#   '은',
#   '것',
#   '도',
#   '엄청',
#   '많',
#   '으니까'],
#  ['아', '나', '이거', '해', '볼까', '?'],
#  ['막',
#   '고유',
#   '같',
#   '은데',
#   '도',
#   '막',
#   '칼',
#   '로',
#   '커트',
#   '막',
#   '이런',
#   '거',
#   '뜨',
#   '니까',
#   '아',
#   '나',
#   '이거',
#   '해',
#   '볼까',
#   '하',
#   '는데'],
#  ['금액',
#   '적',
#   '인',
#   '부분',
#   '도',
#   '그렇',
#   '고',
#   '어',
#   '좀',
#   '이',
#   '방법',
#   '도',
#   '아닌가',
#   '약간',
#   '자중',
#   '하',
#   '는',
#   '그런',
#   '?'],
#  ['그런', '게', '있', '지', '.'],
#  ['맞', '아', '인정', '이', '요', '그건', '그거', '는', '인정', '이', '요', '.'],
#  ['방법',
#   '은',
#   '다',
#   '알',
#   '어',
#   '다',
#   '안',
#   '디',
#   '인제',
#   '그냥',
#   '해',
#   '보',
#   '고',
#   '싶',
#   '어',
#   '.'],
#  ['저거',
#   '하',
#   '면',
#   '빨리',
#   '빠질',
#   '것',
#   '같',
#   '거든',
#   '근데',
#   '저거',
#   '약간',
#   '사기',
#   '인',
#   '건',
#   '나',
#   '도',
#   '아',
#   '는',
#   '데',
#   '하',
#   '는',
#   '거',
#   '지'],
#  ['맞', '아', '.'],
#  ['근데',
#   '또',
#   '막상',
#   '오',
#   '면은',
#   '인제',
#   '또',
#   '안',
#   '먹',
#   '고',
#   '있',
#   '다가',
#   '아',
#   '나',
#   '이때',
#   '부터',
#   '먹',
#   '어야지',
#   '하',
#   '는데',
#   '또',
#   '인제',
#   '그게',
#   '반복',
#   '이',
#   '되',
#   '는',
#   '거',
#   '지'],
#  ['아',
#   '이때',
#   '부터',
#   '먹',
#   '어야지',
#   '했',
#   '는데',
#   '옆',
#   '에서',
#   '는',
#   '야',
#   '먹',
#   '어',
#   '먹',
#   '어',
#   '막',
#   '그러니까',
#   '계속',
#   '이게',
#   '반복',
#   '되',
#   '고'],
#  ['그래',
#   '가지',
#   '고',
#   '인제',
#   '그',
#   '다이어트',
#   '약',
#   '은',
#   '인제',
#   '유통',
#   '기한',
#   '지나',
#   '서',
#   '버릴',
#   '수',
#   '밖에',
#   '없',
#   '고'],
#  ['인제', '나', '는', '살쪄', '있', '고', '그러니까', '좀', '스트레스', '받', '아', '.'],
#  ['맞', '아', '.'],
#  ['다이어트', '진짜', '옆', '에서', '뭐', '라', '하', '면', '더', '힘들', '어', '근데'],
#  ['막',
#   '어',
#   '니',
#   '운동',
#   '한디',
#   '왜',
#   '안',
#   '빠졌',
#   '냐',
#   '이러',
#   '면',
#   '할',
#   '말',
#   '없',
#   '어',
#   '.'],
#  ['아',
#   '근데',
#   '진짜',
#   '옆',
#   '에',
#   '사람',
#   '들',
#   '은',
#   '진짜',
#   '다이어트',
#   '할',
#   '때',
#   '진짜',
#   '중요',
#   '한',
#   '거',
#   '같',
#   '긴',
#   '해',
#   '.'],
#  ['막',
#   '가족',
#   '들',
#   '같',
#   '은',
#   '경우',
#   '에',
#   '도',
#   '막',
#   '옆',
#   '에서',
#   '막',
#   '운동',
#   '하',
#   '고',
#   '집',
#   '에',
#   '왔',
#   '는데'],
#  ['어', '&', 'name', '1', '&', '야', '너', '엄청', '많이', '살', '빠졌', '다', '그러', '면'],
#  ['어', '맞', '아', '.'],
#  ['엄청',
#   '행복',
#   '한데',
#   '막',
#   '옆',
#   '에서',
#   '어느',
#   '순간',
#   '부터',
#   '&',
#   'name',
#   '1',
#   '&',
#   '야',
#   '너',
#   '왜',
#   '살',
#   '이',
#   '안',
#   '빠지',
#   '냐'],
#  ['약간',
#   '엄마',
#   '가',
#   '이러',
#   '면',
#   '엄청',
#   '스트레스',
#   '받',
#   '아',
#   '가지',
#   '고',
#   '아',
#   '나',
#   '는',
#   '나라',
#   '는',
#   '사람',
#   '은',
#   '열심히',
#   '하',
#   '는데'],
#  ['왜', '안', '빠질까', '약간', '이런', '생각', '이', '겹쳐지', '면서'],
#  ['인제', '그게', '훨씬', '힘들', '어', '그때'],
#  ['약간',
#   '나',
#   '는',
#   '운동',
#   '하',
#   '믄서',
#   '스트레스',
#   '풀',
#   '라는',
#   '것',
#   '도',
#   '있',
#   '긴',
#   '한데'],
#  ['운동',
#   '이',
#   '아니',
#   '라',
#   '다이어트',
#   '다',
#   '생각',
#   '을',
#   '하',
#   '면은',
#   '그때',
#   '부터',
#   '스트레스',
#   '를',
#   '받',
#   '는',
#   '것',
#   '같',
#   '애',
#   '.'],
#  ['생각',
#   '을',
#   '안',
#   '해야',
#   '되',
#   '는데',
#   '다이어트',
#   '라고',
#   '내',
#   '가',
#   '딱',
#   '인식',
#   '을',
#   '해',
#   '버리',
#   '니까'],
#  ['그니까', '다이어트', '가', '진짜로', '뭐', '라', '해야', '되', '지'],
#  ['다이어트',
#   '라는',
#   '게',
#   '자체',
#   '가',
#   '솔직히',
#   '엄청난',
#   '스트레스',
#   '있',
#   '고',
#   '엄청',
#   '막',
#   '해야',
#   '될',
#   '것',
#   '같',
#   '고'],
#  ['그래',
#   '진짜',
#   '운동',
#   '할',
#   '때',
#   '도',
#   '나',
#   '도',
#   '운동',
#   '하',
#   '면서',
#   '진짜',
#   '재밌',
#   '었',
#   '거든',
#   '?'],
#  ['그냥',
#   '뭐',
#   '스',
#   '피닝',
#   '타도',
#   '막',
#   '음악',
#   '틀',
#   '어',
#   '주',
#   '면서',
#   '인제',
#   '막',
#   '하',
#   '니까',
#   '?'],
#  ['근데',
#   '다이어트',
#   '라는',
#   '게',
#   '인제',
#   '다이어트',
#   '를',
#   '해야',
#   '된다',
#   '생각',
#   '하',
#   '니까',
#   '확실히',
#   '인제',
#   '아침',
#   '마다',
#   '맨날',
#   '몸무게',
#   '재야',
#   '되',
#   '고'],
#  ['인제', '식단', '같', '은', '것', '도', '철저', '하', '게', '지켜야', '되', '고', '이러', '니까'],
#  ['더',
#   '크',
#   '게',
#   '생각',
#   '하',
#   '니까',
#   '나',
#   '한테',
#   '너무',
#   '이렇게',
#   '날',
#   '압박',
#   '하',
#   '는',
#   '것',
#   '같',
#   '다',
#   '?'],
#  ['약간', '이런', '생각', '도', '들', '어', '.'],
#  ['그리고',
#   '헬스',
#   '장',
#   '가',
#   '면은',
#   '진짜',
#   '몸',
#   '좋',
#   '은',
#   '사람',
#   '들',
#   '이',
#   '너무',
#   '많',
#   '으니까'],
#  ['그거', '보', '고', '이제', '짜증', '나', '는', '거', '지'],
#  ['스트레스', '받', '고'],
#  ['나',
#   '신경',
#   '쓰',
#   '면',
#   '어떡',
#   '하',
#   '지',
#   '난',
#   '몸',
#   '별로',
#   '안',
#   '좋',
#   '은데',
#   '나',
#   '쳐다보',
#   '면',
#   '어떡',
#   '하',
#   '지',
#   '막',
#   '그러',
#   '니까'],
#  ['헬스', '할', '때', '또', '레깅스', '얼마나', '많이', '사', '야', '돼'],
#  ['레깅스',
#   '도',
#   '사',
#   '야',
#   '돼',
#   '운동',
#   '화',
#   '도',
#   '사',
#   '야',
#   '돼',
#   '피트',
#   '니스',
#   '복',
#   '도',
#   '사',
#   '야',
#   '돼'],
#  ['이러', '니까', '너무', '그게', '좀', '돈', '도', '많이', '들', '기', '는', '해', '솔직히'],
#  ['아', '진짜', '맞', '아', '.'],
#  ['그리고',
#   '좀',
#   '약간',
#   '내',
#   '가',
#   '다이어트',
#   '하',
#   '다가',
#   '약간',
#   '좀',
#   '제일',
#   '민망',
#   '했',
#   '을',
#   '때',
#   '민망',
#   '했',
#   '을',
#   '때',
#   '는'],
#  ['그',
#   '헬스',
#   '장',
#   '갔',
#   '는데',
#   '아',
#   '는',
#   '사람',
#   '을',
#   '만났',
#   '을',
#   '때',
#   '그때',
#   '제일',
#   '민망',
#   '했',
#   '어'],
#  ['친구', '헬스', '만났', '는데', '갑자기', '어', '안녕', '어', '이런', '식', '으로'],
#  ['서로', '약간', '눈치', '보', '게', '되', '잖아'],
#  ['어', '너', '도', '어', '나', '도'],
#  ['근데', '다이어트', '할', '때', '같이', '하', '는', '친구', '가', '있', '는', '게'],
#  ['나',
#   '는',
#   '솔직히',
#   '그게',
#   '진짜',
#   '진짜',
#   '필요',
#   '하',
#   '다고',
#   '생각',
#   '해',
#   '그게',
#   '좋',
#   '고',
#   '진짜'],
#  ['옆',
#   '에서',
#   '같이',
#   '해',
#   '주',
#   '는',
#   '사람',
#   '이',
#   '있',
#   '으면',
#   '인제',
#   '같이',
#   '하',
#   '니까',
#   '그래도',
#   '안',
#   '덜',
#   '민망',
#   '하',
#   '고'],
#  ['헬스',
#   '장',
#   '갈',
#   '때',
#   '몸매',
#   '좋',
#   '은',
#   '사람',
#   '들',
#   '몸매',
#   '좋',
#   '은',
#   '사람',
#   '들',
#   '도',
#   '많',
#   '은데'],
#  ['그리고',
#   '인제',
#   '같이',
#   '하',
#   '니까',
#   '아',
#   '얘',
#   '도',
#   '안',
#   '먹',
#   '는데',
#   '나',
#   '도',
#   '안',
#   '먹',
#   '어야',
#   '되',
#   '겠',
#   '다'],
#  ['약간',
#   '이런',
#   '생각',
#   '때문',
#   '에',
#   '같이',
#   '하',
#   '는',
#   '사람',
#   '도',
#   '있',
#   '는',
#   '것',
#   '도',
#   '추천',
#   '완전',
#   '.'],
#  ['근데', '나', '는', '같이', '하', '면은', '같이', '먹', '으러', '다니', '더라', '.'],
#  ['그래서', '그게', '안', '좋', '아', '.'],
#  ['살', '못', '빼', '고', '계속', '같이', '찌', '기', '만', '하', '니까', '.'],
#  ['아', '진짜로', '그런', '경우', '도', '많이', '봤', '어', '.'],
#  ['근데',
#   '나',
#   '는',
#   '&',
#   'name',
#   '2',
#   '&',
#   '이',
#   '랑',
#   '같이',
#   '다녔',
#   '을',
#   '때',
#   '랑',
#   '우리',
#   '끼리',
#   '내',
#   '기',
#   '해',
#   '가지',
#   '고',
#   '막',
#   '하',
#   '니까'],
#  ['난',
#   '나름',
#   '괜찮',
#   '긴',
#   '했',
#   '는데',
#   '확실히',
#   '이렇게',
#   '잡',
#   '아',
#   '주',
#   '는',
#   '사람',
#   '이',
#   '있',
#   '어야지'],
#  ['진짜', '할', '때', '필요', '한', '것', '같', '아', '다이어트', '할', '때', '친구', '있', '어도'],
#  ['확실히',
#   '피티',
#   '받',
#   '아',
#   '보',
#   '니까',
#   '옆',
#   '에서',
#   '확실히',
#   '좀',
#   '건들',
#   '어',
#   '주',
#   '는',
#   '사람',
#   '이',
#   '있',
#   '어야',
#   '좀',
#   '하',
#   '는',
#   '걸',
#   '느끼',
#   '게',
#   '되',
#   '긴',
#   '하',
#   '더라',
#   '약간'],
#  ['맞아', '근데', '나', '는', '솔직히', '개인', '적', '으로', '다이어트', '를', '할', '때'],
#  ['무조건',
#   '헬스',
#   '장',
#   '에',
#   '가',
#   '서',
#   '갔',
#   '헬스',
#   '장',
#   '에',
#   '가',
#   '야',
#   '된다는',
#   '입장',
#   '이',
#   '거든',
#   '?'],
#  ['왜냐하면은', '일단', '나', '같', '은', '경우', '에', '도', '혼자', '서', '마음먹', '고', '인제'],
#  ['아침',
#   '마다',
#   '줄넘기',
#   '천',
#   '개',
#   '씩',
#   '해야지',
#   '약간',
#   '이런',
#   '생각',
#   '해도',
#   '잘',
#   '안',
#   '되',
#   '니까'],
#  ['차라리', '다', '같이', '이렇게', '하', '는', '게', '좋', '겠', '다고', '생각', '해'],
#  ['맞',
#   '아',
#   '헬스',
#   '장',
#   '에',
#   '가',
#   '는',
#   '게',
#   '좋',
#   '기',
#   '는',
#   '해',
#   '막',
#   '운동장',
#   '가',
#   '갖',
#   '고',
#   '달리기',
#   '하',
#   '는',
#   '애',
#   '도',
#   '있',
#   '고'],
#  ['그냥',
#   '막',
#   '걷',
#   '기',
#   '하',
#   '는',
#   '애',
#   '도',
#   '있',
#   '고',
#   '등산',
#   '하',
#   '는',
#   '애',
#   '도',
#   '있',
#   '는데'],
#  ['솔직히', '막', '헬스', '장', '가', '는', '게', '제일', '효과', '적', '이', '긴', '하', '지'],
#  ['그거', '되게', '싫', '어', '하', '는', '애', '들', '도', '있', '잖아'],
#  ['아', '근데', '나', '도', '처음', '에', '다이어트', '를', '시작', '했', '을', '때'],
#  ['헬스',
#   '장',
#   '가',
#   '는',
#   '것',
#   '자체',
#   '가',
#   '엄청나',
#   '게',
#   '큰',
#   '진입',
#   '장벽',
#   '이',
#   '었',
#   '어',
#   '약간'],
#  ['왜냐하면',
#   '거기',
#   '에',
#   '진짜',
#   '몸매',
#   '좋',
#   '은',
#   '사람',
#   '들',
#   '도',
#   '많',
#   '고',
#   '약간',
#   '선입견',
#   '이',
#   '좀',
#   '있',
#   '었',
#   '던',
#   '것',
#   '같',
#   '아'],
#  ['내', '가', '가', '면은', '위축', '되', '면서', '아', '나', '혼자', '살쪘', '는데', '?'],
#  ['약간', '이런', '생각', '하', '게', '된단', '말', '이', '야'],
#  ['근데',
#   '확실히',
#   '일단',
#   '은',
#   '질러',
#   '보',
#   '고',
#   '해',
#   '하',
#   '는',
#   '게',
#   '나을',
#   '것',
#   '같',
#   '아',
#   '.'],
#  ['다이어트', '는', '진짜', '헬스', '장', '무조건', '가', '가지', '고'],
#  ['아',
#   '그',
#   '다이어트',
#   '가',
#   '약간',
#   '그냥',
#   '살',
#   '빼',
#   '는',
#   '것',
#   '도',
#   '중요',
#   '하',
#   '긴',
#   '한데'],
#  ['진짜', '건강', '하', '게', '사', '는', '게', '중요', '하', '긴', '하', '더라', '.'],
#  ['운동', '몇', '달', '해', '보', '고', '느낀', '게', '진짜로', '중요', '한', '게', '있', '는데'],
#  ['진짜',
#   '운동',
#   '하',
#   '면은',
#   '몸',
#   '테',
#   '가',
#   '달라지',
#   '는',
#   '것',
#   '도',
#   '달라지',
#   '는',
#   '건데'],
#  ['애초',
#   '에',
#   '있',
#   '었',
#   '던',
#   '질병',
#   '같',
#   '은',
#   '것',
#   '도',
#   '사라지',
#   '고',
#   '내',
#   '몸',
#   '자체',
#   '가',
#   '되게',
#   '건강',
#   '해져',
#   '.'],
#  ['삶', '도', '건강', '해', '지', '고'],
#  ['나',
#   '도',
#   '거기',
#   '진짜',
#   '동의',
#   '하',
#   '는',
#   '게',
#   '나',
#   '같',
#   '은',
#   '경우',
#   '만',
#   '해도',
#   '막',
#   '뭐',
#   '여섯',
#   '시',
#   '저녁',
#   '에'],
#  ['뭐',
#   '여덟',
#   '시',
#   '이후',
#   '에',
#   '뭐',
#   '먹',
#   '어도',
#   '자기',
#   '전',
#   '에',
#   '부대낌',
#   '있',
#   '고',
#   '몸',
#   '자체',
#   '가'],
#  ['몸', '자체', '가', '?'],
#  ['근데', '다이어트', '를', '하', '니까', '인제', '적', '게', '먹', '으니까'],
#  ['확실히', '인제', '위', '같', '은', '것', '도', '나', '만', '느끼', '는', '건지'],
#  ['나',
#   '혼자',
#   '그냥',
#   '느끼',
#   '는',
#   '걸',
#   '수',
#   '도',
#   '있',
#   '는데',
#   '그냥',
#   '딱',
#   '느꼈',
#   '을',
#   '때'],
#  ['막',
#   '포만감',
#   '도',
#   '막',
#   '엄청',
#   '많',
#   '지',
#   '않',
#   '으니까',
#   '그래서',
#   'xx',
#   'xxx',
#   '도',
#   '나름',
#   '대로',
#   '높',
#   '아',
#   '지',
#   '고'],
#  ['피부',
#   '같',
#   '은',
#   '것',
#   '도',
#   '엄청',
#   '땀',
#   '흘리',
#   '니까',
#   '피부',
#   '가',
#   '여드름',
#   '같',
#   '은',
#   '것',
#   '도',
#   '많이',
#   '없',
#   '어',
#   '지',
#   '고'],
#  ['그래서',
#   '나',
#   '는',
#   '다이어트',
#   '가',
#   '확실히',
#   '몸',
#   '에',
#   '많',
#   '은',
#   '영향',
#   '을',
#   '미치',
#   '구나',
#   '생각',
#   '해',
#   '.'],
#  ['맞아',
#   '그리고',
#   '약간',
#   '기분',
#   '도',
#   '좋',
#   '아',
#   '운동',
#   '딱',
#   '하',
#   '고',
#   '들어오',
#   '면',
#   '기분',
#   '이',
#   '좋',
#   '아',
#   '.'],
#  ['그',
#   '다이어트',
#   '진짜',
#   '힘든',
#   '거',
#   '는',
#   '다이어트',
#   '하',
#   '기',
#   '전',
#   '에',
#   '는',
#   '운동',
#   '해도',
#   '힘들',
#   '다고',
#   '생각',
#   '하',
#   '는데'],
#  ['다이어트',
#   '시작',
#   '하',
#   '고',
#   '나',
#   '면',
#   '운동',
#   '이',
#   '훨씬',
#   '괜찮',
#   '고',
#   '식단',
#   '이',
#   '진짜',
#   '힘들',
#   '어',
#   '.'],
#  ['아', '진짜', '식단', '이', '근데', '진짜', '확실히', '운동', '은', '그냥', '같이', '하', '니까'],
#  ['아까', '말', '했', '듯이', '그냥', '다', '같이', '하', '니까', '운동', '은', '해', '.'],
#  ['근데',
#   '식단',
#   '은',
#   '인제',
#   '와',
#   '진짜로',
#   '이게',
#   '유혹',
#   '에',
#   '못',
#   '유혹',
#   '에',
#   '자꾸',
#   '넘어가',
#   '니까'],
#  ['자꾸', '집', '에', '집', '에', '있', '으면', '더', '안', '될', '것', '같', '아', '.'],
#  ['집',
#   '에',
#   '는',
#   '맛있',
#   '는',
#   '거',
#   '계속',
#   '많',
#   '으니까',
#   '일부러',
#   '밖',
#   '에',
#   '나가',
#   '야',
#   '될',
#   '것',
#   '같',
#   '애',
#   '.'],
#  ['그래서', '더', '다이어트', '에서', '식단', '이', '진짜', '중요', '하', '다고'],
#  ['그', '인터넷', '에', '치', '면은', '고유', '고유', '고유', '이런', '거', '해', '가지', '고'],
#  ['도시락',
#   '한',
#   '나',
#   '에',
#   '막',
#   '뭐',
#   '얼마',
#   '해',
#   '가지',
#   '고',
#   '묶음',
#   '으로',
#   '해',
#   '가지',
#   '고',
#   '판단',
#   '말',
#   '이',
#   '야',
#   '.'],
#  ['근데',
#   '그런',
#   '건',
#   '이게',
#   '내',
#   '가',
#   '먹',
#   '어',
#   '본',
#   '결과',
#   '우선',
#   '비싸',
#   '우선',
#   '비싸',
#   '고',
#   '두',
#   '번',
#   '째',
#   '는',
#   '질려'],
#  ['그래서',
#   '사람',
#   '이',
#   '메뉴',
#   '를',
#   '맨날',
#   '맨날',
#   '바꿔',
#   '줘야',
#   '되',
#   '는데',
#   '또',
#   '그걸',
#   '바꿔',
#   '갖',
#   '고',
#   '사',
#   '기',
#   '는',
#   '힘드',
#   '니까',
#   '맞',
#   '아',
#   '.'],
#  ['그래서', '힘들', '어', '진짜', '.'],
#  ['그게',
#   '진짜',
#   '막',
#   '맨날',
#   '닭',
#   '가슴살',
#   '솔직히',
#   '나',
#   '닭',
#   '가슴살',
#   '진짜',
#   '좋',
#   '아',
#   '했었',
#   '는데'],
#  ['맨날',
#   '닭',
#   '가슴살',
#   '만',
#   '먹',
#   '으니까',
#   '막',
#   '닭',
#   '비린내',
#   '나',
#   '는',
#   '것',
#   '같',
#   '고',
#   '입',
#   '에서'],
#  ['그래', '가지', '고', '이제', '닭', '가슴살', '은', '진짜', '나', '못', '먹', '겠', '어', '.'],
#  ['나', '인제', '는', '더', '못', '먹', '겠', '어', '다이어트', '할', '때'],
#  ['내',
#   '가',
#   '한참',
#   '해',
#   '보',
#   '니까',
#   '식단',
#   '도',
#   '약간',
#   '여러',
#   '개',
#   '가',
#   '있',
#   '는',
#   '거',
#   '야'],
#  ['약간',
#   '뭐',
#   '맨날',
#   '닭',
#   '가슴살',
#   '만',
#   '안',
#   '먹',
#   '어도',
#   '되',
#   '고',
#   '이거',
#   '다른',
#   '단백질',
#   '먹',
#   '어도',
#   '되',
#   '기',
#   '는',
#   '하',
#   '는데'],
#  ['그런', '걸', '내', '가', '요리', '해서', '먹', '기', '가', '힘드', '니까', '그런', '거', '지'],
#  ['되게',
#   '맛있',
#   '게',
#   '먹',
#   '는',
#   '사람',
#   '은',
#   '식단',
#   '되게',
#   '맛있',
#   '게',
#   '해서',
#   '먹',
#   '더라',
#   '.'],
#  ['맞',
#   '아',
#   '나',
#   '도',
#   '그걸',
#   '느꼈',
#   '던',
#   '게',
#   '막',
#   '아보카도',
#   '같',
#   '은',
#   '거',
#   '썰',
#   '어',
#   '넣',
#   '어',
#   '가지',
#   '고',
#   '막',
#   '그러',
#   '는데'],
#  ['솔직히',
#   '우린',
#   '학생',
#   '이',
#   '라서',
#   '엄마',
#   '한테',
#   '그걸',
#   '다',
#   '사',
#   '달',
#   '라고',
#   '할',
#   '수',
#   '도',
#   '없',
#   '고'],
#  ['그래',
#   '가지',
#   '고',
#   '나',
#   '는',
#   '그냥',
#   '진짜',
#   '간단',
#   '하',
#   '게',
#   '고유',
#   '랑',
#   '달걀',
#   '이런',
#   '거',
#   '닭',
#   '가슴살',
#   '같',
#   '은',
#   '거'],
#  ['근데',
#   '나',
#   '는',
#   '다이어트',
#   '다',
#   '하',
#   '면',
#   '제일',
#   '찍',
#   '어',
#   '보',
#   '고',
#   '싶',
#   '은',
#   '거',
#   '는',
#   '바디',
#   '프로필',
#   '다이어트',
#   '하',
#   '면',
#   '진짜',
#   '많이',
#   '찍',
#   '잖아',
#   '.'],
#  ['요즘', '은', '다이어트', '?'],
#  ['하', '면은', '무조건', '바디', '프로필', '이렇게', '해', '가지', '고', '하', '니까'],
#  ['그런',
#   '거',
#   '보',
#   '면은',
#   '더',
#   '자극',
#   '받',
#   '아',
#   '가지',
#   '고',
#   '막',
#   '하',
#   '고',
#   '싶',
#   '어',
#   '그런',
#   '거',
#   '찍',
#   '고',
#   '싶',
#   '어',
#   '.'],
#  ['근데', '확실히', '다이어트', '하', '면은', '몸', '테', '같', '은', '게', '예뻐', '지', '니까'],
#  ['바디', '프로필', '같', '은', '거', '나', '도', '정말', '찍', '고', '싶', '어', '.'],
#  ['젊음', '을', '남기', '는', '거', '니까'],
#  ['맞', '아', '.'],
#  ['이때', '아니', '면', '언제', '빼', '겠', '냐는', '생각', '도', '들', '기', '도', '하', '고'],
#  ['맞',
#   '아',
#   '확실히',
#   '인제',
#   '뭐',
#   '스무',
#   '살',
#   '되',
#   '고',
#   '나',
#   '니까',
#   '인제',
#   '약간',
#   '다이어트',
#   '해',
#   '가지',
#   '고'],
#  ['진짜',
#   '어차피',
#   '한',
#   '번',
#   '사',
#   '는',
#   '청춘',
#   '인데',
#   '다이어트',
#   '해서',
#   '엄청',
#   '예쁘',
#   '게',
#   '살',
#   '아야지'],
#  ['약간', '이', '생각', '도', '많이', '들', '어'],
#  ['그래', '가지', '고', '더', '하', '게', '되', '는', '듯', '한', '약간'],
#  ['근데', '약간', '어느', '정도', '한계', '는', '와'],
#  ['내', '가', '다이어트', '해서', '뺄', '수', '있', '는', '거', '어느', '정도', '한계', '는', '와'],
#  ['한계', '는', '진짜', '있', '더라'],
#  ['맞',
#   '아',
#   '어찌',
#   '됐',
#   '든',
#   '몸무게',
#   '가',
#   '멈추',
#   '고',
#   '인제',
#   '한계',
#   '가',
#   '올',
#   '수',
#   '밖에',
#   '없',
#   '어',
#   '.'],
#  ['근데',
#   '거기',
#   '서',
#   '인제',
#   '더',
#   '해야',
#   '되',
#   '는데',
#   '더',
#   '해야지',
#   '진짜',
#   '다이어트',
#   '너무',
#   '힘들',
#   '어',
#   '.'],
#  ['근데',
#   '고유',
#   '때문',
#   '에',
#   '헬스',
#   '장',
#   '을',
#   '못',
#   '가',
#   '니까',
#   '홈',
#   '트',
#   '도',
#   '많이',
#   '한단',
#   '말',
#   '이',
#   '야',
#   '.'],
#  ['고유',
#   '보고',
#   '하',
#   '는',
#   '거',
#   '홈',
#   '트',
#   '근데',
#   '홈',
#   '트',
#   '는',
#   '내',
#   '가',
#   '해',
#   '보',
#   '니까',
#   '엄청',
#   '아프',
#   '더라',
#   '몸',
#   '이',
#   '?'],
#  ['내',
#   '가',
#   '자세',
#   '를',
#   '잘',
#   '모르',
#   '니까',
#   '그런',
#   '줄',
#   '몰라도',
#   '홈',
#   '트',
#   '한',
#   '번',
#   '씩',
#   '하',
#   '고',
#   '나',
#   '면은'],
#  ['막', '무릎', '이나', '이런', '데', '도', '되게', '아프', '고', '그랬었', '어', '.'],
#  ['나',
#   '도',
#   '다이어트',
#   '할',
#   '때',
#   '홈',
#   '트',
#   '해',
#   '봤',
#   '는데',
#   '나',
#   '도',
#   '약간',
#   '뭐',
#   '랄까',
#   '좀'],
#  ['그',
#   '의지',
#   '가',
#   '약해서',
#   '중간',
#   '에',
#   '꺼',
#   '버리',
#   '고',
#   '인제',
#   '안',
#   '할',
#   '때',
#   '도',
#   '있',
#   '고',
#   '솔직히',
#   '다',
#   '끝',
#   '까지',
#   '해도'],
#  ['나',
#   '도',
#   '자세',
#   '같',
#   '은',
#   '게',
#   '뭐',
#   '가',
#   '잘못',
#   '됐',
#   '는지',
#   '무릎',
#   '이',
#   '계속',
#   '아팠',
#   '어',
#   '.'],
#  ['맞아', '그래서', '홈', '트', '약간', '힘들', '어', '.'],
#  ['되게',
#   '쉬운',
#   '홈',
#   '트',
#   '이런',
#   '거',
#   '보',
#   '고',
#   '따라',
#   '하',
#   '면',
#   '되',
#   '는데',
#   '그럼',
#   '그',
#   '쉬운',
#   '홈',
#   '트',
#   '는',
#   '한',
#   '시간',
#   '짜리'],
#  ['엄청', '길', '게', '해야', '돼', '.'],
#  ['왜냐면', '운동', '이', '별로', '안', '빡세', '니까'],
#  ['그럼',
#   '빡센',
#   '거',
#   '찾',
#   '아',
#   '가지',
#   '고',
#   '해야',
#   '되',
#   '는',
#   '데',
#   '빡센',
#   '건',
#   '또',
#   '잘',
#   '몰라'],
#  ['그게', '너무', '그게', '약간', '어려워', '홈', '트', '는'],
#  ['다이어트',
#   '에서',
#   '홈',
#   '트',
#   '를',
#   '요즘',
#   '많이',
#   '하',
#   '는데',
#   '솔직히',
#   '자세',
#   '제대로',
#   '모르',
#   '면',
#   '못하',
#   '고',
#   '그러',
#   '니까'],
#  ['요즘',
#   '사람',
#   '들',
#   '이',
#   '진짜',
#   '많이',
#   '헬스',
#   '장',
#   '을',
#   '못',
#   '가',
#   '가지',
#   '고',
#   '약간',
#   '좀',
#   '살찐',
#   '사람',
#   '들',
#   '많',
#   '잖아',
#   '그래서',
#   '.'],
#  ['그래',
#   '가지',
#   '고',
#   '내',
#   '가',
#   '아빠',
#   '랑',
#   '다니',
#   '는',
#   '게',
#   '헬스',
#   '장',
#   '말',
#   '고',
#   '고유',
#   '장',
#   '있',
#   '지',
#   '?'],
#  ['등산', '가', '는', '거', '등산', '가', '가지', '고', '진짜', '힘들', '었', '어', '등산'],
#  ['그게', '왜', '다이어트', '에', '도움', '많이', '된다는', '지', '알', '겠', '더라', '진짜로'],
#  ['확실히',
#   '다이어트',
#   '나',
#   '도',
#   '다이어트',
#   '할',
#   '때',
#   '등',
#   '산',
#   '한',
#   '번',
#   '갔',
#   '다',
#   '왔',
#   '는데',
#   '아',
#   '나',
#   '는',
#   '진짜',
#   '안',
#   '맞',
#   '아',
#   '가지',
#   '고'],
#  ['나',
#   '는',
#   '아',
#   '이건',
#   '아니',
#   '다',
#   '싶',
#   '어',
#   '가지',
#   '고',
#   '인제',
#   '그',
#   '이후',
#   '로부터',
#   '는',
#   '등산',
#   '아예',
#   '못',
#   '해',
#   '가지',
#   '고',
#   '진짜'],
#  ['다이어트',
#   '가',
#   '진짜',
#   '방법',
#   '도',
#   '많',
#   '고',
#   '종류',
#   '도',
#   '많',
#   '은데',
#   '나',
#   '한테',
#   '맞',
#   '는',
#   '거',
#   '찾',
#   '는',
#   '것',
#   '도',
#   '힘들',
#   '어',
#   '.'],
#  ['그거', '찾', '는', '게', '제일', '힘든', '거', '같', '애', '솔직히'],
#  ['그래서',
#   '나',
#   '도',
#   '솔직히',
#   '어렸',
#   '을',
#   '때',
#   '부터',
#   '나',
#   '한',
#   '중학교',
#   '때',
#   '부터',
#   '인제',
#   '막',
#   '킥복싱',
#   '같',
#   '은',
#   '거'],
#  ['다이어트', '킥복싱', '이런', '거', '유행', '해', '가지', '고', '인제', '많이', '다녀', '봤', '는데'],
#  ['킥복싱', '다이어트', '해도', '이거', '맨날', '삼겹살', '같', '은', '거', '먹', '어', '버리', '니까'],
#  ['살', '이', '많이', '안', '빠지', '긴', '했', '거든', '?'],
#  ['그래서',
#   '살',
#   '이',
#   '빠져도',
#   '한',
#   '달',
#   '에',
#   '이',
#   '키',
#   '로',
#   '빠지',
#   '는데',
#   '이제',
#   '나중',
#   '에',
#   '나',
#   '한테',
#   '맞',
#   '는',
#   '방법',
#   '을',
#   '찾',
#   '으니까'],
#  ['난',
#   '솔직히',
#   '개인',
#   '적',
#   '으로',
#   '스',
#   '피닝',
#   '이',
#   '나',
#   '한테',
#   '–',
#   '개',
#   '-',
#   '제일',
#   '잘',
#   '맞',
#   '아',
#   '가지',
#   '고'],
#  ['찾', '으니까', '확실히', '살', '도', '잘', '빠지', '고', '그랬', '어', '.'],
#  ['맞', '어', '스', '피닝', '엄청', '잘', '한다고', '듣', '긴', '들', '었', '다', '.'],
#  ['근데',
#   '다이어트',
#   '하',
#   '면',
#   '제일',
#   '중요',
#   '한',
#   '거',
#   '진짜',
#   '스트레스',
#   '관리',
#   '하',
#   '는',
#   '게',
#   '제일',
#   '중요',
#   '해'],
#  ['스트레스', '안', '받', '는', '거'],
#  ['그치',
#   '다이어트',
#   '할',
#   '때',
#   '스트레스',
#   '받',
#   '으면',
#   '이제',
#   '나',
#   '는',
#   '솔직히',
#   '스트레스',
#   '받',
#   '으면'],
#  ['약간',
#   '좀',
#   '먹',
#   '어',
#   '버리',
#   '고',
#   '풀',
#   '어',
#   '버리',
#   '먹',
#   '고',
#   '풀',
#   '어',
#   '버리',
#   '는',
#   '스타일',
#   '이',
#   '라서'],
#  ['인제',
#   '그런',
#   '것',
#   '도',
#   '그런',
#   '것',
#   '때문',
#   '에',
#   '다이어트',
#   '는',
#   '인제',
#   '또',
#   '못',
#   '하',
#   '고',
#   '그래',
#   '가지',
#   '고'],
#  ['그게',
#   '반복',
#   '되',
#   '면서',
#   '그게',
#   '진짜',
#   '다이어트',
#   '할',
#   '때',
#   '스트레스',
#   '안',
#   '받',
#   '는',
#   '게',
#   '진짜',
#   '중요',
#   '해',
#   '.'],
#  ['나', '도', '그건', '동감', '.'],
#  ['아',
#   '근데',
#   '어차피',
#   '뭐',
#   '마른',
#   '체형',
#   '아닌',
#   '이상',
#   '그냥',
#   '해야',
#   '돼',
#   '어쩔',
#   '수',
#   '없',
#   '어',
#   '진짜'],
#  ['평생',
#   '관리',
#   '해야',
#   '돼',
#   '진짜',
#   '그거',
#   '는',
#   '진짜',
#   '부정',
#   '할',
#   '수',
#   '가',
#   '없',
#   '어',
#   '.'],
#  ['다이어트', '이제', '우리', '엄마', '도', '인제', '평생', '을', '솔직히', '말라', '왔', '거든', '?'],
#  ['그래',
#   '우리',
#   '엄마',
#   '도',
#   '나',
#   '랑',
#   '머',
#   '젊',
#   '었',
#   '을',
#   '때',
#   '키',
#   '가',
#   '백',
#   '육',
#   '십',
#   '사',
#   '오',
#   '에'],
#  ['진짜',
#   '몸무게',
#   '사',
#   '십',
#   '칠',
#   '키',
#   '로',
#   '그렇게',
#   '살아왔',
#   '다고',
#   '했',
#   '단',
#   '말',
#   '야',
#   '?'],
#  ['근데',
#   '확실히',
#   '다이어트',
#   '평생',
#   '해야',
#   'xx',
#   '느낀',
#   '게',
#   '우리',
#   '엄마',
#   '도',
#   '살',
#   '이',
#   '찌',
#   '더라고'],
#  ['그래서',
#   '다이어트',
#   '아',
#   '진짜',
#   '평생',
#   '해야',
#   '되',
#   '겠',
#   '구나',
#   '이',
#   '생각',
#   '했',
#   '어',
#   '.'],
#  ['근데',
#   '가족',
#   '중',
#   '에',
#   '마른',
#   '사람',
#   '있',
#   '으면',
#   '난',
#   '더',
#   '스트레스',
#   '받',
#   '아',
#   '불',
#   '드라',
#   '진짜'],
#  ['아',
#   '막',
#   '언니',
#   '는',
#   '말랐',
#   '는데',
#   '뭐',
#   '니',
#   '는',
#   '어짜',
#   '냐',
#   '이런',
#   '말',
#   '들으면은'],
#  ['아', '진짜', '확', '스트레스', '겁나', '받', '아', '진짜'],
#  ['나',
#   '도',
#   '그런',
#   '말',
#   '진짜',
#   '많이',
#   '들',
#   '은',
#   '게',
#   '내',
#   '동생',
#   '이',
#   '키',
#   '가',
#   '백',
#   '팔',
#   '십',
#   '지금',
#   '고유'],
#  ['진짜',
#   '육',
#   '십',
#   '키',
#   '로',
#   '그램',
#   '막',
#   '살',
#   '고유',
#   '고유',
#   '요즘',
#   '살',
#   '빠졌',
#   '다고',
#   '육',
#   '십',
#   '키',
#   '로',
#   '그램',
#   '이',
#   '안',
#   '넘',
#   '는다고',
#   '그래'],
#  ['그래서',
#   '아니',
#   '너',
#   '는',
#   '키',
#   '백',
#   '팔',
#   '십',
#   '산',
#   '데',
#   '어떻',
#   '게',
#   '하',
#   '면',
#   '뭐',
#   '막',
#   '친척',
#   '들',
#   '같',
#   '은',
#   '추석',
#   '때',
#   '가',
#   '도'],
#  ['막',
#   '어',
#   '동생',
#   '은',
#   '막',
#   '엄청',
#   '살',
#   '빠졌',
#   '는데',
#   '아',
#   '엄청',
#   '마른',
#   '말랐',
#   '는데'],
#  ['&',
#   'name',
#   '1',
#   '&',
#   '너',
#   '는',
#   '왜',
#   '케',
#   '막',
#   '그런',
#   '식',
#   '으로',
#   '나',
#   '한테',
#   '꼽',
#   '을',
#   '주',
#   '니까'],
#  ['인제',
#   '나',
#   '는',
#   '나대',
#   '로',
#   '또',
#   '스트레스',
#   '받',
#   '아',
#   '가지',
#   '고',
#   '다이어트',
#   '해야',
#   '되',
#   '겠',
#   '다고',
#   '계속',
#   '생각',
#   '해',
#   '.'],
#  ['주변', '에서', '그러니까', '더', '그런', '것', '같', '아', '주변', '시선', '때문', '에', '.'],
#  ['나',
#   '는',
#   '다이어트',
#   '는',
#   '진짜',
#   '그래도',
#   '진짜',
#   '아니',
#   '면',
#   '평생',
#   '그냥',
#   '좀',
#   '뚱뚱',
#   '하',
#   '고',
#   '통통',
#   '하',
#   '게',
#   '살',
#   '던가'],
#  ['둘',
#   '중',
#   '하난',
#   '디',
#   '그렇게',
#   '뚱뚱',
#   '하',
#   '게',
#   '살',
#   '믄',
#   '진짜',
#   '한',
#   '번',
#   '씩',
#   '현',
#   '타',
#   '와',
#   '가지',
#   '고야'],
#  ['다이어트',
#   '를',
#   '할',
#   '수',
#   '밖에',
#   '없',
#   '게',
#   '되',
#   '더라',
#   '진짜',
#   '운동',
#   '겁나',
#   '열심히',
#   '하',
#   '고'],
#  ['그러게',
#   '한',
#   '번',
#   '씩',
#   '쫙',
#   '빼',
#   '고',
#   '나',
#   '면',
#   '기분',
#   '되게',
#   '좋',
#   '긴',
#   '한데',
#   '그걸',
#   '유지',
#   '하',
#   '기',
#   '가',
#   '힘든',
#   '거',
#   '야',
#   '.'],
#  ['근께', '유지', '어', '터', '라도', '해', '유지', '어', '터'],
#  ['아',
#   '다이어트',
#   '근데',
#   '주변',
#   '시선',
#   '때문',
#   '에',
#   '도',
#   '있',
#   '는데',
#   '확실히',
#   '주변',
#   '시선',
#   '보다',
#   '는'],
#  ['나',
#   '자신',
#   '을',
#   '위해서',
#   '하',
#   '는',
#   '게',
#   '진짜',
#   '그때',
#   '가',
#   '–',
#   '그',
#   '-',
#   '그렇게',
#   '하',
#   '는',
#   '게',
#   '더',
#   '중요',
#   '한',
#   '거',
#   '같',
#   '아',
#   '.'],
#  ['주변',
#   '시선',
#   '때문',
#   '에',
#   '하',
#   '면은',
#   '평생',
#   '주변',
#   '시선',
#   '이렇게',
#   '생각',
#   '하',
#   '면서',
#   '살',
#   '빼',
#   '야',
#   '되',
#   '면'],
#  ['그럼', '불행', '한', '삶', '아닌가', '그것', '도', '?'],
#  ['그래서', '인제', '다이어트', '는', '나', '한테', '맞', '게'],
#  ['나',
#   '나',
#   '를',
#   '만족',
#   '할',
#   '수',
#   '있',
#   '을',
#   '정도',
#   '로',
#   '빼',
#   '야',
#   '되',
#   '겠',
#   '다',
#   '약간',
#   '이',
#   '생각'],
#  ['근데', '주변', '시선', '때문', '에', '내', '가', '몇', '번', '해', '보', '고'],
#  ['또', '내', '스스로', '해야', '겠', '다고', '해본', '적', '도', '있', '는데'],
#  ['주변',
#   '시선',
#   '때문',
#   '에',
#   '한',
#   '다이어트',
#   '는',
#   '뭐',
#   '지',
#   '한',
#   '번',
#   '씩',
#   '자기',
#   '합리',
#   '화',
#   '를',
#   '이제',
#   '겁나',
#   '한다',
#   '?'],
#  ['아', '뭐', '남', '의', '시선', '뭐', '가', '중요', '해', '?'],
#  ['이러', '면서', '자기', '합리', '화', '겁나', '하', '고', '다이어트', '안', '해', '.'],
#  ['그러니까', '진다', '내', '가', '아', '진짜', '이제', '는', '해야겠다', '.'],
#  ['그', '마음', '딱', '결심', '먹', '고', '하', '는', '다이어트', '가', '진짜', '찐', '다이어트'],
#  ['살', '빠지', '는', '다이어트', '그게', '진짜', '살', '빠지', '는', '다이어트'],
#  ['다이어트', '근데', '막', '요즘', '에', '는', '솔직히', '말', '해서'],
#  ['막',
#   '아',
#   '나',
#   '자신',
#   '한테',
#   '만족',
#   '하',
#   '면서',
#   '살',
#   '아야',
#   '된',
#   '살',
#   '아야',
#   '한다',
#   '.'],
#  ['막', '그런', '식', '으로', '하', '잖아', '많', '은', '사람', '들', '이'],
#  ['근데',
#   '어떡',
#   '해',
#   '뚱뚱',
#   '하',
#   '고',
#   '미련',
#   '해',
#   '보이',
#   '는',
#   '내',
#   '자신',
#   '을',
#   '거울',
#   '속',
#   '내',
#   '자신',
#   '을',
#   '보',
#   '면서'],
#  ['이',
#   '자신',
#   '을',
#   '이',
#   '사람',
#   '을',
#   '어떻게',
#   '사랑',
#   '하',
#   '고',
#   '그러',
#   '니까',
#   '무조건',
#   '다이어트',
#   '를',
#   '하',
#   '면서'],
#  ['어찌',
#   '됐',
#   '든',
#   '가꿔',
#   '지',
#   '는',
#   '나',
#   '자신',
#   '을',
#   '보',
#   '면서',
#   '사랑',
#   '해야',
#   '된다고',
#   '생각',
#   '해',
#   '.'],
#  ['막',
#   '계속',
#   '이렇게',
#   '먹',
#   '으면서',
#   '나',
#   '자신',
#   '에',
#   '만족',
#   '해야',
#   '돼',
#   '이런',
#   '것',
#   '보다',
#   '는'],
#  ['나',
#   '자신',
#   '갖',
#   '고',
#   '가',
#   '면서',
#   '어느',
#   '정도',
#   '뭐',
#   '열심히',
#   '이렇게',
#   '살',
#   '빼',
#   '면서'],
#  ['그렇게', '하', '면서', '다이어트', '해야', '된다고', '생각', '해', '.'],
#  ['맞', '어', '다이어트', '진짜', '그래', '.'],
#  ['나',
#   '는',
#   '근데',
#   '이제',
#   '운동',
#   '을',
#   '하',
#   '다가',
#   '안',
#   '하',
#   '니까',
#   '약간',
#   '간헐',
#   '적',
#   '단식',
#   '하',
#   '는',
#   '걸로',
#   '바꼈',
#   '거든',
#   '?'],
#  ['의도', '해서', '아닌데', '하루', '에', '막', '한', '끼', '두', '끼', '이렇게', '먹', '으니까'],
#  ['막',
#   '아침',
#   '에',
#   '일어나',
#   '막',
#   '아침',
#   '에',
#   '어차피',
#   '늦',
#   '게',
#   '일어나',
#   '니까',
#   '막',
#   '열',
#   '한',
#   '시',
#   '열',
#   '두',
#   '시',
#   '한',
#   '끼',
#   '먹',
#   '고'],
#  ['밤',
#   '여덟',
#   '시',
#   '한',
#   '끼',
#   '먹',
#   '고',
#   '이렇게',
#   '하',
#   '면은',
#   '솔직히',
#   '말',
#   '해서',
#   '체중',
#   '유지',
#   '가',
#   '되',
#   '긴',
#   '되',
#   '더라',
#   '.'],
#  ['근데',
#   '근육',
#   '은',
#   '다',
#   '빠지',
#   '고',
#   '지방',
#   '막',
#   '출렁출렁',
#   '해',
#   '갖',
#   '고',
#   '그래',
#   '그러',
#   '고',
#   '있',
#   '어',
#   '.'],
#  ['어', '근데', '진짜', '확실히', '이게', '확', '빼', '다가', '갑자기', '인제', '유지', '할려면'],
#  ['난', '솔직히', '유지', '가', '더', '힘', '들', '더', '힘들', '었', '어', '개인', '적', '으로'],
#  ['왜냐면',
#   '인제',
#   '다이어트',
#   '할',
#   '때',
#   '는',
#   '나',
#   '도',
#   '확',
#   '하',
#   '는',
#   '스타일',
#   '이',
#   '어서',
#   '진짜',
#   '식단',
#   '도',
#   '완전히',
#   '줄여',
#   '버리',
#   '고'],
#  ['운동',
#   '도',
#   '진짜',
#   '엄청',
#   '빡세',
#   '게',
#   '하',
#   '는데',
#   '인제',
#   '–',
#   '그',
#   '-',
#   '그',
#   '이후',
#   '에',
#   '유지',
#   '를',
#   '한다고',
#   '치',
#   '면은'],
#  ['솔직히',
#   '많',
#   '은',
#   '유혹',
#   '들',
#   '이',
#   '어떻게',
#   '뭐',
#   '치킨',
#   '이',
#   '있',
#   '는데',
#   '치킨',
#   '을',
#   '한두',
#   '조각',
#   '만',
#   '먹',
#   '어'],
#  ['먹',
#   '어',
#   '버리',
#   '면',
#   '확',
#   '먹',
#   '어',
#   '버리',
#   '니까',
#   '인제',
#   '그',
#   '부분',
#   '에서',
#   '진짜',
#   '유지',
#   '하',
#   '기',
#   '도',
#   '힘들',
#   '고'],
#  ['간헐',
#   '적',
#   '단식',
#   '한다고',
#   '해도',
#   '정말',
#   '한',
#   '끼',
#   '만',
#   '먹',
#   '어도',
#   '진짜',
#   '나',
#   '도',
#   '원래',
#   '근육',
#   '엄청',
#   '많',
#   '았',
#   '고'],
#  ['근육',
#   '이',
#   '잘',
#   '붙',
#   '는',
#   '체형',
#   '이',
#   '라서',
#   '근육',
#   '엄청',
#   '많',
#   '았었',
#   '는데',
#   '인제',
#   '허벅지',
#   '가',
#   '출렁거려'],
#  ['그러니까', '더', '스트레스', '받', '는', '것', '같', '아', '.'],
#  ['맞', '아', '몸무게', '는', '줄', '어도', '몸', '테', '는', '안', '예쁘', '니까', '.'],
#  ['근육', '이', '늘', '어야', '몸', '테', '가', '예쁘', '잖아', '다이어트', '할', '때', '도'],
#  ['그', '근육', '늘리', '기', '가', '진짜', '힘들', '더라고'],
#  ['어',
#   '근육',
#   '이',
#   '진짜',
#   '나',
#   '도',
#   '개인',
#   '적',
#   '으로',
#   '이제',
#   '어느',
#   '정도',
#   '지방',
#   '태우',
#   '고'],
#  ['이런', '거', '는', '그냥', '적', '게', '먹', '으면', '솔직히', '지방', '태워', '지', '잖아'],
#  ['근데', '적', '게', '먹', '으면', '또', '근육', '까지', '빠져', '버리', '니까'],
#  ['이제',
#   '근육',
#   '까지',
#   '빠지',
#   '면',
#   '인제',
#   '딱',
#   '거울',
#   '봤',
#   '을',
#   '때',
#   '몸',
#   '테',
#   '가',
#   '별로',
#   '안',
#   '이쁘',
#   '지',
#   '.'],
#  ['그래서', '좀', '그래', '.'],
#  ['근데', '마른', '애', '들', '도', '다이어트', '라고', '해야', '되', '나', '그것', '도', '?'],
#  ['마른',
#   '애',
#   '들',
#   '도',
#   '살',
#   '찌우',
#   '는',
#   '근육',
#   '키우',
#   '는',
#   '뭐',
#   '그런',
#   '걸',
#   '하',
#   '긴',
#   '하',
#   '더라',
#   '.'],
#  ['어', '근데', '그거', '그게', '더', '힘들', '어', '보이', '던데', '나', '는'],
#  ['막',
#   '프로',
#   '틴',
#   '겁나',
#   '챙겨',
#   '먹',
#   '고',
#   '운동',
#   '헬스',
#   '장',
#   '가',
#   '가지',
#   '고',
#   '근육',
#   '운동',
#   '만',
#   '겁나',
#   '막',
#   '때리',
#   '고',
#   '이러',
#   '니까'],
#  ['아',
#   '요즘',
#   '에',
#   '는',
#   '확실히',
#   '인식',
#   '같',
#   '은',
#   '게',
#   '진짜',
#   '다이어트',
#   '에',
#   '대한',
#   '인식',
#   '이',
#   '좀',
#   '달라졌',
#   '던',
#   '것',
#   '같',
#   '아',
#   '.'],
#  ['왜냐하면',
#   '옛날',
#   '에',
#   '는',
#   '진짜',
#   '막',
#   '우리',
#   '가',
#   '막',
#   '중학교',
#   '때',
#   '나',
#   '초등',
#   '학교',
#   '때',
#   '보',
#   '면',
#   '그냥'],
#  ['아',
#   '무조건',
#   '사람',
#   '다이어트',
#   '아이',
#   '돌',
#   '같',
#   '은',
#   '경우',
#   '에',
#   '도',
#   '진짜',
#   '무조건',
#   '말라야',
#   '돼',
#   '약간',
#   '이랬',
#   '는데'],
#  ['그냥',
#   '대중',
#   '들',
#   '의',
#   '잣대',
#   '가',
#   '근데',
#   '요즘',
#   '같',
#   '은',
#   '경우',
#   '에',
#   '는',
#   '좀',
#   '탄탄',
#   '한',
#   '몸매'],
#  ['마르',
#   '기',
#   '보다',
#   '는',
#   '좀',
#   '탄탄',
#   '하',
#   '고',
#   '그러니까',
#   '사람',
#   '들',
#   '이',
#   '말라도',
#   '근육',
#   '운동',
#   '많이',
#   '하',
#   '고',
#   '그러',
#   '더라고'],
#  ['맞', '아', '.'],
#  ['그래',
#   '가지',
#   '고',
#   '&',
#   'company',
#   '-',
#   'name',
#   '1',
#   '&',
#   '가',
#   '겁나',
#   '뜬',
#   '거',
#   '잖',
#   '아',
#   '.'],
#  ['그',
#   '다이어트',
#   '다이어트',
#   '고유',
#   '채널',
#   '들',
#   '엄청',
#   '뜨',
#   '잖아',
#   '구독자',
#   '막',
#   '몇',
#   '만',
#   '명',
#   '씩',
#   '찍',
#   '어',
#   '블',
#   '고'],
#  ['좋', '긴', '하', '더라', '보', '고', '있', '으면', '진짜'],
#  ['아',
#   '진짜',
#   '다이어트',
#   '고유',
#   '고유',
#   '들',
#   '보',
#   '면서',
#   '아',
#   '나',
#   '도',
#   '다이어트',
#   '열심히',
#   '해',
#   '가지',
#   '고'],
#  ['다이어트',
#   '고유',
#   '고유',
#   '할까',
#   '생각',
#   '하',
#   '는데',
#   '혹시',
#   '다이어트',
#   '고유',
#   '고유',
#   '도',
#   '그',
#   '나름',
#   '대로',
#   '의',
#   '그',
#   '고충',
#   '이',
#   '있',
#   '고',
#   '막',
#   '힘들',
#   '것',
#   '같',
#   '아',
#   '.'],
#  ['막',
#   '어느',
#   '자세',
#   '에서',
#   '는',
#   '이렇게',
#   '해야',
#   '되',
#   '고',
#   '그래도',
#   '막',
#   'xxx',
#   '해',
#   '가지',
#   '고',
#   '해',
#   '주',
#   '는',
#   '거',
#   '잖',
#   '아',
#   '.'],
#  ['맞아',
#   '근데',
#   '뭐',
#   '어차피',
#   '계속',
#   '해야',
#   '되',
#   '는',
#   '게',
#   '다이어트',
#   '니까',
#   '방법',
#   '만',
#   '계속',
#   '바꿔',
#   '가',
#   '면서',
#   '한',
#   '거긴',
#   '한',
#   '디'],
#  ['언제',
#   '또',
#   '요요',
#   '가',
#   '올지',
#   '모르',
#   '니까',
#   '그거',
#   '때문',
#   '에',
#   '진짜',
#   '맨날',
#   '떨',
#   '면서',
#   '하',
#   '는',
#   '거',
#   '같',
#   '애',
#   '진짜로'],
#  ['다이어트', '근데', '평생', '해야', '되', '는', '거', '라고', '생각', '하', '고'],
#  ['그냥',
#   '좀',
#   '더',
#   '마음',
#   '가볍',
#   '게',
#   '먹',
#   '고',
#   '그냥',
#   '그렇게',
#   '하',
#   '는',
#   '게',
#   '좋',
#   '은',
#   '것',
#   '같',
#   '아',
#   '.'],
#  ['다이어트', '여러', '번', '여러', '번', '하', '고', '요요', '와', '본', '입장', '으로서'],
#  ['그냥',
#   '좀',
#   '평생',
#   '해야',
#   '될',
#   '거',
#   '라',
#   '생각',
#   '하',
#   '고',
#   '마음',
#   '편하',
#   '게',
#   '먹',
#   '고',
#   '인제',
#   '그렇게',
#   '해야',
#   '될',
#   '것',
#   '같',
#   '아',
#   '.'],
#  ['근데', '다이어트', '탈모', '는', '진짜', '인정', '이', '야', '.'],
#  ['나', '도', '옛날', '에', '뭐', '방울토마토', '하루', '에', '막', '뭐', '열', '다섯', '개'],
#  ['이것',
#   '만',
#   '먹',
#   '고',
#   '살',
#   '기',
#   '이런',
#   '거',
#   '했었',
#   '는데',
#   '진짜',
#   '훅',
#   '가',
#   '더라',
#   '걍',
#   '훅',
#   '가'],
#  ['걍', '그냥', '머리', '바로', '빠져', '블', '고', '난리', '나', '브', '러', '진짜'],
#  ['아', '진짜', '다이어트', '조심', '해서', '해야', '되', '더라', '그것', '도'],
#  ['아',
#   '진짜',
#   '그런',
#   '게',
#   '나',
#   '도',
#   '옛날',
#   '에',
#   '한',
#   '번',
#   '그',
#   '다이어트',
#   '내기',
#   '를',
#   '했었',
#   '는데'],
#  ['인제', '다이어트', '내기', '를', '할', '때', '아이유', '물', '다이어트', '라고', '인제'],
#  ['맞', '아', '인정', '이', '야', '그건', '진짜', '인정', '.'],
#  ['괜히',
#   '쓰',
#   '잘',
#   '데기',
#   '없',
#   '는',
#   '거',
#   '해',
#   '갖',
#   '고',
#   '신경',
#   '만',
#   '겁나',
#   '예민',
#   '예민',
#   '해',
#   '지',
#   '고',
#   '가족',
#   '들',
#   '한테',
#   '틱',
#   '틱',
#   '대',
#   '고',
#   '다이어트',
#   '하',
#   '면',
#   '그런',
#   '경험',
#   '이',
#   '진짜',
#   '있',
#   '긴',
#   '해',
#   '.'],
#  ['근데',
#   '오히려',
#   '난',
#   '스무',
#   '살',
#   '되',
#   '고',
#   '나',
#   '서',
#   '다이어트',
#   '보다',
#   '고등학교',
#   '때',
#   '더',
#   '하',
#   '고',
#   '싶',
#   '더라',
#   '.'],
#  ['왜', '?', '고등학교', '때', '왜', '?'],
#  ['아',
#   '그니까',
#   '고등학교',
#   '때',
#   '공부',
#   '도',
#   '되게',
#   '중요',
#   '하',
#   '지만',
#   '주변',
#   '에',
#   '마른',
#   '애',
#   '들',
#   '이',
#   '있',
#   '으니까',
#   '.'],
#  ['또', '남자', '애', '들', '이', '넌', '다이어트', '안', '하', '냐', '?'],
#  ['다이어트', '안', '해', '?', '이런단', '말', '야'],
#  ['그러면', '그때', '가', '더', '빼', '고', '싶', '지', '.'],
#  ['지금', '스무', '살', '되', '고', '나서', '는', '아', '빼', '고', '싶', '긴', '한데'],
#  ['난', '고등학교', '때', '가', '더', '다이어트', '때문', '에', '스트레스', '받', '았', '어', '.'],
#  ['아',
#   '근데',
#   '스무',
#   '살',
#   '되',
#   '고',
#   '나',
#   '서',
#   '약간',
#   '좀',
#   '지금',
#   '느끼',
#   '는',
#   '건데',
#   '약간',
#   '너',
#   '말',
#   '듣',
#   '고',
#   '느끼',
#   '는',
#   '건데'],
#  ['약간',
#   '좀',
#   '학교',
#   '를',
#   '안',
#   '가',
#   '서',
#   '더',
#   '그런',
#   '것',
#   '도',
#   '있',
#   '는',
#   '것',
#   '같',
#   '긴',
#   '해',
#   '.'],
#  ['우리',
#   '가',
#   '만약',
#   '에',
#   '학교',
#   '갔',
#   '으면',
#   '진짜',
#   '엄청',
#   '더',
#   '그랬',
#   '을',
#   '거',
#   '같',
#   '아',
#   '.'],
#  ['맞', '아', '.'],
#  ['우리', '연애', '랑', '결혼', '에', '대해서', '얘기', '해', '보', '자', '.'],
#  ['근데', '나', '는', '지금', '연애', '를', '하', '고', '있', '잖아', '.'],
#  ['근데',
#   '연애',
#   '를',
#   '하',
#   '믄서',
#   '느낀',
#   '거',
#   '는',
#   '지금',
#   '그래도',
#   '꽤',
#   '길',
#   '게',
#   '연애',
#   '를',
#   '하',
#   '고',
#   '있',
#   '는데'],
#  ['이게',
#   '한',
#   '번',
#   '씩',
#   '그',
#   '타임',
#   '이',
#   '와',
#   '아',
#   '나',
#   '왜',
#   '얘',
#   '랑',
#   '사귀',
#   '고',
#   '있',
#   '지',
#   '아',
#   '그냥',
#   '헤어질까',
#   '?'],
#  ['그거',
#   '를',
#   '좀',
#   '잘',
#   '넘겨야',
#   '연애',
#   '가',
#   '좀',
#   '되게',
#   '길',
#   '게',
#   '지속',
#   '될',
#   '수',
#   '있',
#   '는',
#   '거',
#   '같',
#   '애',
#   '.'],
#  ['아',
#   '진짜',
#   '나',
#   '는',
#   '연애',
#   '를',
#   '해',
#   '보',
#   '진',
#   '않',
#   '았',
#   '지만',
#   '연애',
#   '를',
#   '하',
#   '면서',
#   '나',
#   '는',
#   '오래',
#   '사귀',
#   '는',
#   '애',
#   '들',
#   '을',
#   '보',
#   '면서'],
#  ['어', '어떻게', '저렇게', '오래', '사귀', '지', '안', '질리', '나', '?'],
#  ['난',
#   '개인',
#   '적',
#   '으로',
#   '난',
#   '사람',
#   '을',
#   '보',
#   '면',
#   '아니',
#   '야',
#   '난',
#   '약간',
#   '좀',
#   '질릴',
#   '것',
#   '같',
#   '거든',
#   '?'],
#  ['나',
#   '는',
#   '하루',
#   '만',
#   '에',
#   '진짜',
#   '좋',
#   '아',
#   '하',
#   '던',
#   '사람',
#   '도',
#   '그냥',
#   '못생긴',
#   '모습',
#   '보',
#   '면',
#   '정떨어지',
#   '고',
#   '그런단',
#   '말',
#   '야'],
#  ['그믄',
#   '어떻게',
#   '저렇게',
#   '좋',
#   '아',
#   '하',
#   '지',
#   '약간',
#   '좀',
#   '그런',
#   '생각',
#   '이',
#   '들',
#   '때',
#   '도',
#   '있',
#   '어',
#   '.'],
#  ['근데',
#   '솔직히',
#   '말',
#   '해서',
#   '설레',
#   '는',
#   '건',
#   '한',
#   '몇',
#   '개월',
#   '가',
#   '고',
#   '그',
#   '계속',
#   '설레',
#   '면',
#   '심장',
#   '에',
#   '도',
#   '안',
#   '좋',
#   '고'],
#  ['약간',
#   '설레',
#   '다가',
#   '그',
#   '다음',
#   '부터',
#   '그냥',
#   '계속',
#   '보',
#   '는',
#   '뭐',
#   '코드',
#   '도',
#   '맞',
#   '고',
#   '말',
#   '도',
#   '잘',
#   '맞',
#   '고',
#   '정',
#   '이',
#   '맞',
#   '으니까',
#   '하',
#   '는',
#   '거',
#   '지',
#   '.'],
#  ['근데',
#   '너',
#   '막',
#   '어떤',
#   '사람',
#   '이랑',
#   '이런',
#   '연애',
#   '하',
#   '고',
#   '싶',
#   '다',
#   '그런',
#   '말',
#   '엄청',
#   '하',
#   '잖아',
#   '?'],
#  ['아',
#   '나',
#   '같',
#   '은',
#   '경우',
#   '에',
#   '는',
#   '뭐',
#   '약간',
#   '좀',
#   '눈',
#   '이',
#   '높',
#   '은',
#   '경우',
#   '도',
#   '있',
#   '는데'],
#  ['약간',
#   '좀',
#   '영화',
#   '같',
#   '은',
#   '걸',
#   '좀',
#   '많이',
#   '봐',
#   '가지',
#   '고',
#   '인제',
#   '나',
#   '는',
#   '좀',
#   '약간',
#   '연애',
#   '를',
#   '운명',
#   '처럼',
#   '받아들였',
#   '는데'],
#  ['요즘', '에', '는', '생각', '이', '진짜', '많이', '바뀌', '었', '어', '.'],
#  ['아',
#   '그냥',
#   '보',
#   '면서',
#   '나',
#   '이러',
#   '다가',
#   '진짜',
#   '평생',
#   '연애',
#   '못',
#   '할',
#   '수',
#   '도',
#   '있',
#   '겠',
#   '구나',
#   '약간',
#   '이런',
#   '생각',
#   '했',
#   '어',
#   '.'],
#  ['근데',
#   '운명',
#   '적',
#   '인',
#   '사랑',
#   '그딴',
#   '거',
#   '다',
#   '필요',
#   '없',
#   '고',
#   '그냥',
#   '어느',
#   '정도',
#   '맞',
#   '기',
#   '만',
#   '하',
#   '면은',
#   '다',
#   '하',
#   '는',
#   '게',
#   '연애',
#   '긴',
#   '하',
#   '지',
#   '.'],
#  ['근데',
#   '난',
#   '그게',
#   '가벼운',
#   '연애',
#   '냐',
#   '아니면',
#   '좀',
#   '길',
#   '게',
#   '끌',
#   '고',
#   '가',
#   '는',
#   '연애',
#   '냐',
#   '그게',
# ...
#  ['아',
#   '약간',
#   '뭐',
#   '수능',
#   '준비',
#   '하',
#   '는',
#   '애',
#   '들',
#   '이나',
#   '아니면',
#   '수시',
#   '자소',
#   '서',
#   '준비',
#   '하',
#   '는',
#   '애',
#   '들',
#   '이나',
#   '다',
#   '힘든',
#   '건',
#   '마찬가지',
#   '였',
#   '으니까'],
#  ['그래서', '약간', '서로', '서로', '뭔가'],
#  ['고',
#   '일',
#   '고',
#   '이',
#   '때',
#   '는',
#   '진짜',
#   '되게',
#   '많이',
#   '싸웠',
#   '던',
#   '애',
#   '들',
#   '이',
#   '꼴',
#   '도',
#   '보',
#   '기',
#   '싫',
#   '어',
#   '했',
#   '던',
#   '애',
#   '들',
#   '인데'],
#  ['뭔가',
#   '약간',
#   '다',
#   '같이',
#   '힘든',
#   '느낌',
#   '다',
#   '같이',
#   '약간',
#   '고통',
#   '을',
#   '공유',
#   '하',
#   '는',
#   '느낌',
#   '이',
#   '야',
#   '.'],
#  ['아',
#   '맞아',
#   '근데',
#   '진짜',
#   '고',
#   '삼',
#   '되',
#   '면서',
#   '확실히',
#   '애',
#   '들',
#   '이',
#   '좀',
#   '많이',
#   '달라졌',
#   '다',
#   '.'],
#  ['난',
#   '좀',
#   '깜짝',
#   '놀란',
#   '게',
#   '진짜',
#   '애',
#   '들',
#   '이',
#   '다',
#   '공부',
#   '하',
#   '더라',
#   '그래서',
#   '그것',
#   '도',
#   '좀',
#   '깜짝',
#   '놀랐',
#   '고'],
#  ['근데',
#   '고',
#   '삼',
#   '때',
#   '가',
#   '난',
#   '진짜로',
#   '공부',
#   '안',
#   '했',
#   '고',
#   '진짜로',
#   '막',
#   '제일',
#   '놀',
#   '러',
#   '다녔',
#   '던',
#   '시기',
#   '?'],
#  ['약간', '그랬', '던', '거', '같', '아', '.'],
#  ['진짜',
#   '고',
#   '이때',
#   '는',
#   '좀',
#   '나',
#   '쉬',
#   '는',
#   '시간',
#   '까지',
#   '진짜',
#   '열심히',
#   '공부',
#   '했었',
#   '는데'],
#  ['고', '삼', '때', '되', '면서', '맨날', '놀', '고', '그랬', '던', '거', '같', '아', '.'],
#  ['맞아', '근데', '고등학교', '때', '진짜', '그', '~'],
#  ['뭔가',
#   '일',
#   '학년',
#   '때',
#   '는',
#   '남녀',
#   '가',
#   '분반',
#   '이',
#   '돼',
#   '있',
#   '으니까',
#   '서로',
#   '서로',
#   '약간',
#   '눈치',
#   '보',
#   '는',
#   '느낌',
#   '?'],
#  ['막',
#   '학교',
#   '에',
#   '화장',
#   '도',
#   '엄청',
#   '하',
#   '고',
#   '오',
#   '고',
#   '여자',
#   '애',
#   '들',
#   '은',
#   '남자',
#   '애',
#   '들',
#   '도',
#   '괜히',
#   '막',
#   '이쪽',
#   'x',
#   '한',
#   '번',
#   '더',
#   '오',
#   '고',
#   '그랬',
#   '잖아',
#   '.'],
#  ['근데',
#   '남녀',
#   '합반',
#   '되',
#   '고',
#   '나',
#   '서',
#   '는',
#   '진짜',
#   '나',
#   '는',
#   '아',
#   '고유',
#   '에',
#   '대한',
#   '그런',
#   '환상',
#   '이',
#   '다',
#   '깨',
#   '졌어',
#   '.'],
#  ['이런', '거', '구나', '이런', '게', '고유', '이', '구', '나', '라고', '확', '느꼈', '어', '.'],
#  ['나', '는', '그냥', '좀'],
#  ['다',
#   '재밌',
#   '었',
#   '던',
#   '거',
#   '같',
#   '아',
#   '진짜',
#   '고유',
#   '이',
#   '든',
#   '남녀',
#   '분반',
#   '이',
#   '든',
#   '진짜',
#   '애',
#   '들',
#   '도'],
#  ['진짜', '엄청', '웃긴', '애', '들', '도', '많', '아', '가지', '고'],
#  ['막',
#   '진짜',
#   '일',
#   '학년',
#   '때',
#   '만',
#   '해도',
#   '진짜',
#   '막',
#   '우리',
#   '수학여행',
#   '갔',
#   '을',
#   '때',
#   '도'],
#  ['막', '진짜', '재밌', '었', '어', '.'],
#  ['나',
#   '는',
#   '그냥',
#   '뭐',
#   '순간',
#   '어느',
#   '순간',
#   '을',
#   '말',
#   '할',
#   '수',
#   '없',
#   '을',
#   '만큼',
#   '그냥',
#   '다',
#   '재밌',
#   '게',
#   '살',
#   '았',
#   '던',
#   '거',
#   '같',
#   '아',
#   '.'],
#  ['우리', '수학여행', '을', '어디', '로', '갔', '지', '고등학교', '때', '?'],
#  ['고유', '로', '갔', '지', '않', '아', '?'],
#  ['고유', '로', '갔었', '나', '?'],
#  ['아', '고유', '로', '갔었', '구나', '.'],
#  ['근데', '수학여행', '다니', '면', '확실히', '좀', '재밌', '긴', '했었', '어', '.'],
#  ['그런', '게', '여행', '한', '번', '가', '는', '게', '애', '들', '이랑', '다', '같이'],
#  ['너',
#   '나',
#   '할',
#   '거',
#   '없이',
#   '엄청나',
#   '게',
#   '꾸미',
#   '고',
#   '와',
#   '가지',
#   '고',
#   '근데',
#   '어차피',
#   '봤',
#   '을',
#   '땐',
#   '다',
#   '애기',
#   '들',
#   '이',
#   '잖아',
#   '.'],
#  ['애기',
#   '들',
#   '이',
#   '그렇게',
#   '꾸미',
#   '고',
#   '와',
#   '가지',
#   '고',
#   '노니까',
#   '재밌',
#   '긴',
#   '재밌',
#   '었',
#   '지',
#   '진짜'],
#  ['맞', '어', '진짜', '가', '가지', '고', '진짜', '수학여행', '가', '서', '인제'],
#  ['막',
#   '엄청',
#   '설레',
#   '는',
#   '그',
#   '기분',
#   '을',
#   '아직',
#   '도',
#   '잊',
#   '을',
#   '수',
#   '없',
#   '을',
#   '만큼'],
#  ['그냥',
#   '그런',
#   '거',
#   '하나하나',
#   '다',
#   '갔',
#   '을',
#   '때',
#   '재밌',
#   '고',
#   '그랬',
#   '던',
#   '거',
#   '같',
#   '아',
#   '.'],
#  ['근데', '진짜', '나', '는', '뭔가', '고등학교', '애', '들', '을'],
#  ['고등학교',
#   '졸업',
#   '하',
#   '면은',
#   '이렇게',
#   '까지',
#   '많이',
#   '못',
#   '보',
#   '게',
#   '될',
#   '줄',
#   '몰랐',
#   '는데'],
#  ['아',
#   '되게',
#   '그',
#   '고등학교',
#   '그',
#   '학교',
#   '라는',
#   '그',
#   '집단',
#   '안',
#   '에서',
#   '같이',
#   '있',
#   '다는',
#   '게'],
#  ['되게',
#   '자주',
#   '볼',
#   '수',
#   '있',
#   '고',
#   '같이',
#   '뭔가',
#   '얘기',
#   '할',
#   '수',
#   '있',
#   '는',
#   '그런',
#   '기회',
#   '가',
#   '그때',
#   '야',
#   '많이',
#   '생기',
#   '는',
#   '거',
#   '지'],
#  ['졸업',
#   '하',
#   '고',
#   '나',
#   '서',
#   '는',
#   '억지로',
#   '이제',
#   '뭐',
#   '약속',
#   '을',
#   '잡',
#   '지',
#   '않',
#   '는',
#   '이상'],
#  ['별로',
#   '친하',
#   '지',
#   '않',
#   '는',
#   '애',
#   '들',
#   '은',
#   '그냥',
#   '소식',
#   '도',
#   '모르',
#   '고',
#   '살',
#   '게',
#   '되',
#   '는',
#   '경우',
#   '가',
#   '진짜',
#   '많',
#   '구나',
#   '나',
#   '그거',
#   '되게',
#   '느꼈',
#   '어',
#   '.'],
#  ['아',
#   '진짜',
#   '그거',
#   '나',
#   '도',
#   '동감',
#   '하',
#   '는',
#   '게',
#   '지금',
#   '만',
#   '해서',
#   '도',
#   '진짜',
#   '맨날',
#   '만나',
#   '는',
#   '애',
#   '들'],
#  ['걍', '맨날', '친했', '던', '애', '들', '만', '만나', '지', '진짜', '진짜', '뭐'],
#  ['그냥',
#   '별로',
#   '안',
#   '친했',
#   '던',
#   '안',
#   '친했',
#   '는데',
#   '그래도',
#   '얘기',
#   '는',
#   '하',
#   '는',
#   '그런',
#   '애',
#   '들',
#   '은',
#   '뭐',
#   '소식',
#   '도',
#   '진짜',
#   '모르',
#   '고',
#   '살',
#   '고'],
#  ['그냥', '뭐', '일부러', '이렇게', '약속', '을', '잡', '지', '않', '는', '이상'],
#  ['더', '이상', '만날', '일', '없', '구나', '약간', '이', '생각', '많이', '들', '었', '지'],
#  ['맞아',
#   '근데',
#   '그',
#   '생각',
#   '들',
#   '면',
#   '약간',
#   '아련',
#   '해',
#   '지',
#   '더라',
#   '아',
#   '~',
#   '고등학교',
#   '때',
#   '가',
#   '좋',
#   '긴',
#   '좋',
#   '았',
#   '구나',
#   '다',
#   '같이',
#   '그렇',
#   '게',
#   '있',
#   '을',
#   '때',
#   '가'],
#  ['근데',
#   '그렇게',
#   '같이',
#   '있',
#   '으면서',
#   '쓸데없이',
#   '싸우',
#   '는',
#   '것',
#   '도',
#   '진짜',
#   '많',
#   '았',
#   '던',
#   '거',
#   '같',
#   '아',
#   '.'],
#  ['우리', '진짜', '별', '에', '별', '사건', '다', '있', '었', '잖아', '.'],
#  ['아',
#   '진짜',
#   '왜',
#   '굳이',
#   '그런',
#   '그',
#   '순간',
#   '에서',
#   '그냥',
#   '좀',
#   '만',
#   '참으',
#   '면',
#   '되',
#   '는데'],
#  ['약간', '왜', '싸웠', '지', '약간', '이', '생각', '많이', '들', '기', '도', '하', '고'],
#  ['그냥',
#   '내',
#   '가',
#   '좀',
#   '만',
#   '더',
#   '인제',
#   '너그럽',
#   '게',
#   '이렇게',
#   '배려',
#   '해',
#   '줬',
#   '으면은'],
#  ['그것',
#   '만',
#   '지나',
#   '면',
#   '괜찮',
#   '았',
#   '을',
#   '텐데',
#   '약간',
#   '이',
#   '생각',
#   '많이',
#   '들',
#   '기',
#   '도',
#   '했',
#   '어',
#   '.'],
#  ['근데', '너', '그거', '였잖', '아', '공포', '의', '선도', '부장', '이', '었', '잖아', '.'],
#  ['아니야',
#   '나',
#   '진짜',
#   '나',
#   '지금',
#   '솔직히',
#   '말',
#   '해서',
#   '지금',
#   '와서',
#   '제일',
#   '후회',
#   '하',
#   '는',
#   '게',
#   '선도',
#   '부장',
#   '한',
#   '거',
#   '진짜',
#   '후회',
#   '해'],
#  ['왜냐면', '그때', '욕', '많이', '먹', '기', '도', '진짜', '많이', '먹', '었', '고'],
#  ['그냥',
#   '솔직히',
#   '말',
#   '해서',
#   '내',
#   '어린',
#   '나이',
#   '에',
#   '감당',
#   '할',
#   '수',
#   '있',
#   '는',
#   '직책',
#   '이',
#   '아니',
#   '었',
#   '던',
#   '것',
#   '같',
#   '아',
#   '.'],
#  ['아',
#   '근데',
#   '진짜',
#   '웃기',
#   '긴',
#   '했',
#   '어',
#   '우리',
#   '학년',
#   '이',
#   '든',
#   '일',
#   '학년',
#   '이',
#   '든',
#   '삼',
#   '학년',
#   '이',
#   '든'],
#  ['너',
#   '앞',
#   '에',
#   '스면',
#   '은',
#   '아무',
#   '도',
#   '안',
#   '갔',
#   '잖아',
#   '밥',
#   '먹',
#   '으러',
#   '화장',
#   '한',
#   '애',
#   '들',
#   '이',
#   '고',
#   '교복',
#   '줄인',
#   '애',
#   '들',
#   '이',
#   '고'],
#  ['아',
#   '그리고',
#   '내',
#   '가',
#   '이번',
#   '에',
#   '느낀',
#   '게',
#   '나',
#   '진짜',
#   '진짜',
#   '애',
#   '들',
#   '한테',
#   '너무',
#   '미안',
#   '했',
#   '던',
#   '게'],
#  ['일', '학년', '애', '들', '이랑', '그런', '애', '들', '한테', '너무', '미안', '했', '던', '게'],
#  ['내', '가', '이번', '에', '가', '가지', '고', '적응', '교육', '을', '받', '았', '잖아', '.'],
#  ['인제',
#   '거기',
#   '에',
#   '적응',
#   '교육',
#   '받',
#   '았',
#   '는데',
#   '훈련',
#   '하',
#   '고',
#   '그랬',
#   '잖아',
#   '.'],
#  ['밥',
#   '먹',
#   '는데',
#   '도',
#   '막',
#   '얼차려',
#   '하',
#   '고',
#   '있',
#   '고',
#   '밥',
#   '먹',
#   '기',
#   '전',
#   '에',
#   '얼차려',
#   '하',
#   '고',
#   '그랬',
#   '단',
#   '말',
#   '이',
#   '야',
#   '.'],
#  ['그래서', '나', '는', '솔직히', '진짜', '밥', '엄청', '맛있', '었', '는데', '거기', '밥'],
#  ['그래서', '하루', '에', '한', '끼', '밖', '에', '안', '먹', '고', '그랬었', '는데'],
#  ['아', '나', '진짜', '나쁜', '사람', '이', '었', '구나', '생각', '들', '었', '어', '.'],
#  ['막상', '내', '가', '겪', '고', '나', '니까', '약간', '진짜'],
#  ['고등학교',
#   '때',
#   '고등학교',
#   '때',
#   '너',
#   '가',
#   '그',
#   '잡',
#   '았',
#   '던',
#   '애',
#   '들',
#   '한테',
#   '미안',
#   '했',
#   '어',
#   '?'],
#  ['그냥',
#   '좀',
#   '좀',
#   '만',
#   '더',
#   '약간',
#   '좀',
#   '선도',
#   '부장',
#   '해도',
#   '약간',
#   '좀',
#   '눈',
#   '좀',
#   '처음',
#   '에',
#   '는',
#   '진짜'],
#  ['아',
#   '내',
#   '가',
#   '이',
#   '학교',
#   '진짜',
#   '복장',
#   '같',
#   '은',
#   '게',
#   '맘',
#   '에',
#   '안',
#   '드',
#   '니까'],
#  ['그냥', '다', '바꿔', '보', '겠', '다', '라는', '생각', '으로', '가', '긴', '했', '는데'],
#  ['그냥',
#   '나중',
#   '에',
#   '와서',
#   '느낀',
#   '게',
#   '아',
#   '굳이',
#   '이렇게',
#   '까지',
#   '복장',
#   '을',
#   '막',
#   '잡',
#   '고',
#   '굳이',
#   '이렇게',
#   '막',
#   '화장',
#   '을',
#   '잡',
#   '고',
#   '할',
#   '필요',
#   '가',
#   '있',
#   '나',
#   '?'],
#  ['어차피',
#   '이런',
#   '것',
#   '도',
#   '하나',
#   '의',
#   '자유',
#   '를',
#   '억압',
#   '하',
#   '는',
#   '게',
#   '아닌가',
#   '약간',
#   '이',
#   '생각',
#   '도',
#   '많이',
#   '들',
#   '었',
#   '어',
#   '나중',
#   '에',
#   '와서'],
#  ['근데',
#   '약간',
#   '난',
#   '지금',
#   '와서',
#   '후회',
#   '하',
#   '는',
#   '게',
#   '교복',
#   '많이',
#   '안',
#   '입',
#   '은',
#   '거',
#   '진짜',
#   '후회',
#   '해',
#   '.'],
#  ['아',
#   '그때',
#   '아니',
#   '면',
#   '입',
#   '을',
#   '일',
#   '도',
#   '없',
#   '었',
#   '는데',
#   '뭐',
#   '어',
#   '쩐',
#   '다고',
#   '그렇게',
#   '계속',
#   '맨날',
#   '교복',
#   '안',
#   '입',
#   '는다고',
#   '뻐팅겼지',
#   '?'],
#  ['교복',
#   '좀',
#   '자주',
#   '입',
#   '을',
#   '걸',
#   '이런',
#   '생각',
#   '그때',
#   '아니',
#   '면',
#   '진짜',
#   '못',
#   '입',
#   '는',
#   '거',
#   '잖',
#   '아',
#   '교복',
#   '은'],
#  ['아',
#   '진짜',
#   '나',
#   '는',
#   '근데',
#   '교복',
#   '좀',
#   '많이',
#   '입',
#   '고',
#   '다니',
#   '긴',
#   '했',
#   '는데',
#   '교복'],
#  ['교복',
#   '진짜',
#   '약간',
#   '좀',
#   '길',
#   '지나가',
#   '다가',
#   '우리',
#   '가',
#   '한',
#   '그래도',
#   '한',
#   '오후',
#   '네',
#   '시',
#   '다섯',
#   '시',
#   '쯤',
#   '되',
#   '면은',
#   '그때',
#   '쯤',
#   '마트',
#   '를',
#   '간다'],
#  ['그러면은', '막', '사람', '들', '중학생', '들', '이랑', '고등학생', '들', '인제'],
#  ['자',
#   '다',
#   '인제',
#   '끝나',
#   '고',
#   '수업',
#   '끝',
#   '나',
#   '고',
#   '오',
#   '는',
#   '거',
#   '교복',
#   '입',
#   '고',
#   '오',
#   '는',
#   '거',
#   '보',
#   '면서'],
#  ['약간', '좀', '아련', '해', '지', '는', '느낌', '그런', '게', '있', '지'],
#  ['그러고',
#   '나',
#   '는',
#   '아',
#   '기숙사',
#   '살',
#   '때',
#   '사감',
#   '쌤',
#   '들',
#   '진짜',
#   '욕',
#   '많이',
#   '했',
#   '는데'],
#  ['진짜',
#   '그',
#   '사감',
#   '쌤',
#   '들',
#   '은',
#   '우리',
#   '가',
#   '치',
#   '는',
#   '그',
#   '사고',
#   '들',
#   '을',
#   '정말',
#   '정말',
#   '천사',
#   '처럼',
#   '다',
#   '봐',
#   '주',
#   '신',
#   '거',
#   '구나',
#   '하',
#   '는',
#   '생각',
#   '을',
#   '했',
#   '다',
#   '?'],
#  ['진짜', '더럽', '게', '말', '안', '들', '었', '잖아', '우리'],
#  ['맨날',
#   '밤',
#   '에',
#   '새벽',
#   '마다',
#   '수다',
#   '떨',
#   '면서',
#   '떠들',
#   '고',
#   '와',
#   '가지',
#   '고',
#   '문',
#   '쾅쾅쾅',
#   '뚜드리',
#   '면은',
#   '다',
#   '자',
#   '는',
#   '척하',
#   '고',
#   '이불',
#   '속',
#   '에',
#   '숨',
#   '고'],
#  ['아',
#   '이제',
#   '와서',
#   '생각',
#   '해',
#   '보',
#   '면',
#   '사감',
#   '쌤',
#   '들',
#   '을',
#   '진짜',
#   '우리',
#   '가',
#   '힘들',
#   '게',
#   '했',
#   '다',
#   '그런',
#   '생각',
#   '했',
#   '어',
#   '.'],
#  ['진짜'],
#  ['거기',
#   '서',
#   '맨날',
#   '뭐',
#   '에어컨',
#   '몰래',
#   '애',
#   '들',
#   '이',
#   '에어컨',
#   '냉장고',
#   '선',
#   '에다가',
#   '연결',
#   '시켜',
#   '놓',
#   '고',
#   '에어컨',
#   '틀',
#   '고',
#   '몰래'],
#  ['그런', '거', '보', '면서', '진짜', '진짜', '기숙사', '때', '나', '는', '솔직히'],
#  ['이',
#   '삼',
#   '학년',
#   '때',
#   '는',
#   '기숙사',
#   '에',
#   '없',
#   '어서',
#   '몰랐',
#   '지만',
#   '난',
#   '일',
#   '학년',
#   '땐',
#   '기숙사',
#   '에',
#   '있',
#   '을',
#   '때',
#   '진짜',
#   '재밌',
#   '었',
#   '어',
#   '.'],
#  ['뭐', '새벽', '에', '공부', '한다고', '하', '는데', '고', '밑', '으로', '내려가', '서'],
#  ['그', '핸드폰', '질', '하', '고', '있', '고'],
#  ['맞아',
#   '근데',
#   '난',
#   '제일',
#   '재밌',
#   '었',
#   '던',
#   '건',
#   '일',
#   '학년',
#   '기숙사',
#   '다',
#   '끝나갈',
#   '때'],
#  ['학', 'x', '쌤', '이랑', '고기', '파티', '한', '거'],
#  ['거기',
#   '이',
#   '층',
#   '기숙사',
#   '다',
#   '비우',
#   '고',
#   '하룻밤',
#   '자',
#   '고',
#   '그게',
#   '진짜',
#   '재밌',
#   '었',
#   '던',
#   '거',
#   '같',
#   '애',
#   '.'],
#  ['이제',
#   '와서',
#   '생각',
#   '해',
#   '보',
#   '면',
#   '솔직히',
#   '고등학교',
#   '기숙사',
#   '에서',
#   '그런',
#   '걸',
#   '한다는',
#   '거',
#   '자체',
#   '가',
#   '말',
#   '이',
#   '안',
#   '되',
#   '지'],
#  ['근데',
#   '선생',
#   '님',
#   '들',
#   '이',
#   '그렇게',
#   '해',
#   '준',
#   '게',
#   '진짜',
#   '기억',
#   '에',
#   '되게',
#   '많이',
#   '남',
#   '아',
#   '.'],
#  ['그',
#   '고기',
#   '꾸',
#   '어',
#   '먹',
#   '고',
#   '애',
#   '들',
#   '이랑',
#   '막',
#   '다',
#   '같이',
#   '모여',
#   '가지',
#   '고',
#   '카드',
#   '게임',
#   '하',
#   '고',
#   '진짜',
#   '재밌',
#   '었',
#   '어',
#   '그때',
#   '는'],
#  ['아', '난', '사실', '못', '갔', '어', '.'],
#  ['너', '못', '왔', '어', '못', '왔', '나', '?'],
#  ['어',
#   '그때',
#   '막',
#   '가',
#   '기',
#   '귀찮',
#   '아',
#   '가지',
#   '고',
#   '인제',
#   '막상',
#   '집',
#   '갔',
#   '는데',
#   '가',
#   '기',
#   '가',
#   '기',
#   '귀찮',
#   '아서',
#   '계속',
#   '버팅',
#   '겼',
#   '는데'],
#  ['갈', '걸', '그랬', '어', '그', '나중', '에', '도', '후회', '했', '어', '.'],
#  ['진짜',
#   '그',
#   '며칠',
#   '안',
#   '지나',
#   '서',
#   '도',
#   '애',
#   '들',
#   '이',
#   '막',
#   '엄청',
#   '재밌',
#   '었',
#   '다고',
#   '그러',
#   '니까'],
#  ['진짜', '기숙사', '에', '있', '을', '때', '막', '애', '들', '한테', '애', '들', '한테'],
#  ['막',
#   '진짜',
#   '막',
#   '음식',
#   '도',
#   '뺏',
#   '어',
#   '먹',
#   '고',
#   '아침',
#   '급식',
#   '먹',
#   '으러',
#   '갈',
#   '때',
#   '다',
#   '부',
#   '어',
#   '가지',
#   '고',
#   '인제'],
#  ['일어나',
#   '가지',
#   '고',
#   '진짜',
#   '밥',
#   '먹',
#   '는',
#   '사람',
#   '한두',
#   '명',
#   '되',
#   '고',
#   '나중',
#   '에',
#   '와서',
#   '는'],
#  ['그런',
#   '것',
#   '도',
#   '재밌',
#   '었',
#   '고',
#   '이제',
#   '저녁',
#   '에',
#   '석식',
#   '먹',
#   '고',
#   '들어왔',
#   '을',
#   '때'],
#  ['막', '시험', '기간', '에', '도', '시험', '기간', '때', '공부', '하나', '도', '안', '하', '고'],
#  ['막',
#   '마지막',
#   '날',
#   '돼서',
#   '야',
#   '겨우',
#   '이거',
#   '외워야',
#   '된다고',
#   '하',
#   '면서',
#   '서로',
#   '알려',
#   '주',
#   '면서',
#   '이제',
#   '그렇게',
#   '하',
#   '고'],
#  ['그런', '것', '도', '진짜', '재밌', '었', '고'],
#  ['걍', '다', '애', '들', '도', '진짜', '막'],
#  ['진짜',
#   '막',
#   '갑자기',
#   '뭐',
#   '저녁',
#   '에',
#   '갑자기',
#   '뭐',
#   '갑자기',
#   '자기',
#   '들',
#   '끼리',
#   '화장',
#   '하',
#   '고',
#   '자기',
#   '들',
#   '끼리',
#   '혼자',
#   '춤추',
#   '면서',
#   '그것',
#   '도',
#   '웃겼',
#   '고'],
#  ['다', '재밌', '었', '던', '거', '같', '아', '.'],
#  ['근데', '나', '는', '이제', '와서', '약간', '웃긴', '게'],
#  ['우리',
#   '는',
#   '왜',
#   '그렇게',
#   '축제',
#   '와',
#   '체육',
#   '대회',
#   '에',
#   '집착',
#   '을',
#   '하',
#   '였',
#   '는가'],
#  ['그게',
#   '이제',
#   '와서',
#   '생각',
#   '해',
#   '보',
#   '면',
#   '되게',
#   '웃기',
#   '다',
#   '그',
#   '지',
#   '않',
#   '아',
#   '?'],
#  ['아',
#   '진짜',
#   '축제',
#   '때',
#   '막',
#   '진짜',
#   '왜',
#   '그렇게',
#   '진짜',
#   '다',
#   '집착',
#   '을',
#   '했',
#   '지',
#   '?'],
#  ['굳이',
#   '그',
#   '가운데',
#   '자리',
#   '가',
#   '뭐',
#   '가',
#   '중요',
#   '하',
#   '다고',
#   '막',
#   '–',
#   '선',
#   '-',
#   '선배',
#   '돼',
#   '가지',
#   '고'],
#  ['막', '그런', '것', '도', '있', '었', '고'],
#  ['뭐',
#   '체육',
#   '대회',
#   '만',
#   '해도',
#   '내',
#   '가',
#   '왜',
#   '그렇게',
#   '열심히',
#   '했',
#   '는지',
#   '모르',
#   '겠',
#   '어',
#   '.'],
#  ['그냥', '조용히', '뒤', '에서', '뒤', '에서', '있', '을', '걸', '귀찮', '은데'],
#  ['진짜',
#   '축제',
#   '때',
#   '막',
#   '누가',
#   '반',
#   '애',
#   '들',
#   '끼리',
#   '다',
#   '같이',
#   '춤',
#   '짜',
#   '가지',
#   '고',
#   '막',
#   '겁나',
#   '열심히',
#   '하',
#   '고'],
#  ['이제',
#   '와서',
#   '생각',
#   '해',
#   '보',
#   '면',
#   '우리',
#   '가',
#   '무슨',
#   '고유',
#   '도',
#   '아니',
#   '고',
#   '그렇게',
#   '할',
#   '필요',
#   '도',
#   '없',
#   '었',
#   '는데'],
#  ['다',
#   '춤',
#   '에',
#   '집착',
#   '해',
#   '가지',
#   '고',
#   '막',
#   '하루',
#   '에',
#   '여섯',
#   '시간',
#   '씩',
#   '수업',
#   '시간',
#   '다',
#   '빼',
#   '고',
#   '연습',
#   '실',
#   '빌려',
#   '가지',
#   '고',
#   '막',
#   '연습',
#   '하',
#   '고'],
#  ['그런', '거', '보', '면', '진짜', '웃긴', '거', '같', '애', '체육', '대회', '도', '막'],
#  ['선생',
#   '님',
#   '들',
#   '한테',
#   '선생',
#   '님',
#   '체육',
#   '대회',
#   '잖',
#   '아요',
#   '다음',
#   '시간',
#   '체육',
#   '대회',
#   '잖',
#   '아요',
#   '이러',
#   '면서'],
#  ['수업',
#   '시간',
#   '한',
#   '시간',
#   '빼',
#   '가지',
#   '고',
#   '운동장',
#   '가',
#   '서',
#   '막',
#   '연습',
#   '하',
#   '고',
#   '그랬',
#   '던'],
#  ['이제', '와서', '보', '면', '진짜', '웃겼', '던', '거', '같', '애', '그건', '진짜'],
#  ['특히',
#   '우리',
#   '중학생',
#   '때',
#   '더',
#   '그랬',
#   '던',
#   '거',
#   '같',
#   '아',
#   '막',
#   '에어로빅',
#   '한다고',
#   '하',
#   '면서'],
#  ['근데', '나', '는', '그때', '항상', '의아', '했', '던', '게', '왜', '에어로빅', '보다'],
#  ['달리기',
#   '가',
#   '더',
#   '점수',
#   '가',
#   '더',
#   '큰',
#   '데',
#   '에어로빅',
#   '에',
#   '왜',
#   '케',
#   '집착',
#   '하',
#   '지',
#   '약간',
#   '이런',
#   '생각',
#   '도',
#   '했',
#   '는데'],
#  ['근데', '또', '애', '들', '이', '나름', '대로', '의', '자존심', '이', '있', '더라고'],
#  ['중학교', '때', '생각', '해도', '진짜', '웃겼', '었', '어', '.'],
#  ['아',
#   '중학교',
#   '때',
#   '가',
#   '진짜',
#   '미친',
#   '듯이',
#   '재밌',
#   '었',
#   '던',
#   '거',
#   '같',
#   '애',
#   '&',
#   'name',
#   '1',
#   '&',
#   '쌤',
#   '진짜',
#   '웃겼',
#   '고'],
#  ['그', '담', '에', '중학교', '때', '생각나', '는', '건', '나', '는', '중학교'],
#  ['우리',
#   '중학교',
#   '앞',
#   '에',
#   '있',
#   '었',
#   '던',
#   '그',
#   '수많',
#   '은',
#   '분식집',
#   '과',
#   '이삭',
#   '토스트'],
#  ['그거', '먹', '었', '던', '게', '진짜', '생각', '이', '되게', '많이', '나'],
#  ['나', '도', '솔직히', '말', '하', '면', '중학교', '딱', '돌아가', '면'],
#  ['중학교',
#   '가',
#   '면',
#   '솔직히',
#   '그',
#   '거리',
#   '걸',
#   '을',
#   '수',
#   '밖에',
#   '없',
#   '는',
#   '것',
#   '같',
#   '아',
#   '.'],
#  ['근데',
#   '좀',
#   '슬펐',
#   '던',
#   '게',
#   '다',
#   '사라지',
#   '고',
#   '인제',
#   '없',
#   '어',
#   '진',
#   '것',
#   '도',
#   '슬펐',
#   '는데'],
#  ['약간',
#   '좀',
#   '진짜',
#   '점심',
#   '에',
#   '우리',
#   '맨날',
#   '거기',
#   '계단',
#   '앞',
#   '에',
#   '있',
#   '어',
#   '가지',
#   '고',
#   '아이스크림',
#   '사',
#   '먹',
#   '는다고'],
#  ['몰래',
#   '거기',
#   '있',
#   '다가',
#   '시내',
#   '에서',
#   '밥',
#   '먹',
#   '고',
#   '보',
#   '는',
#   '선생',
#   '님',
#   '들',
#   '보',
#   '면은',
#   '인제',
#   '그',
#   '&',
#   'company',
#   '-',
#   'name',
#   '1',
#   '&',
#   '슈퍼',
#   '아이스크림'],
#  ['거기',
#   '냉장고',
#   '옆',
#   '에',
#   '숨',
#   '어',
#   '있',
#   '고',
#   '막',
#   '아줌마',
#   '한테',
#   '화장품',
#   '좀',
#   '맡겨',
#   '달',
#   '라고',
#   '하',
#   '고',
#   '그랬었',
#   '던',
#   '그런',
#   '것',
#   '도',
#   '많',
#   '았',
#   '어',
#   '.'],
#  ['맞', '아', '진짜', '재밌', '었', '던', '거', '같', '애', '.'],
#  ...]

# %%
standard_list = df["표준어"].to_list()
standard_list = list(map(morph_and_preprocess, standard_list))
standard_list

# %% [markdown]
# ### 형태소로 분리한 문장을 띄어쓰기로 구분하여 저장

# %%
list_to_spaced_sentence = lambda li : " ".join(li)
df["방언"] = list(map(list_to_spaced_sentence, dialect_list))
df["표준어"] = list(map(list_to_spaced_sentence, standard_list))

df.head()

# %%
df.to_csv("datas/output/jeonla_dialect_data_processed_2.csv")

# %% [markdown]
# ### 단어 수 분석

# %% [markdown]
# ### 표준어-방언 등장 단어 비교 분석
